# %% [markdown]
# Time-Series Prediction
# Time series and sequence prediction could be a really amazing to predict/estimate a robot's trajectory which requires temporal data at hand. In this assignemnt we will see how this could be done using Deep Learning.
#
# Given a dataset [link](https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv) for airline passengers prediction problem. Predict the number of international airline passengers in units of 1,000 given a year and a month.
# Here is how the data looks like.

# %%
import netron 
netron.start('rnnmodel.onnx')
# Out:
# Serving 'rnnmodel.onnx' at http://localhost:8080
# ('localhost', 8080)

# %%
import matplotlib.pyplot as plt
import pandas as pd
file_name = 'experimental/Training.csv' # dataset path
# Reading data using pandas or csv
df = pd.read_csv(file_name)
print(df.columns)
# Out:
# Index(['Time', 'Output Speed', 'Input Torque', 'Input Speed', 'Weight on bit'], dtype='object')

# %%
df
# Out:
#          Time  Output Speed  Input Torque  Input Speed  Weight on bit
# 0       0.000    148.157782      0.546254   104.776226     539.866525
# 1       0.001    148.870922      0.566799   105.120533     537.944529
# 2       0.002    149.556036      0.594301   106.241970     536.005967
# 3       0.003    150.212917      0.628518   108.393450     534.037938
# 4       0.004    150.841484      0.669332   109.377789     532.056127
# ...       ...           ...           ...          ...            ...
# 52995  52.995    141.525790      1.402770   102.036217     448.634747
# 52996  52.996    142.137385      1.391925   101.221814     447.199109
# 52997  52.997    142.726691      1.381913   100.893232     445.788984
# 52998  52.998    143.293376      1.372741   101.865686     444.418114
# 52999  52.999    143.837221      1.364316   102.100991     443.069257
#
# [53000 rows x 5 columns]

# %%
# Converting columns to numpy arrays for plotting
time = df[["Time"]].values.astype('float32')
output_speed = df[["Output Speed"]].values.astype('float32')
input_torque = df[["Input Torque"]].values.astype('float32')
input_speed = df[["Input Speed"]].values.astype('float32')
weight_on_bit = df[["Weight on bit"]].values.astype('float32')

# Plotting the dataset
fig, axs = plt.subplots(2, 2, figsize=(15, 9))

# Plot Input Speed
axs[0, 0].plot(time, input_speed, label='Input Speed')
axs[0, 0].set_title('Input Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Plot Input Torque
axs[0, 1].plot(time, input_torque, label='Input Torque')
axs[0, 1].set_title('Input Torque')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Torque (N-m)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Plot Output Speed
axs[1, 0].plot(time, output_speed, label='Output Speed')
axs[1, 0].set_title('Output Speed')
axs[1, 0].set_xlabel('Time (s)')
axs[1, 0].set_ylabel('Angular Speed (rad/s)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Plot Weight on Bit
axs[1, 1].plot(time, weight_on_bit, label='Weight on Bit')
axs[1, 1].set_title('Weight on Bit')
axs[1, 1].set_xlabel('Time (s)')
axs[1, 1].set_ylabel('Weight (kg)')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # **Pytorch LSTM Implementation**

# %% [markdown]
# # Pre-Processing the Training Data

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

xy = np.loadtxt('experimental/Training.csv', delimiter=",", dtype=np.object_, skiprows=1)

# Convert the data to a 2D NumPy array of floats
features = np.array(xy[:, 1:], dtype=np.float32)

from sklearn.preprocessing import MinMaxScaler
feature_scaler = MinMaxScaler(feature_range=(0,1))
scaled_features = feature_scaler.fit_transform(features)

# Convert the NumPy array to a PyTorch tensor
Training_set = torch.from_numpy(scaled_features).to(device)

print("=================Creating_Dataset==================\n", Training_set.shape, "\n")

set_to_scale_features = []
set_to_scale_labels = []

# # Loop through the array to create the feature and label sets
for i in range(30, Training_set.shape[0]):
    set_to_scale_features.append(Training_set[i-30:i, [1, 2]].cpu().numpy())
    set_to_scale_labels.append(Training_set[i, [0, 3]].cpu().numpy())

# # Convert lists to NumPy arrays
set_to_scale_features = np.array(set_to_scale_features)
set_to_scale_labels = np.array(set_to_scale_labels)


print("=================Creating Features and Labels==================\n", set_to_scale_features.shape, "\n", set_to_scale_labels.shape, "\n" )

# # Reshape the feature set
X_train = torch.from_numpy(set_to_scale_features.reshape(set_to_scale_features.shape[0], set_to_scale_features.shape[1], 2)).to(device)

# # Convert labels to PyTorch tensor
Y_train = torch.from_numpy(set_to_scale_labels.reshape(set_to_scale_labels.shape[0], 2)).to(device)

print("=================Converting Features and Labels to Tensors==================\n", X_train.shape, "\n", Y_train.shape, "\n" )

# set_to_scale_labels = set_to_scale_labels.unsqueeze(1)
# print("Unsqueezed the labels to combine", set_to_scale_labels.shape)
# Out:
# =================Creating_Dataset==================
#  torch.Size([53000, 4])
#
# =================Creating Features and Labels==================
#  (52970, 30, 2)
#  (52970, 2)
#
# =================Converting Features and Labels to Tensors==================
#  torch.Size([52970, 30, 2])
#  torch.Size([52970, 2])

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

xy = np.loadtxt('experimental/Testing.csv', delimiter=",", dtype=np.object_, skiprows=1)

# Convert the data to a 2D NumPy array of floats
test_features = np.array(xy[:, 1:], dtype=np.float32)

scaled_test_features = feature_scaler.transform(test_features)

# Convert the NumPy array to a PyTorch tensor
Testing_set = torch.from_numpy(scaled_test_features).to(device)

print("=================Creating_Dataset==================\n", Testing_set.shape, "\n")

set_to_scale_test_features = []
set_to_scale_test_labels = []

# # Loop through the array to create the feature and label sets
for i in range(30, Testing_set.shape[0]):
    set_to_scale_test_features.append(Testing_set[i-30:i, [1, 2]].cpu().numpy())
    set_to_scale_test_labels.append(Testing_set[i, [0, 3]].cpu().numpy())

# # Convert lists to NumPy arrays
set_to_scale_test_features = np.array(set_to_scale_test_features)
set_to_scale_test_labels = np.array(set_to_scale_test_labels)


print("=================Creating Features and Labels==================\n", set_to_scale_test_features.shape, "\n", set_to_scale_test_labels.shape, "\n" )

# # Reshape the feature set
X_test = torch.from_numpy(set_to_scale_test_features.reshape(set_to_scale_test_features.shape[0], set_to_scale_test_features.shape[1], 2)).to(device)

# # Convert labels to PyTorch tensor
Y_test = torch.from_numpy(set_to_scale_test_labels.reshape(set_to_scale_test_labels.shape[0], 2)).to(device)

print("=================Converting Features and Labels to Tensors==================\n", X_test.shape, "\n", Y_test.shape, "\n" )
# Out:
# =================Creating_Dataset==================
#  torch.Size([6000, 4])
#
# =================Creating Features and Labels==================
#  (5970, 30, 2)
#  (5970, 2)
#
# =================Converting Features and Labels to Tensors==================
#  torch.Size([5970, 30, 2])
#  torch.Size([5970, 2])

# %%
# # Creating dataset objects to process nn data through pytorch
from torch.utils.data import Dataset

class TSA(Dataset):
  def __init__(self, X, Y):
    self.X = X
    self.Y = Y

  def __getitem__(self, index) :
    return self.X[index], self.Y[index]

  def __len__(self):
    return len(self.X)

train_dataset = TSA(X_train, Y_train)
test_dataset = TSA(X_test, Y_test)

# train_dataset

# # Using data_loader to classify data in required format
from torch.utils.data import DataLoader

batch_size = 30

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# # Print the batch sizes to confirm
for _, batch in enumerate(train_loader):
  x_batch, y_batch = batch[0].to(device), batch[1].to(device)
  print(x_batch.shape, y_batch.shape)
  break
# Out:
# torch.Size([30, 30, 2]) torch.Size([30, 2])

# %% [markdown]
# # LSTM Training

# %%
import numpy as np
import torch
import torch.nn as nn

# Define the hyperparameters
input_size = 2
hidden_size = 120
num_stacked_layers = 5
fc_size1 = 140
fc_size2 = 280
fc_size3 = 360
output_size = 2
dropout = 0.1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Modified LSTMModel with separate fully connected layers for each output
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers, dropout, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm1 = nn.LSTM(input_size, hidden_size, num_stacked_layers, batch_first=True, dropout=dropout)
        self.dropout = nn.Dropout(dropout)

        # Separate fully connected layers for each output
        self.fc_output1 = nn.Sequential(
            nn.Linear(hidden_size, fc_size1),
            nn.ReLU(),
            nn.Linear(fc_size1, fc_size2),
            nn.ReLU(),
            nn.Linear(fc_size2, fc_size3),
            nn.ReLU(),
            nn.Linear(fc_size3, 1)
        )

        self.fc_output2 = nn.Sequential(
            nn.Linear(hidden_size, fc_size1),
            nn.ReLU(),
            nn.Linear(fc_size1, fc_size2),
            nn.ReLU(),
            nn.Linear(fc_size2, fc_size3),
            nn.ReLU(),
            nn.Linear(fc_size3, 1)
        )

    def forward(self, x):
        h0 = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_stacked_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm1(x, (h0, c0))
        out = self.dropout(out[:, -1, :])  # Use only the last time step output

        # Apply separate fully connected layers for each output
        output1 = self.fc_output1(out)
        output2 = self.fc_output2(out)

        # Concatenate the outputs
        return torch.cat((output1, output2), dim=1)

# Initialize the model
model = LSTMModel(input_size, hidden_size, num_stacked_layers, dropout, output_size=output_size)
model.to(device)

# Print model summary
print(model)
# Out:
# LSTMModel(
#   (lstm1): LSTM(2, 120, num_layers=5, batch_first=True, dropout=0.1)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc_output1): Sequential(
#     (0): Linear(in_features=120, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=280, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=280, out_features=360, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=360, out_features=1, bias=True)
#   )
#   (fc_output2): Sequential(
#     (0): Linear(in_features=120, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=280, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=280, out_features=360, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=360, out_features=1, bias=True)
#   )
# )

# %%
import torch.optim as optim
learning_rate = 0.001
num_epochs = 20

best_val_loss = float('inf')
patience = 5
counter = 0

val_loss_list = []

# Define your loss function
loss_function = nn.MSELoss()

# Define your optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Running epochs
for epoch in range(num_epochs):
    # Set model to training mode
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # print(batch_index)
        if batch_index % 2 == 1:
          avg_loss_across_batches = running_loss / 100
          print('Batch {0}, Loss: {1: .6f}, Epoch: {2}'.format(batch_index+1, avg_loss_across_batches, epoch+1))

# Validate every epoch
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
          output = model(x_batch)
          loss = loss_function(output, y_batch)
          running_loss += loss

    val_loss = running_loss / len(test_loader)
    print('Validation Loss {0: .3f}'.format(val_loss))

    print('###################################################')

    running_loss = 0.0

    val_loss_list.append(val_loss)

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping")
            print(val_loss_list)
            print("Best_Validation_Loss", best_val_loss)
            break

# Save the model
model_save_path = 'model.pth'
torch.save(model.state_dict(), model_save_path)
# Out:
# Epoch: 1
# Batch 2, Loss:  0.005532, Epoch: 1
# Batch 4, Loss:  0.009188, Epoch: 1
# Batch 6, Loss:  0.011901, Epoch: 1
# Batch 8, Loss:  0.013316, Epoch: 1
# Batch 10, Loss:  0.014962, Epoch: 1
# Batch 12, Loss:  0.016149, Epoch: 1
# Batch 14, Loss:  0.017369, Epoch: 1
# Batch 16, Loss:  0.018734, Epoch: 1
# Batch 18, Loss:  0.020173, Epoch: 1
# Batch 20, Loss:  0.021332, Epoch: 1
# Batch 22, Loss:  0.022558, Epoch: 1
# Batch 24, Loss:  0.023975, Epoch: 1
# Batch 26, Loss:  0.025252, Epoch: 1
# Batch 28, Loss:  0.026511, Epoch: 1
# Batch 30, Loss:  0.027867, Epoch: 1
# Batch 32, Loss:  0.028983, Epoch: 1
# Batch 34, Loss:  0.030016, Epoch: 1
# Batch 36, Loss:  0.031182, Epoch: 1
# Batch 38, Loss:  0.032474, Epoch: 1
# Batch 40, Loss:  0.033765, Epoch: 1
# Batch 42, Loss:  0.034992, Epoch: 1
# Batch 44, Loss:  0.036114, Epoch: 1
# Batch 46, Loss:  0.037087, Epoch: 1
# Batch 48, Loss:  0.038296, Epoch: 1
# Batch 50, Loss:  0.039314, Epoch: 1
# Batch 52, Loss:  0.040400, Epoch: 1
# Batch 54, Loss:  0.041505, Epoch: 1
# Batch 56, Loss:  0.042514, Epoch: 1
# Batch 58, Loss:  0.043534, Epoch: 1
# Batch 60, Loss:  0.044439, Epoch: 1
# Batch 62, Loss:  0.045121, Epoch: 1
# Batch 64, Loss:  0.045825, Epoch: 1
# Batch 66, Loss:  0.046683, Epoch: 1
# Batch 68, Loss:  0.047221, Epoch: 1
# Batch 70, Loss:  0.047975, Epoch: 1
# Batch 72, Loss:  0.048794, Epoch: 1
# Batch 74, Loss:  0.049600, Epoch: 1
# Batch 76, Loss:  0.050266, Epoch: 1
# Batch 78, Loss:  0.050858, Epoch: 1
# Batch 80, Loss:  0.051541, Epoch: 1
# Batch 82, Loss:  0.052273, Epoch: 1
# Batch 84, Loss:  0.052871, Epoch: 1
# Batch 86, Loss:  0.053493, Epoch: 1
# Batch 88, Loss:  0.054158, Epoch: 1
# Batch 90, Loss:  0.054724, Epoch: 1
# Batch 92, Loss:  0.055284, Epoch: 1
# Batch 94, Loss:  0.055666, Epoch: 1
# Batch 96, Loss:  0.056186, Epoch: 1
# Batch 98, Loss:  0.056672, Epoch: 1
# Batch 100, Loss:  0.057393, Epoch: 1
# Batch 102, Loss:  0.057800, Epoch: 1
# Batch 104, Loss:  0.058403, Epoch: 1
# Batch 106, Loss:  0.058843, Epoch: 1
# Batch 108, Loss:  0.059517, Epoch: 1
# Batch 110, Loss:  0.059949, Epoch: 1
# Batch 112, Loss:  0.060412, Epoch: 1
# Batch 114, Loss:  0.060863, Epoch: 1
# Batch 116, Loss:  0.061271, Epoch: 1
# Batch 118, Loss:  0.061755, Epoch: 1
# Batch 120, Loss:  0.062151, Epoch: 1
# Batch 122, Loss:  0.062552, Epoch: 1
# Batch 124, Loss:  0.062922, Epoch: 1
# Batch 126, Loss:  0.063352, Epoch: 1
# Batch 128, Loss:  0.063813, Epoch: 1
# Batch 130, Loss:  0.064162, Epoch: 1
# Batch 132, Loss:  0.064610, Epoch: 1
# Batch 134, Loss:  0.065024, Epoch: 1
# Batch 136, Loss:  0.065442, Epoch: 1
# Batch 138, Loss:  0.065942, Epoch: 1
# Batch 140, Loss:  0.066339, Epoch: 1
# Batch 142, Loss:  0.066772, Epoch: 1
# Batch 144, Loss:  0.067200, Epoch: 1
# Batch 146, Loss:  0.067697, Epoch: 1
# Batch 148, Loss:  0.068204, Epoch: 1
# Batch 150, Loss:  0.068710, Epoch: 1
# Batch 152, Loss:  0.069048, Epoch: 1
# Batch 154, Loss:  0.069586, Epoch: 1
# Batch 156, Loss:  0.070046, Epoch: 1
# Batch 158, Loss:  0.070465, Epoch: 1
# Batch 160, Loss:  0.070979, Epoch: 1
# Batch 162, Loss:  0.071332, Epoch: 1
# Batch 164, Loss:  0.071738, Epoch: 1
# Batch 166, Loss:  0.072181, Epoch: 1
# Batch 168, Loss:  0.072575, Epoch: 1
# Batch 170, Loss:  0.072940, Epoch: 1
# Batch 172, Loss:  0.073269, Epoch: 1
# Batch 174, Loss:  0.073702, Epoch: 1
# Batch 176, Loss:  0.074171, Epoch: 1
# Batch 178, Loss:  0.074591, Epoch: 1
# Batch 180, Loss:  0.075085, Epoch: 1
# Batch 182, Loss:  0.075495, Epoch: 1
# Batch 184, Loss:  0.075975, Epoch: 1
# Batch 186, Loss:  0.076386, Epoch: 1
# Batch 188, Loss:  0.076851, Epoch: 1
# Batch 190, Loss:  0.077286, Epoch: 1
# Batch 192, Loss:  0.077621, Epoch: 1
# Batch 194, Loss:  0.078122, Epoch: 1
# Batch 196, Loss:  0.078491, Epoch: 1
# Batch 198, Loss:  0.078898, Epoch: 1
# Batch 200, Loss:  0.079333, Epoch: 1
# Batch 202, Loss:  0.079741, Epoch: 1
# Batch 204, Loss:  0.080151, Epoch: 1
# Batch 206, Loss:  0.080538, Epoch: 1
# Batch 208, Loss:  0.080924, Epoch: 1
# Batch 210, Loss:  0.081298, Epoch: 1
# Batch 212, Loss:  0.081690, Epoch: 1
# Batch 214, Loss:  0.082111, Epoch: 1
# Batch 216, Loss:  0.082416, Epoch: 1
# Batch 218, Loss:  0.082922, Epoch: 1
# Batch 220, Loss:  0.083337, Epoch: 1
# Batch 222, Loss:  0.083782, Epoch: 1
# Batch 224, Loss:  0.084067, Epoch: 1
# Batch 226, Loss:  0.084510, Epoch: 1
# Batch 228, Loss:  0.084875, Epoch: 1
# Batch 230, Loss:  0.085247, Epoch: 1
# Batch 232, Loss:  0.085713, Epoch: 1
# Batch 234, Loss:  0.086127, Epoch: 1
# Batch 236, Loss:  0.086659, Epoch: 1
# Batch 238, Loss:  0.087084, Epoch: 1
# Batch 240, Loss:  0.087524, Epoch: 1
# Batch 242, Loss:  0.087957, Epoch: 1
# Batch 244, Loss:  0.088330, Epoch: 1
# Batch 246, Loss:  0.088726, Epoch: 1
# Batch 248, Loss:  0.089153, Epoch: 1
# Batch 250, Loss:  0.089566, Epoch: 1
# Batch 252, Loss:  0.090049, Epoch: 1
# Batch 254, Loss:  0.090434, Epoch: 1
# Batch 256, Loss:  0.090833, Epoch: 1
# Batch 258, Loss:  0.091113, Epoch: 1
# Batch 260, Loss:  0.091481, Epoch: 1
# Batch 262, Loss:  0.091791, Epoch: 1
# Batch 264, Loss:  0.092186, Epoch: 1
# Batch 266, Loss:  0.092575, Epoch: 1
# Batch 268, Loss:  0.092887, Epoch: 1
# Batch 270, Loss:  0.093283, Epoch: 1
# Batch 272, Loss:  0.093736, Epoch: 1
# Batch 274, Loss:  0.094112, Epoch: 1
# Batch 276, Loss:  0.094447, Epoch: 1
# Batch 278, Loss:  0.094840, Epoch: 1
# Batch 280, Loss:  0.095133, Epoch: 1
# Batch 282, Loss:  0.095508, Epoch: 1
# Batch 284, Loss:  0.095859, Epoch: 1
# Batch 286, Loss:  0.096360, Epoch: 1
# Batch 288, Loss:  0.096849, Epoch: 1
# Batch 290, Loss:  0.097243, Epoch: 1
# Batch 292, Loss:  0.097679, Epoch: 1
# Batch 294, Loss:  0.098064, Epoch: 1
# Batch 296, Loss:  0.098331, Epoch: 1
# Batch 298, Loss:  0.098718, Epoch: 1
# Batch 300, Loss:  0.099085, Epoch: 1
# Batch 302, Loss:  0.099329, Epoch: 1
# Batch 304, Loss:  0.099687, Epoch: 1
# Batch 306, Loss:  0.100075, Epoch: 1
# Batch 308, Loss:  0.100418, Epoch: 1
# Batch 310, Loss:  0.100869, Epoch: 1
# Batch 312, Loss:  0.101218, Epoch: 1
# Batch 314, Loss:  0.101642, Epoch: 1
# Batch 316, Loss:  0.102068, Epoch: 1
# Batch 318, Loss:  0.102416, Epoch: 1
# Batch 320, Loss:  0.102710, Epoch: 1
# Batch 322, Loss:  0.102981, Epoch: 1
# Batch 324, Loss:  0.103340, Epoch: 1
# Batch 326, Loss:  0.103647, Epoch: 1
# Batch 328, Loss:  0.103983, Epoch: 1
# Batch 330, Loss:  0.104308, Epoch: 1
# Batch 332, Loss:  0.104569, Epoch: 1
# Batch 334, Loss:  0.104976, Epoch: 1
# Batch 336, Loss:  0.105378, Epoch: 1
# Batch 338, Loss:  0.105699, Epoch: 1
# Batch 340, Loss:  0.106163, Epoch: 1
# Batch 342, Loss:  0.106502, Epoch: 1
# Batch 344, Loss:  0.106827, Epoch: 1
# Batch 346, Loss:  0.107168, Epoch: 1
# Batch 348, Loss:  0.107538, Epoch: 1
# Batch 350, Loss:  0.107841, Epoch: 1
# Batch 352, Loss:  0.108229, Epoch: 1
# Batch 354, Loss:  0.108591, Epoch: 1
# Batch 356, Loss:  0.108907, Epoch: 1
# Batch 358, Loss:  0.109355, Epoch: 1
# Batch 360, Loss:  0.109637, Epoch: 1
# Batch 362, Loss:  0.109956, Epoch: 1
# Batch 364, Loss:  0.110267, Epoch: 1
# Batch 366, Loss:  0.110546, Epoch: 1
# Batch 368, Loss:  0.110803, Epoch: 1
# Batch 370, Loss:  0.111142, Epoch: 1
# Batch 372, Loss:  0.111526, Epoch: 1
# Batch 374, Loss:  0.111936, Epoch: 1
# Batch 376, Loss:  0.112277, Epoch: 1
# Batch 378, Loss:  0.112661, Epoch: 1
# Batch 380, Loss:  0.113202, Epoch: 1
# Batch 382, Loss:  0.113639, Epoch: 1
# Batch 384, Loss:  0.114094, Epoch: 1
# Batch 386, Loss:  0.114511, Epoch: 1
# Batch 388, Loss:  0.114927, Epoch: 1
# Batch 390, Loss:  0.115408, Epoch: 1
# Batch 392, Loss:  0.115738, Epoch: 1
# Batch 394, Loss:  0.116167, Epoch: 1
# Batch 396, Loss:  0.116519, Epoch: 1
# Batch 398, Loss:  0.116875, Epoch: 1
# Batch 400, Loss:  0.117328, Epoch: 1
# Batch 402, Loss:  0.117712, Epoch: 1
# Batch 404, Loss:  0.118160, Epoch: 1
# Batch 406, Loss:  0.118623, Epoch: 1
# Batch 408, Loss:  0.118978, Epoch: 1
# Batch 410, Loss:  0.119415, Epoch: 1
# Batch 412, Loss:  0.119885, Epoch: 1
# Batch 414, Loss:  0.120356, Epoch: 1
# Batch 416, Loss:  0.120746, Epoch: 1
# Batch 418, Loss:  0.121215, Epoch: 1
# Batch 420, Loss:  0.121661, Epoch: 1
# Batch 422, Loss:  0.122041, Epoch: 1
# Batch 424, Loss:  0.122347, Epoch: 1
# Batch 426, Loss:  0.122728, Epoch: 1
# Batch 428, Loss:  0.123126, Epoch: 1
# Batch 430, Loss:  0.123461, Epoch: 1
# Batch 432, Loss:  0.123788, Epoch: 1
# Batch 434, Loss:  0.124289, Epoch: 1
# Batch 436, Loss:  0.124656, Epoch: 1
# Batch 438, Loss:  0.125044, Epoch: 1
# Batch 440, Loss:  0.125373, Epoch: 1
# Batch 442, Loss:  0.125712, Epoch: 1
# Batch 444, Loss:  0.126129, Epoch: 1
# Batch 446, Loss:  0.126399, Epoch: 1
# Batch 448, Loss:  0.126817, Epoch: 1
# Batch 450, Loss:  0.127189, Epoch: 1
# Batch 452, Loss:  0.127655, Epoch: 1
# Batch 454, Loss:  0.127971, Epoch: 1
# Batch 456, Loss:  0.128293, Epoch: 1
# Batch 458, Loss:  0.128682, Epoch: 1
# Batch 460, Loss:  0.128936, Epoch: 1
# Batch 462, Loss:  0.129299, Epoch: 1
# Batch 464, Loss:  0.129594, Epoch: 1
# Batch 466, Loss:  0.129940, Epoch: 1
# Batch 468, Loss:  0.130319, Epoch: 1
# Batch 470, Loss:  0.130665, Epoch: 1
# Batch 472, Loss:  0.131014, Epoch: 1
# Batch 474, Loss:  0.131359, Epoch: 1
# Batch 476, Loss:  0.131710, Epoch: 1
# Batch 478, Loss:  0.131996, Epoch: 1
# Batch 480, Loss:  0.132360, Epoch: 1
# Batch 482, Loss:  0.132746, Epoch: 1
# Batch 484, Loss:  0.133085, Epoch: 1
# Batch 486, Loss:  0.133428, Epoch: 1
# Batch 488, Loss:  0.133720, Epoch: 1
# Batch 490, Loss:  0.134027, Epoch: 1
# Batch 492, Loss:  0.134437, Epoch: 1
# Batch 494, Loss:  0.134756, Epoch: 1
# Batch 496, Loss:  0.134992, Epoch: 1
# Batch 498, Loss:  0.135333, Epoch: 1
# Batch 500, Loss:  0.135616, Epoch: 1
# Batch 502, Loss:  0.135989, Epoch: 1
# Batch 504, Loss:  0.136300, Epoch: 1
# Batch 506, Loss:  0.136628, Epoch: 1
# Batch 508, Loss:  0.136990, Epoch: 1
# Batch 510, Loss:  0.137271, Epoch: 1
# Batch 512, Loss:  0.137677, Epoch: 1
# Batch 514, Loss:  0.138096, Epoch: 1
# Batch 516, Loss:  0.138465, Epoch: 1
# Batch 518, Loss:  0.138988, Epoch: 1
# Batch 520, Loss:  0.139341, Epoch: 1
# Batch 522, Loss:  0.139755, Epoch: 1
# Batch 524, Loss:  0.140169, Epoch: 1
# Batch 526, Loss:  0.140545, Epoch: 1
# Batch 528, Loss:  0.140869, Epoch: 1
# Batch 530, Loss:  0.141208, Epoch: 1
# Batch 532, Loss:  0.141534, Epoch: 1
# Batch 534, Loss:  0.141868, Epoch: 1
# Batch 536, Loss:  0.142174, Epoch: 1
# Batch 538, Loss:  0.142440, Epoch: 1
# Batch 540, Loss:  0.142793, Epoch: 1
# Batch 542, Loss:  0.143241, Epoch: 1
# Batch 544, Loss:  0.143719, Epoch: 1
# Batch 546, Loss:  0.144124, Epoch: 1
# Batch 548, Loss:  0.144509, Epoch: 1
# Batch 550, Loss:  0.144993, Epoch: 1
# Batch 552, Loss:  0.145384, Epoch: 1
# Batch 554, Loss:  0.145851, Epoch: 1
# Batch 556, Loss:  0.146395, Epoch: 1
# Batch 558, Loss:  0.146833, Epoch: 1
# Batch 560, Loss:  0.147232, Epoch: 1
# Batch 562, Loss:  0.147559, Epoch: 1
# Batch 564, Loss:  0.147960, Epoch: 1
# Batch 566, Loss:  0.148216, Epoch: 1
# Batch 568, Loss:  0.148497, Epoch: 1
# Batch 570, Loss:  0.148834, Epoch: 1
# Batch 572, Loss:  0.149140, Epoch: 1
# Batch 574, Loss:  0.149449, Epoch: 1
# Batch 576, Loss:  0.149716, Epoch: 1
# Batch 578, Loss:  0.149958, Epoch: 1
# Batch 580, Loss:  0.150288, Epoch: 1
# Batch 582, Loss:  0.150681, Epoch: 1
# Batch 584, Loss:  0.150949, Epoch: 1
# Batch 586, Loss:  0.151278, Epoch: 1
# Batch 588, Loss:  0.151698, Epoch: 1
# Batch 590, Loss:  0.152095, Epoch: 1
# Batch 592, Loss:  0.152388, Epoch: 1
# Batch 594, Loss:  0.152748, Epoch: 1
# Batch 596, Loss:  0.153051, Epoch: 1
# Batch 598, Loss:  0.153329, Epoch: 1
# Batch 600, Loss:  0.153683, Epoch: 1
# Batch 602, Loss:  0.154004, Epoch: 1
# Batch 604, Loss:  0.154315, Epoch: 1
# Batch 606, Loss:  0.154735, Epoch: 1
# Batch 608, Loss:  0.155040, Epoch: 1
# Batch 610, Loss:  0.155309, Epoch: 1
# Batch 612, Loss:  0.155656, Epoch: 1
# Batch 614, Loss:  0.155992, Epoch: 1
# Batch 616, Loss:  0.156369, Epoch: 1
# Batch 618, Loss:  0.156725, Epoch: 1
# Batch 620, Loss:  0.157065, Epoch: 1
# Batch 622, Loss:  0.157422, Epoch: 1
# Batch 624, Loss:  0.157660, Epoch: 1
# Batch 626, Loss:  0.157953, Epoch: 1
# Batch 628, Loss:  0.158344, Epoch: 1
# Batch 630, Loss:  0.158726, Epoch: 1
# Batch 632, Loss:  0.159031, Epoch: 1
# Batch 634, Loss:  0.159295, Epoch: 1
# Batch 636, Loss:  0.159604, Epoch: 1
# Batch 638, Loss:  0.159854, Epoch: 1
# Batch 640, Loss:  0.160198, Epoch: 1
# Batch 642, Loss:  0.160495, Epoch: 1
# Batch 644, Loss:  0.160888, Epoch: 1
# Batch 646, Loss:  0.161251, Epoch: 1
# Batch 648, Loss:  0.161537, Epoch: 1
# Batch 650, Loss:  0.161904, Epoch: 1
# Batch 652, Loss:  0.162207, Epoch: 1
# Batch 654, Loss:  0.162464, Epoch: 1
# Batch 656, Loss:  0.162759, Epoch: 1
# Batch 658, Loss:  0.163199, Epoch: 1
# Batch 660, Loss:  0.163543, Epoch: 1
# Batch 662, Loss:  0.163857, Epoch: 1
# Batch 664, Loss:  0.164241, Epoch: 1
# Batch 666, Loss:  0.164613, Epoch: 1
# Batch 668, Loss:  0.164892, Epoch: 1
# Batch 670, Loss:  0.165169, Epoch: 1
# Batch 672, Loss:  0.165507, Epoch: 1
# Batch 674, Loss:  0.165747, Epoch: 1
# Batch 676, Loss:  0.166049, Epoch: 1
# Batch 678, Loss:  0.166331, Epoch: 1
# Batch 680, Loss:  0.166639, Epoch: 1
# Batch 682, Loss:  0.166859, Epoch: 1
# Batch 684, Loss:  0.167202, Epoch: 1
# Batch 686, Loss:  0.167556, Epoch: 1
# Batch 688, Loss:  0.167873, Epoch: 1
# Batch 690, Loss:  0.168178, Epoch: 1
# Batch 692, Loss:  0.168535, Epoch: 1
# Batch 694, Loss:  0.168826, Epoch: 1
# Batch 696, Loss:  0.169164, Epoch: 1
# Batch 698, Loss:  0.169494, Epoch: 1
# Batch 700, Loss:  0.169724, Epoch: 1
# Batch 702, Loss:  0.170064, Epoch: 1
# Batch 704, Loss:  0.170278, Epoch: 1
# Batch 706, Loss:  0.170667, Epoch: 1
# Batch 708, Loss:  0.170948, Epoch: 1
# Batch 710, Loss:  0.171249, Epoch: 1
# Batch 712, Loss:  0.171601, Epoch: 1
# Batch 714, Loss:  0.171867, Epoch: 1
# Batch 716, Loss:  0.172210, Epoch: 1
# Batch 718, Loss:  0.172501, Epoch: 1
# Batch 720, Loss:  0.172789, Epoch: 1
# Batch 722, Loss:  0.173216, Epoch: 1
# Batch 724, Loss:  0.173472, Epoch: 1
# Batch 726, Loss:  0.173746, Epoch: 1
# Batch 728, Loss:  0.174025, Epoch: 1
# Batch 730, Loss:  0.174303, Epoch: 1
# Batch 732, Loss:  0.174642, Epoch: 1
# Batch 734, Loss:  0.174931, Epoch: 1
# Batch 736, Loss:  0.175245, Epoch: 1
# Batch 738, Loss:  0.175557, Epoch: 1
# Batch 740, Loss:  0.175811, Epoch: 1
# Batch 742, Loss:  0.176197, Epoch: 1
# Batch 744, Loss:  0.176448, Epoch: 1
# Batch 746, Loss:  0.176753, Epoch: 1
# Batch 748, Loss:  0.177127, Epoch: 1
# Batch 750, Loss:  0.177414, Epoch: 1
# Batch 752, Loss:  0.177769, Epoch: 1
# Batch 754, Loss:  0.178118, Epoch: 1
# Batch 756, Loss:  0.178395, Epoch: 1
# Batch 758, Loss:  0.178715, Epoch: 1
# Batch 760, Loss:  0.178985, Epoch: 1
# Batch 762, Loss:  0.179258, Epoch: 1
# Batch 764, Loss:  0.179598, Epoch: 1
# Batch 766, Loss:  0.179860, Epoch: 1
# Batch 768, Loss:  0.180102, Epoch: 1
# Batch 770, Loss:  0.180380, Epoch: 1
# Batch 772, Loss:  0.180658, Epoch: 1
# Batch 774, Loss:  0.180956, Epoch: 1
# Batch 776, Loss:  0.181236, Epoch: 1
# Batch 778, Loss:  0.181546, Epoch: 1
# Batch 780, Loss:  0.181810, Epoch: 1
# Batch 782, Loss:  0.182122, Epoch: 1
# Batch 784, Loss:  0.182384, Epoch: 1
# Batch 786, Loss:  0.182662, Epoch: 1
# Batch 788, Loss:  0.182976, Epoch: 1
# Batch 790, Loss:  0.183296, Epoch: 1
# Batch 792, Loss:  0.183615, Epoch: 1
# Batch 794, Loss:  0.183912, Epoch: 1
# Batch 796, Loss:  0.184207, Epoch: 1
# Batch 798, Loss:  0.184491, Epoch: 1
# Batch 800, Loss:  0.184769, Epoch: 1
# Batch 802, Loss:  0.185015, Epoch: 1
# Batch 804, Loss:  0.185336, Epoch: 1
# Batch 806, Loss:  0.185621, Epoch: 1
# Batch 808, Loss:  0.185870, Epoch: 1
# Batch 810, Loss:  0.186136, Epoch: 1
# Batch 812, Loss:  0.186398, Epoch: 1
# Batch 814, Loss:  0.186655, Epoch: 1
# Batch 816, Loss:  0.186929, Epoch: 1
# Batch 818, Loss:  0.187183, Epoch: 1
# Batch 820, Loss:  0.187495, Epoch: 1
# Batch 822, Loss:  0.187735, Epoch: 1
# Batch 824, Loss:  0.188072, Epoch: 1
# Batch 826, Loss:  0.188413, Epoch: 1
# Batch 828, Loss:  0.188714, Epoch: 1
# Batch 830, Loss:  0.188953, Epoch: 1
# Batch 832, Loss:  0.189357, Epoch: 1
# Batch 834, Loss:  0.189578, Epoch: 1
# Batch 836, Loss:  0.189855, Epoch: 1
# Batch 838, Loss:  0.190093, Epoch: 1
# Batch 840, Loss:  0.190400, Epoch: 1
# Batch 842, Loss:  0.190660, Epoch: 1
# Batch 844, Loss:  0.190934, Epoch: 1
# Batch 846, Loss:  0.191298, Epoch: 1
# Batch 848, Loss:  0.191549, Epoch: 1
# Batch 850, Loss:  0.191802, Epoch: 1
# Batch 852, Loss:  0.192055, Epoch: 1
# Batch 854, Loss:  0.192320, Epoch: 1
# Batch 856, Loss:  0.192504, Epoch: 1
# Batch 858, Loss:  0.192774, Epoch: 1
# Batch 860, Loss:  0.193042, Epoch: 1
# Batch 862, Loss:  0.193359, Epoch: 1
# Batch 864, Loss:  0.193575, Epoch: 1
# Batch 866, Loss:  0.193841, Epoch: 1
# Batch 868, Loss:  0.194206, Epoch: 1
# Batch 870, Loss:  0.194510, Epoch: 1
# Batch 872, Loss:  0.194794, Epoch: 1
# Batch 874, Loss:  0.195073, Epoch: 1
# Batch 876, Loss:  0.195504, Epoch: 1
# Batch 878, Loss:  0.195783, Epoch: 1
# Batch 880, Loss:  0.196063, Epoch: 1
# Batch 882, Loss:  0.196278, Epoch: 1
# Batch 884, Loss:  0.196535, Epoch: 1
# Batch 886, Loss:  0.196801, Epoch: 1
# Batch 888, Loss:  0.197052, Epoch: 1
# Batch 890, Loss:  0.197334, Epoch: 1
# Batch 892, Loss:  0.197569, Epoch: 1
# Batch 894, Loss:  0.197826, Epoch: 1
# Batch 896, Loss:  0.198051, Epoch: 1
# Batch 898, Loss:  0.198314, Epoch: 1
# Batch 900, Loss:  0.198526, Epoch: 1
# Batch 902, Loss:  0.198758, Epoch: 1
# Batch 904, Loss:  0.199002, Epoch: 1
# Batch 906, Loss:  0.199238, Epoch: 1
# Batch 908, Loss:  0.199449, Epoch: 1
# Batch 910, Loss:  0.199655, Epoch: 1
# Batch 912, Loss:  0.199881, Epoch: 1
# Batch 914, Loss:  0.200145, Epoch: 1
# Batch 916, Loss:  0.200388, Epoch: 1
# Batch 918, Loss:  0.200616, Epoch: 1
# Batch 920, Loss:  0.200813, Epoch: 1
# Batch 922, Loss:  0.200991, Epoch: 1
# Batch 924, Loss:  0.201159, Epoch: 1
# Batch 926, Loss:  0.201331, Epoch: 1
# Batch 928, Loss:  0.201550, Epoch: 1
# Batch 930, Loss:  0.201715, Epoch: 1
# Batch 932, Loss:  0.201934, Epoch: 1
# Batch 934, Loss:  0.202156, Epoch: 1
# Batch 936, Loss:  0.202412, Epoch: 1
# Batch 938, Loss:  0.202757, Epoch: 1
# Batch 940, Loss:  0.202995, Epoch: 1
# Batch 942, Loss:  0.203331, Epoch: 1
# Batch 944, Loss:  0.203599, Epoch: 1
# Batch 946, Loss:  0.203992, Epoch: 1
# Batch 948, Loss:  0.204242, Epoch: 1
# Batch 950, Loss:  0.204485, Epoch: 1
# Batch 952, Loss:  0.204746, Epoch: 1
# Batch 954, Loss:  0.205033, Epoch: 1
# Batch 956, Loss:  0.205333, Epoch: 1
# Batch 958, Loss:  0.205596, Epoch: 1
# Batch 960, Loss:  0.206042, Epoch: 1
# Batch 962, Loss:  0.206429, Epoch: 1
# Batch 964, Loss:  0.206800, Epoch: 1
# Batch 966, Loss:  0.207078, Epoch: 1
# Batch 968, Loss:  0.207431, Epoch: 1
# Batch 970, Loss:  0.207766, Epoch: 1
# Batch 972, Loss:  0.208016, Epoch: 1
# Batch 974, Loss:  0.208291, Epoch: 1
# Batch 976, Loss:  0.208514, Epoch: 1
# Batch 978, Loss:  0.208761, Epoch: 1
# Batch 980, Loss:  0.208982, Epoch: 1
# Batch 982, Loss:  0.209236, Epoch: 1
# Batch 984, Loss:  0.209452, Epoch: 1
# Batch 986, Loss:  0.209706, Epoch: 1
# Batch 988, Loss:  0.209998, Epoch: 1
# Batch 990, Loss:  0.210231, Epoch: 1
# Batch 992, Loss:  0.210485, Epoch: 1
# Batch 994, Loss:  0.210727, Epoch: 1
# Batch 996, Loss:  0.210987, Epoch: 1
# Batch 998, Loss:  0.211224, Epoch: 1
# Batch 1000, Loss:  0.211490, Epoch: 1
# Batch 1002, Loss:  0.211723, Epoch: 1
# Batch 1004, Loss:  0.211955, Epoch: 1
# Batch 1006, Loss:  0.212194, Epoch: 1
# Batch 1008, Loss:  0.212413, Epoch: 1
# Batch 1010, Loss:  0.212597, Epoch: 1
# Batch 1012, Loss:  0.212837, Epoch: 1
# Batch 1014, Loss:  0.213059, Epoch: 1
# Batch 1016, Loss:  0.213256, Epoch: 1
# Batch 1018, Loss:  0.213486, Epoch: 1
# Batch 1020, Loss:  0.213684, Epoch: 1
# Batch 1022, Loss:  0.213979, Epoch: 1
# Batch 1024, Loss:  0.214214, Epoch: 1
# Batch 1026, Loss:  0.214436, Epoch: 1
# Batch 1028, Loss:  0.214675, Epoch: 1
# Batch 1030, Loss:  0.214905, Epoch: 1
# Batch 1032, Loss:  0.215124, Epoch: 1
# Batch 1034, Loss:  0.215382, Epoch: 1
# Batch 1036, Loss:  0.215620, Epoch: 1
# Batch 1038, Loss:  0.215861, Epoch: 1
# Batch 1040, Loss:  0.216115, Epoch: 1
# Batch 1042, Loss:  0.216333, Epoch: 1
# Batch 1044, Loss:  0.216563, Epoch: 1
# Batch 1046, Loss:  0.216863, Epoch: 1
# Batch 1048, Loss:  0.217164, Epoch: 1
# Batch 1050, Loss:  0.217411, Epoch: 1
# Batch 1052, Loss:  0.217685, Epoch: 1
# Batch 1054, Loss:  0.217914, Epoch: 1
# Batch 1056, Loss:  0.218164, Epoch: 1
# Batch 1058, Loss:  0.218358, Epoch: 1
# Batch 1060, Loss:  0.218521, Epoch: 1
# Batch 1062, Loss:  0.218711, Epoch: 1
# Batch 1064, Loss:  0.218937, Epoch: 1
# Batch 1066, Loss:  0.219126, Epoch: 1
# Batch 1068, Loss:  0.219298, Epoch: 1
# Batch 1070, Loss:  0.219479, Epoch: 1
# Batch 1072, Loss:  0.219693, Epoch: 1
# Batch 1074, Loss:  0.219927, Epoch: 1
# Batch 1076, Loss:  0.220146, Epoch: 1
# Batch 1078, Loss:  0.220360, Epoch: 1
# Batch 1080, Loss:  0.220556, Epoch: 1
# Batch 1082, Loss:  0.220727, Epoch: 1
# Batch 1084, Loss:  0.220901, Epoch: 1
# Batch 1086, Loss:  0.221097, Epoch: 1
# Batch 1088, Loss:  0.221264, Epoch: 1
# Batch 1090, Loss:  0.221446, Epoch: 1
# Batch 1092, Loss:  0.221598, Epoch: 1
# Batch 1094, Loss:  0.221807, Epoch: 1
# Batch 1096, Loss:  0.221980, Epoch: 1
# Batch 1098, Loss:  0.222157, Epoch: 1
# Batch 1100, Loss:  0.222396, Epoch: 1
# Batch 1102, Loss:  0.222630, Epoch: 1
# Batch 1104, Loss:  0.222836, Epoch: 1
# Batch 1106, Loss:  0.222994, Epoch: 1
# Batch 1108, Loss:  0.223189, Epoch: 1
# Batch 1110, Loss:  0.223388, Epoch: 1
# Batch 1112, Loss:  0.223559, Epoch: 1
# Batch 1114, Loss:  0.223777, Epoch: 1
# Batch 1116, Loss:  0.223991, Epoch: 1
# Batch 1118, Loss:  0.224205, Epoch: 1
# Batch 1120, Loss:  0.224458, Epoch: 1
# Batch 1122, Loss:  0.224671, Epoch: 1
# Batch 1124, Loss:  0.224833, Epoch: 1
# Batch 1126, Loss:  0.224982, Epoch: 1
# Batch 1128, Loss:  0.225188, Epoch: 1
# Batch 1130, Loss:  0.225358, Epoch: 1
# Batch 1132, Loss:  0.225589, Epoch: 1
# Batch 1134, Loss:  0.225723, Epoch: 1
# Batch 1136, Loss:  0.225932, Epoch: 1
# Batch 1138, Loss:  0.226141, Epoch: 1
# Batch 1140, Loss:  0.226334, Epoch: 1
# Batch 1142, Loss:  0.226520, Epoch: 1
# Batch 1144, Loss:  0.226775, Epoch: 1
# Batch 1146, Loss:  0.226964, Epoch: 1
# Batch 1148, Loss:  0.227181, Epoch: 1
# Batch 1150, Loss:  0.227377, Epoch: 1
# Batch 1152, Loss:  0.227571, Epoch: 1
# Batch 1154, Loss:  0.227743, Epoch: 1
# Batch 1156, Loss:  0.227924, Epoch: 1
# Batch 1158, Loss:  0.228070, Epoch: 1
# Batch 1160, Loss:  0.228266, Epoch: 1
# Batch 1162, Loss:  0.228483, Epoch: 1
# Batch 1164, Loss:  0.228647, Epoch: 1
# Batch 1166, Loss:  0.228829, Epoch: 1
# Batch 1168, Loss:  0.228988, Epoch: 1
# Batch 1170, Loss:  0.229122, Epoch: 1
# Batch 1172, Loss:  0.229329, Epoch: 1
# Batch 1174, Loss:  0.229535, Epoch: 1
# Batch 1176, Loss:  0.229726, Epoch: 1
# Batch 1178, Loss:  0.229909, Epoch: 1
# Batch 1180, Loss:  0.230079, Epoch: 1
# Batch 1182, Loss:  0.230271, Epoch: 1
# Batch 1184, Loss:  0.230457, Epoch: 1
# Batch 1186, Loss:  0.230613, Epoch: 1
# Batch 1188, Loss:  0.230822, Epoch: 1
# Batch 1190, Loss:  0.231038, Epoch: 1
# Batch 1192, Loss:  0.231242, Epoch: 1
# Batch 1194, Loss:  0.231466, Epoch: 1
# Batch 1196, Loss:  0.231641, Epoch: 1
# Batch 1198, Loss:  0.231842, Epoch: 1
# Batch 1200, Loss:  0.232008, Epoch: 1
# Batch 1202, Loss:  0.232165, Epoch: 1
# Batch 1204, Loss:  0.232371, Epoch: 1
# Batch 1206, Loss:  0.232538, Epoch: 1
# Batch 1208, Loss:  0.232748, Epoch: 1
# Batch 1210, Loss:  0.232935, Epoch: 1
# Batch 1212, Loss:  0.233126, Epoch: 1
# Batch 1214, Loss:  0.233304, Epoch: 1
# Batch 1216, Loss:  0.233482, Epoch: 1
# Batch 1218, Loss:  0.233680, Epoch: 1
# Batch 1220, Loss:  0.233837, Epoch: 1
# Batch 1222, Loss:  0.234003, Epoch: 1
# Batch 1224, Loss:  0.234137, Epoch: 1
# Batch 1226, Loss:  0.234313, Epoch: 1
# Batch 1228, Loss:  0.234500, Epoch: 1
# Batch 1230, Loss:  0.234715, Epoch: 1
# Batch 1232, Loss:  0.234821, Epoch: 1
# Batch 1234, Loss:  0.234999, Epoch: 1
# Batch 1236, Loss:  0.235174, Epoch: 1
# Batch 1238, Loss:  0.235374, Epoch: 1
# Batch 1240, Loss:  0.235537, Epoch: 1
# Batch 1242, Loss:  0.235675, Epoch: 1
# Batch 1244, Loss:  0.235845, Epoch: 1
# Batch 1246, Loss:  0.236066, Epoch: 1
# Batch 1248, Loss:  0.236253, Epoch: 1
# Batch 1250, Loss:  0.236431, Epoch: 1
# Batch 1252, Loss:  0.236606, Epoch: 1
# Batch 1254, Loss:  0.236747, Epoch: 1
# Batch 1256, Loss:  0.236938, Epoch: 1
# Batch 1258, Loss:  0.237064, Epoch: 1
# Batch 1260, Loss:  0.237209, Epoch: 1
# Batch 1262, Loss:  0.237399, Epoch: 1
# Batch 1264, Loss:  0.237523, Epoch: 1
# Batch 1266, Loss:  0.237695, Epoch: 1
# Batch 1268, Loss:  0.237856, Epoch: 1
# Batch 1270, Loss:  0.238012, Epoch: 1
# Batch 1272, Loss:  0.238186, Epoch: 1
# Batch 1274, Loss:  0.238351, Epoch: 1
# Batch 1276, Loss:  0.238484, Epoch: 1
# Batch 1278, Loss:  0.238671, Epoch: 1
# Batch 1280, Loss:  0.238849, Epoch: 1
# Batch 1282, Loss:  0.238999, Epoch: 1
# Batch 1284, Loss:  0.239190, Epoch: 1
# Batch 1286, Loss:  0.239344, Epoch: 1
# Batch 1288, Loss:  0.239531, Epoch: 1
# Batch 1290, Loss:  0.239668, Epoch: 1
# Batch 1292, Loss:  0.239866, Epoch: 1
# Batch 1294, Loss:  0.240022, Epoch: 1
# Batch 1296, Loss:  0.240156, Epoch: 1
# Batch 1298, Loss:  0.240360, Epoch: 1
# Batch 1300, Loss:  0.240485, Epoch: 1
# Batch 1302, Loss:  0.240644, Epoch: 1
# Batch 1304, Loss:  0.240817, Epoch: 1
# Batch 1306, Loss:  0.240984, Epoch: 1
# Batch 1308, Loss:  0.241110, Epoch: 1
# Batch 1310, Loss:  0.241255, Epoch: 1
# Batch 1312, Loss:  0.241386, Epoch: 1
# Batch 1314, Loss:  0.241598, Epoch: 1
# Batch 1316, Loss:  0.241777, Epoch: 1
# Batch 1318, Loss:  0.241896, Epoch: 1
# Batch 1320, Loss:  0.242052, Epoch: 1
# Batch 1322, Loss:  0.242209, Epoch: 1
# Batch 1324, Loss:  0.242402, Epoch: 1
# Batch 1326, Loss:  0.242573, Epoch: 1
# Batch 1328, Loss:  0.242716, Epoch: 1
# Batch 1330, Loss:  0.242880, Epoch: 1
# Batch 1332, Loss:  0.242998, Epoch: 1
# Batch 1334, Loss:  0.243130, Epoch: 1
# Batch 1336, Loss:  0.243302, Epoch: 1
# Batch 1338, Loss:  0.243443, Epoch: 1
# Batch 1340, Loss:  0.243583, Epoch: 1
# Batch 1342, Loss:  0.243716, Epoch: 1
# Batch 1344, Loss:  0.243901, Epoch: 1
# Batch 1346, Loss:  0.244067, Epoch: 1
# Batch 1348, Loss:  0.244201, Epoch: 1
# Batch 1350, Loss:  0.244342, Epoch: 1
# Batch 1352, Loss:  0.244516, Epoch: 1
# Batch 1354, Loss:  0.244716, Epoch: 1
# Batch 1356, Loss:  0.244945, Epoch: 1
# Batch 1358, Loss:  0.245127, Epoch: 1
# Batch 1360, Loss:  0.245313, Epoch: 1
# Batch 1362, Loss:  0.245461, Epoch: 1
# Batch 1364, Loss:  0.245595, Epoch: 1
# Batch 1366, Loss:  0.245755, Epoch: 1
# Batch 1368, Loss:  0.245887, Epoch: 1
# Batch 1370, Loss:  0.246108, Epoch: 1
# Batch 1372, Loss:  0.246270, Epoch: 1
# Batch 1374, Loss:  0.246397, Epoch: 1
# Batch 1376, Loss:  0.246542, Epoch: 1
# Batch 1378, Loss:  0.246693, Epoch: 1
# Batch 1380, Loss:  0.246818, Epoch: 1
# Batch 1382, Loss:  0.246991, Epoch: 1
# Batch 1384, Loss:  0.247124, Epoch: 1
# Batch 1386, Loss:  0.247280, Epoch: 1
# Batch 1388, Loss:  0.247438, Epoch: 1
# Batch 1390, Loss:  0.247567, Epoch: 1
# Batch 1392, Loss:  0.247694, Epoch: 1
# Batch 1394, Loss:  0.247792, Epoch: 1
# Batch 1396, Loss:  0.247916, Epoch: 1
# Batch 1398, Loss:  0.248031, Epoch: 1
# Batch 1400, Loss:  0.248155, Epoch: 1
# Batch 1402, Loss:  0.248304, Epoch: 1
# Batch 1404, Loss:  0.248463, Epoch: 1
# Batch 1406, Loss:  0.248611, Epoch: 1
# Batch 1408, Loss:  0.248800, Epoch: 1
# Batch 1410, Loss:  0.248922, Epoch: 1
# Batch 1412, Loss:  0.249095, Epoch: 1
# Batch 1414, Loss:  0.249220, Epoch: 1
# Batch 1416, Loss:  0.249398, Epoch: 1
# Batch 1418, Loss:  0.249554, Epoch: 1
# Batch 1420, Loss:  0.249674, Epoch: 1
# Batch 1422, Loss:  0.249831, Epoch: 1
# Batch 1424, Loss:  0.250002, Epoch: 1
# Batch 1426, Loss:  0.250171, Epoch: 1
# Batch 1428, Loss:  0.250323, Epoch: 1
# Batch 1430, Loss:  0.250449, Epoch: 1
# Batch 1432, Loss:  0.250645, Epoch: 1
# Batch 1434, Loss:  0.250802, Epoch: 1
# Batch 1436, Loss:  0.250942, Epoch: 1
# Batch 1438, Loss:  0.251091, Epoch: 1
# Batch 1440, Loss:  0.251299, Epoch: 1
# Batch 1442, Loss:  0.251456, Epoch: 1
# Batch 1444, Loss:  0.251587, Epoch: 1
# Batch 1446, Loss:  0.251792, Epoch: 1
# Batch 1448, Loss:  0.251943, Epoch: 1
# Batch 1450, Loss:  0.252091, Epoch: 1
# Batch 1452, Loss:  0.252243, Epoch: 1
# Batch 1454, Loss:  0.252360, Epoch: 1
# Batch 1456, Loss:  0.252547, Epoch: 1
# Batch 1458, Loss:  0.252725, Epoch: 1
# Batch 1460, Loss:  0.252894, Epoch: 1
# Batch 1462, Loss:  0.253082, Epoch: 1
# Batch 1464, Loss:  0.253212, Epoch: 1
# Batch 1466, Loss:  0.253392, Epoch: 1
# Batch 1468, Loss:  0.253588, Epoch: 1
# Batch 1470, Loss:  0.253739, Epoch: 1
# Batch 1472, Loss:  0.253952, Epoch: 1
# Batch 1474, Loss:  0.254106, Epoch: 1
# Batch 1476, Loss:  0.254294, Epoch: 1
# Batch 1478, Loss:  0.254473, Epoch: 1
# Batch 1480, Loss:  0.254654, Epoch: 1
# Batch 1482, Loss:  0.254835, Epoch: 1
# Batch 1484, Loss:  0.254960, Epoch: 1
# Batch 1486, Loss:  0.255100, Epoch: 1
# Batch 1488, Loss:  0.255287, Epoch: 1
# Batch 1490, Loss:  0.255476, Epoch: 1
# Batch 1492, Loss:  0.255592, Epoch: 1
# Batch 1494, Loss:  0.255756, Epoch: 1
# Batch 1496, Loss:  0.255960, Epoch: 1
# Batch 1498, Loss:  0.256151, Epoch: 1
# Batch 1500, Loss:  0.256293, Epoch: 1
# Batch 1502, Loss:  0.256562, Epoch: 1
# Batch 1504, Loss:  0.256750, Epoch: 1
# Batch 1506, Loss:  0.256996, Epoch: 1
# Batch 1508, Loss:  0.257185, Epoch: 1
# Batch 1510, Loss:  0.257355, Epoch: 1
# Batch 1512, Loss:  0.257545, Epoch: 1
# Batch 1514, Loss:  0.257704, Epoch: 1
# Batch 1516, Loss:  0.257870, Epoch: 1
# Batch 1518, Loss:  0.258036, Epoch: 1
# Batch 1520, Loss:  0.258172, Epoch: 1
# Batch 1522, Loss:  0.258320, Epoch: 1
# Batch 1524, Loss:  0.258460, Epoch: 1
# Batch 1526, Loss:  0.258626, Epoch: 1
# Batch 1528, Loss:  0.258792, Epoch: 1
# Batch 1530, Loss:  0.258980, Epoch: 1
# Batch 1532, Loss:  0.259110, Epoch: 1
# Batch 1534, Loss:  0.259300, Epoch: 1
# Batch 1536, Loss:  0.259450, Epoch: 1
# Batch 1538, Loss:  0.259625, Epoch: 1
# Batch 1540, Loss:  0.259787, Epoch: 1
# Batch 1542, Loss:  0.259984, Epoch: 1
# Batch 1544, Loss:  0.260189, Epoch: 1
# Batch 1546, Loss:  0.260378, Epoch: 1
# Batch 1548, Loss:  0.260519, Epoch: 1
# Batch 1550, Loss:  0.260706, Epoch: 1
# Batch 1552, Loss:  0.260838, Epoch: 1
# Batch 1554, Loss:  0.261030, Epoch: 1
# Batch 1556, Loss:  0.261165, Epoch: 1
# Batch 1558, Loss:  0.261341, Epoch: 1
# Batch 1560, Loss:  0.261482, Epoch: 1
# Batch 1562, Loss:  0.261616, Epoch: 1
# Batch 1564, Loss:  0.261778, Epoch: 1
# Batch 1566, Loss:  0.261903, Epoch: 1
# Batch 1568, Loss:  0.262063, Epoch: 1
# Batch 1570, Loss:  0.262207, Epoch: 1
# Batch 1572, Loss:  0.262365, Epoch: 1
# Batch 1574, Loss:  0.262567, Epoch: 1
# Batch 1576, Loss:  0.262683, Epoch: 1
# Batch 1578, Loss:  0.262810, Epoch: 1
# Batch 1580, Loss:  0.262973, Epoch: 1
# Batch 1582, Loss:  0.263122, Epoch: 1
# Batch 1584, Loss:  0.263241, Epoch: 1
# Batch 1586, Loss:  0.263375, Epoch: 1
# Batch 1588, Loss:  0.263526, Epoch: 1
# Batch 1590, Loss:  0.263674, Epoch: 1
# Batch 1592, Loss:  0.263772, Epoch: 1
# Batch 1594, Loss:  0.263934, Epoch: 1
# Batch 1596, Loss:  0.264080, Epoch: 1
# Batch 1598, Loss:  0.264207, Epoch: 1
# Batch 1600, Loss:  0.264407, Epoch: 1
# Batch 1602, Loss:  0.264532, Epoch: 1
# Batch 1604, Loss:  0.264698, Epoch: 1
# Batch 1606, Loss:  0.264836, Epoch: 1
# Batch 1608, Loss:  0.264995, Epoch: 1
# Batch 1610, Loss:  0.265152, Epoch: 1
# Batch 1612, Loss:  0.265299, Epoch: 1
# Batch 1614, Loss:  0.265442, Epoch: 1
# Batch 1616, Loss:  0.265580, Epoch: 1
# Batch 1618, Loss:  0.265733, Epoch: 1
# Batch 1620, Loss:  0.265917, Epoch: 1
# Batch 1622, Loss:  0.266060, Epoch: 1
# Batch 1624, Loss:  0.266201, Epoch: 1
# Batch 1626, Loss:  0.266377, Epoch: 1
# Batch 1628, Loss:  0.266531, Epoch: 1
# Batch 1630, Loss:  0.266656, Epoch: 1
# Batch 1632, Loss:  0.266805, Epoch: 1
# Batch 1634, Loss:  0.266924, Epoch: 1
# Batch 1636, Loss:  0.267075, Epoch: 1
# Batch 1638, Loss:  0.267233, Epoch: 1
# Batch 1640, Loss:  0.267402, Epoch: 1
# Batch 1642, Loss:  0.267536, Epoch: 1
# Batch 1644, Loss:  0.267650, Epoch: 1
# Batch 1646, Loss:  0.267779, Epoch: 1
# Batch 1648, Loss:  0.267906, Epoch: 1
# Batch 1650, Loss:  0.268059, Epoch: 1
# Batch 1652, Loss:  0.268218, Epoch: 1
# Batch 1654, Loss:  0.268375, Epoch: 1
# Batch 1656, Loss:  0.268503, Epoch: 1
# Batch 1658, Loss:  0.268647, Epoch: 1
# Batch 1660, Loss:  0.268752, Epoch: 1
# Batch 1662, Loss:  0.268908, Epoch: 1
# Batch 1664, Loss:  0.269039, Epoch: 1
# Batch 1666, Loss:  0.269134, Epoch: 1
# Batch 1668, Loss:  0.269249, Epoch: 1
# Batch 1670, Loss:  0.269384, Epoch: 1
# Batch 1672, Loss:  0.269548, Epoch: 1
# Batch 1674, Loss:  0.269651, Epoch: 1
# Batch 1676, Loss:  0.269792, Epoch: 1
# Batch 1678, Loss:  0.269930, Epoch: 1
# Batch 1680, Loss:  0.270075, Epoch: 1
# Batch 1682, Loss:  0.270209, Epoch: 1
# Batch 1684, Loss:  0.270354, Epoch: 1
# Batch 1686, Loss:  0.270481, Epoch: 1
# Batch 1688, Loss:  0.270618, Epoch: 1
# Batch 1690, Loss:  0.270783, Epoch: 1
# Batch 1692, Loss:  0.270959, Epoch: 1
# Batch 1694, Loss:  0.271096, Epoch: 1
# Batch 1696, Loss:  0.271244, Epoch: 1
# Batch 1698, Loss:  0.271400, Epoch: 1
# Batch 1700, Loss:  0.271503, Epoch: 1
# Batch 1702, Loss:  0.271623, Epoch: 1
# Batch 1704, Loss:  0.271765, Epoch: 1
# Batch 1706, Loss:  0.271898, Epoch: 1
# Batch 1708, Loss:  0.272042, Epoch: 1
# Batch 1710, Loss:  0.272190, Epoch: 1
# Batch 1712, Loss:  0.272326, Epoch: 1
# Batch 1714, Loss:  0.272467, Epoch: 1
# Batch 1716, Loss:  0.272664, Epoch: 1
# Batch 1718, Loss:  0.272804, Epoch: 1
# Batch 1720, Loss:  0.272900, Epoch: 1
# Batch 1722, Loss:  0.273006, Epoch: 1
# Batch 1724, Loss:  0.273172, Epoch: 1
# Batch 1726, Loss:  0.273311, Epoch: 1
# Batch 1728, Loss:  0.273469, Epoch: 1
# Batch 1730, Loss:  0.273605, Epoch: 1
# Batch 1732, Loss:  0.273743, Epoch: 1
# Batch 1734, Loss:  0.273865, Epoch: 1
# Batch 1736, Loss:  0.273986, Epoch: 1
# Batch 1738, Loss:  0.274130, Epoch: 1
# Batch 1740, Loss:  0.274264, Epoch: 1
# Batch 1742, Loss:  0.274388, Epoch: 1
# Batch 1744, Loss:  0.274546, Epoch: 1
# Batch 1746, Loss:  0.274659, Epoch: 1
# Batch 1748, Loss:  0.274758, Epoch: 1
# Batch 1750, Loss:  0.274894, Epoch: 1
# Batch 1752, Loss:  0.275032, Epoch: 1
# Batch 1754, Loss:  0.275174, Epoch: 1
# Batch 1756, Loss:  0.275304, Epoch: 1
# Batch 1758, Loss:  0.275460, Epoch: 1
# Batch 1760, Loss:  0.275614, Epoch: 1
# Batch 1762, Loss:  0.275743, Epoch: 1
# Batch 1764, Loss:  0.275920, Epoch: 1
# Batch 1766, Loss:  0.276021, Epoch: 1
# Validation Loss  0.009
# ###################################################
# Epoch: 2
# Batch 2, Loss:  0.000111, Epoch: 2
# Batch 4, Loss:  0.000306, Epoch: 2
# Batch 6, Loss:  0.000411, Epoch: 2
# Batch 8, Loss:  0.000535, Epoch: 2
# Batch 10, Loss:  0.000651, Epoch: 2
# Batch 12, Loss:  0.000809, Epoch: 2
# Batch 14, Loss:  0.000984, Epoch: 2
# Batch 16, Loss:  0.001133, Epoch: 2
# Batch 18, Loss:  0.001287, Epoch: 2
# Batch 20, Loss:  0.001430, Epoch: 2
# Batch 22, Loss:  0.001581, Epoch: 2
# Batch 24, Loss:  0.001720, Epoch: 2
# Batch 26, Loss:  0.001904, Epoch: 2
# Batch 28, Loss:  0.002019, Epoch: 2
# Batch 30, Loss:  0.002158, Epoch: 2
# Batch 32, Loss:  0.002291, Epoch: 2
# Batch 34, Loss:  0.002408, Epoch: 2
# Batch 36, Loss:  0.002505, Epoch: 2
# Batch 38, Loss:  0.002613, Epoch: 2
# Batch 40, Loss:  0.002770, Epoch: 2
# Batch 42, Loss:  0.002940, Epoch: 2
# Batch 44, Loss:  0.003096, Epoch: 2
# Batch 46, Loss:  0.003239, Epoch: 2
# Batch 48, Loss:  0.003383, Epoch: 2
# Batch 50, Loss:  0.003513, Epoch: 2
# Batch 52, Loss:  0.003674, Epoch: 2
# Batch 54, Loss:  0.003834, Epoch: 2
# Batch 56, Loss:  0.003943, Epoch: 2
# Batch 58, Loss:  0.004085, Epoch: 2
# Batch 60, Loss:  0.004252, Epoch: 2
# Batch 62, Loss:  0.004358, Epoch: 2
# Batch 64, Loss:  0.004497, Epoch: 2
# Batch 66, Loss:  0.004641, Epoch: 2
# Batch 68, Loss:  0.004766, Epoch: 2
# Batch 70, Loss:  0.004879, Epoch: 2
# Batch 72, Loss:  0.005021, Epoch: 2
# Batch 74, Loss:  0.005144, Epoch: 2
# Batch 76, Loss:  0.005281, Epoch: 2
# Batch 78, Loss:  0.005430, Epoch: 2
# Batch 80, Loss:  0.005543, Epoch: 2
# Batch 82, Loss:  0.005684, Epoch: 2
# Batch 84, Loss:  0.005808, Epoch: 2
# Batch 86, Loss:  0.005981, Epoch: 2
# Batch 88, Loss:  0.006146, Epoch: 2
# Batch 90, Loss:  0.006269, Epoch: 2
# Batch 92, Loss:  0.006457, Epoch: 2
# Batch 94, Loss:  0.006619, Epoch: 2
# Batch 96, Loss:  0.006777, Epoch: 2
# Batch 98, Loss:  0.006907, Epoch: 2
# Batch 100, Loss:  0.007063, Epoch: 2
# Batch 102, Loss:  0.007216, Epoch: 2
# Batch 104, Loss:  0.007380, Epoch: 2
# Batch 106, Loss:  0.007561, Epoch: 2
# Batch 108, Loss:  0.007715, Epoch: 2
# Batch 110, Loss:  0.007936, Epoch: 2
# Batch 112, Loss:  0.008121, Epoch: 2
# Batch 114, Loss:  0.008306, Epoch: 2
# Batch 116, Loss:  0.008460, Epoch: 2
# Batch 118, Loss:  0.008576, Epoch: 2
# Batch 120, Loss:  0.008737, Epoch: 2
# Batch 122, Loss:  0.008876, Epoch: 2
# Batch 124, Loss:  0.009003, Epoch: 2
# Batch 126, Loss:  0.009130, Epoch: 2
# Batch 128, Loss:  0.009299, Epoch: 2
# Batch 130, Loss:  0.009433, Epoch: 2
# Batch 132, Loss:  0.009586, Epoch: 2
# Batch 134, Loss:  0.009726, Epoch: 2
# Batch 136, Loss:  0.009871, Epoch: 2
# Batch 138, Loss:  0.010046, Epoch: 2
# Batch 140, Loss:  0.010201, Epoch: 2
# Batch 142, Loss:  0.010329, Epoch: 2
# Batch 144, Loss:  0.010433, Epoch: 2
# Batch 146, Loss:  0.010562, Epoch: 2
# Batch 148, Loss:  0.010662, Epoch: 2
# Batch 150, Loss:  0.010800, Epoch: 2
# Batch 152, Loss:  0.010936, Epoch: 2
# Batch 154, Loss:  0.011051, Epoch: 2
# Batch 156, Loss:  0.011174, Epoch: 2
# Batch 158, Loss:  0.011320, Epoch: 2
# Batch 160, Loss:  0.011501, Epoch: 2
# Batch 162, Loss:  0.011631, Epoch: 2
# Batch 164, Loss:  0.011772, Epoch: 2
# Batch 166, Loss:  0.011911, Epoch: 2
# Batch 168, Loss:  0.012091, Epoch: 2
# Batch 170, Loss:  0.012242, Epoch: 2
# Batch 172, Loss:  0.012399, Epoch: 2
# Batch 174, Loss:  0.012535, Epoch: 2
# Batch 176, Loss:  0.012697, Epoch: 2
# Batch 178, Loss:  0.012821, Epoch: 2
# Batch 180, Loss:  0.012965, Epoch: 2
# Batch 182, Loss:  0.013092, Epoch: 2
# Batch 184, Loss:  0.013215, Epoch: 2
# Batch 186, Loss:  0.013347, Epoch: 2
# Batch 188, Loss:  0.013479, Epoch: 2
# Batch 190, Loss:  0.013651, Epoch: 2
# Batch 192, Loss:  0.013808, Epoch: 2
# Batch 194, Loss:  0.013936, Epoch: 2
# Batch 196, Loss:  0.014053, Epoch: 2
# Batch 198, Loss:  0.014225, Epoch: 2
# Batch 200, Loss:  0.014355, Epoch: 2
# Batch 202, Loss:  0.014459, Epoch: 2
# Batch 204, Loss:  0.014609, Epoch: 2
# Batch 206, Loss:  0.014776, Epoch: 2
# Batch 208, Loss:  0.014894, Epoch: 2
# Batch 210, Loss:  0.015056, Epoch: 2
# Batch 212, Loss:  0.015222, Epoch: 2
# Batch 214, Loss:  0.015383, Epoch: 2
# Batch 216, Loss:  0.015491, Epoch: 2
# Batch 218, Loss:  0.015659, Epoch: 2
# Batch 220, Loss:  0.015815, Epoch: 2
# Batch 222, Loss:  0.015967, Epoch: 2
# Batch 224, Loss:  0.016112, Epoch: 2
# Batch 226, Loss:  0.016247, Epoch: 2
# Batch 228, Loss:  0.016390, Epoch: 2
# Batch 230, Loss:  0.016554, Epoch: 2
# Batch 232, Loss:  0.016708, Epoch: 2
# Batch 234, Loss:  0.016851, Epoch: 2
# Batch 236, Loss:  0.016995, Epoch: 2
# Batch 238, Loss:  0.017166, Epoch: 2
# Batch 240, Loss:  0.017267, Epoch: 2
# Batch 242, Loss:  0.017402, Epoch: 2
# Batch 244, Loss:  0.017552, Epoch: 2
# Batch 246, Loss:  0.017724, Epoch: 2
# Batch 248, Loss:  0.017863, Epoch: 2
# Batch 250, Loss:  0.018035, Epoch: 2
# Batch 252, Loss:  0.018165, Epoch: 2
# Batch 254, Loss:  0.018294, Epoch: 2
# Batch 256, Loss:  0.018436, Epoch: 2
# Batch 258, Loss:  0.018537, Epoch: 2
# Batch 260, Loss:  0.018685, Epoch: 2
# Batch 262, Loss:  0.018852, Epoch: 2
# Batch 264, Loss:  0.018975, Epoch: 2
# Batch 266, Loss:  0.019145, Epoch: 2
# Batch 268, Loss:  0.019254, Epoch: 2
# Batch 270, Loss:  0.019423, Epoch: 2
# Batch 272, Loss:  0.019578, Epoch: 2
# Batch 274, Loss:  0.019690, Epoch: 2
# Batch 276, Loss:  0.019817, Epoch: 2
# Batch 278, Loss:  0.019944, Epoch: 2
# Batch 280, Loss:  0.020140, Epoch: 2
# Batch 282, Loss:  0.020299, Epoch: 2
# Batch 284, Loss:  0.020454, Epoch: 2
# Batch 286, Loss:  0.020574, Epoch: 2
# Batch 288, Loss:  0.020760, Epoch: 2
# Batch 290, Loss:  0.020902, Epoch: 2
# Batch 292, Loss:  0.021013, Epoch: 2
# Batch 294, Loss:  0.021160, Epoch: 2
# Batch 296, Loss:  0.021322, Epoch: 2
# Batch 298, Loss:  0.021446, Epoch: 2
# Batch 300, Loss:  0.021577, Epoch: 2
# Batch 302, Loss:  0.021751, Epoch: 2
# Batch 304, Loss:  0.021903, Epoch: 2
# Batch 306, Loss:  0.021991, Epoch: 2
# Batch 308, Loss:  0.022142, Epoch: 2
# Batch 310, Loss:  0.022271, Epoch: 2
# Batch 312, Loss:  0.022431, Epoch: 2
# Batch 314, Loss:  0.022590, Epoch: 2
# Batch 316, Loss:  0.022729, Epoch: 2
# Batch 318, Loss:  0.022862, Epoch: 2
# Batch 320, Loss:  0.023001, Epoch: 2
# Batch 322, Loss:  0.023163, Epoch: 2
# Batch 324, Loss:  0.023312, Epoch: 2
# Batch 326, Loss:  0.023501, Epoch: 2
# Batch 328, Loss:  0.023655, Epoch: 2
# Batch 330, Loss:  0.023817, Epoch: 2
# Batch 332, Loss:  0.023953, Epoch: 2
# Batch 334, Loss:  0.024081, Epoch: 2
# Batch 336, Loss:  0.024173, Epoch: 2
# Batch 338, Loss:  0.024283, Epoch: 2
# Batch 340, Loss:  0.024432, Epoch: 2
# Batch 342, Loss:  0.024576, Epoch: 2
# Batch 344, Loss:  0.024725, Epoch: 2
# Batch 346, Loss:  0.024870, Epoch: 2
# Batch 348, Loss:  0.024991, Epoch: 2
# Batch 350, Loss:  0.025122, Epoch: 2
# Batch 352, Loss:  0.025249, Epoch: 2
# Batch 354, Loss:  0.025376, Epoch: 2
# Batch 356, Loss:  0.025516, Epoch: 2
# Batch 358, Loss:  0.025658, Epoch: 2
# Batch 360, Loss:  0.025802, Epoch: 2
# Batch 362, Loss:  0.025926, Epoch: 2
# Batch 364, Loss:  0.026056, Epoch: 2
# Batch 366, Loss:  0.026173, Epoch: 2
# Batch 368, Loss:  0.026364, Epoch: 2
# Batch 370, Loss:  0.026511, Epoch: 2
# Batch 372, Loss:  0.026636, Epoch: 2
# Batch 374, Loss:  0.026783, Epoch: 2
# Batch 376, Loss:  0.026938, Epoch: 2
# Batch 378, Loss:  0.027108, Epoch: 2
# Batch 380, Loss:  0.027303, Epoch: 2
# Batch 382, Loss:  0.027416, Epoch: 2
# Batch 384, Loss:  0.027583, Epoch: 2
# Batch 386, Loss:  0.027726, Epoch: 2
# Batch 388, Loss:  0.027876, Epoch: 2
# Batch 390, Loss:  0.028018, Epoch: 2
# Batch 392, Loss:  0.028162, Epoch: 2
# Batch 394, Loss:  0.028296, Epoch: 2
# Batch 396, Loss:  0.028465, Epoch: 2
# Batch 398, Loss:  0.028585, Epoch: 2
# Batch 400, Loss:  0.028775, Epoch: 2
# Batch 402, Loss:  0.028926, Epoch: 2
# Batch 404, Loss:  0.029042, Epoch: 2
# Batch 406, Loss:  0.029188, Epoch: 2
# Batch 408, Loss:  0.029306, Epoch: 2
# Batch 410, Loss:  0.029432, Epoch: 2
# Batch 412, Loss:  0.029571, Epoch: 2
# Batch 414, Loss:  0.029695, Epoch: 2
# Batch 416, Loss:  0.029803, Epoch: 2
# Batch 418, Loss:  0.029944, Epoch: 2
# Batch 420, Loss:  0.030089, Epoch: 2
# Batch 422, Loss:  0.030239, Epoch: 2
# Batch 424, Loss:  0.030377, Epoch: 2
# Batch 426, Loss:  0.030513, Epoch: 2
# Batch 428, Loss:  0.030659, Epoch: 2
# Batch 430, Loss:  0.030813, Epoch: 2
# Batch 432, Loss:  0.030937, Epoch: 2
# Batch 434, Loss:  0.031082, Epoch: 2
# Batch 436, Loss:  0.031213, Epoch: 2
# Batch 438, Loss:  0.031359, Epoch: 2
# Batch 440, Loss:  0.031526, Epoch: 2
# Batch 442, Loss:  0.031667, Epoch: 2
# Batch 444, Loss:  0.031831, Epoch: 2
# Batch 446, Loss:  0.031965, Epoch: 2
# Batch 448, Loss:  0.032109, Epoch: 2
# Batch 450, Loss:  0.032259, Epoch: 2
# Batch 452, Loss:  0.032385, Epoch: 2
# Batch 454, Loss:  0.032534, Epoch: 2
# Batch 456, Loss:  0.032694, Epoch: 2
# Batch 458, Loss:  0.032865, Epoch: 2
# Batch 460, Loss:  0.033028, Epoch: 2
# Batch 462, Loss:  0.033180, Epoch: 2
# Batch 464, Loss:  0.033369, Epoch: 2
# Batch 466, Loss:  0.033508, Epoch: 2
# Batch 468, Loss:  0.033688, Epoch: 2
# Batch 470, Loss:  0.033838, Epoch: 2
# Batch 472, Loss:  0.033961, Epoch: 2
# Batch 474, Loss:  0.034131, Epoch: 2
# Batch 476, Loss:  0.034326, Epoch: 2
# Batch 478, Loss:  0.034470, Epoch: 2
# Batch 480, Loss:  0.034585, Epoch: 2
# Batch 482, Loss:  0.034737, Epoch: 2
# Batch 484, Loss:  0.034849, Epoch: 2
# Batch 486, Loss:  0.034977, Epoch: 2
# Batch 488, Loss:  0.035101, Epoch: 2
# Batch 490, Loss:  0.035205, Epoch: 2
# Batch 492, Loss:  0.035350, Epoch: 2
# Batch 494, Loss:  0.035522, Epoch: 2
# Batch 496, Loss:  0.035663, Epoch: 2
# Batch 498, Loss:  0.035802, Epoch: 2
# Batch 500, Loss:  0.035940, Epoch: 2
# Batch 502, Loss:  0.036117, Epoch: 2
# Batch 504, Loss:  0.036278, Epoch: 2
# Batch 506, Loss:  0.036408, Epoch: 2
# Batch 508, Loss:  0.036529, Epoch: 2
# Batch 510, Loss:  0.036667, Epoch: 2
# Batch 512, Loss:  0.036828, Epoch: 2
# Batch 514, Loss:  0.036936, Epoch: 2
# Batch 516, Loss:  0.037081, Epoch: 2
# Batch 518, Loss:  0.037194, Epoch: 2
# Batch 520, Loss:  0.037352, Epoch: 2
# Batch 522, Loss:  0.037498, Epoch: 2
# Batch 524, Loss:  0.037634, Epoch: 2
# Batch 526, Loss:  0.037778, Epoch: 2
# Batch 528, Loss:  0.037911, Epoch: 2
# Batch 530, Loss:  0.038069, Epoch: 2
# Batch 532, Loss:  0.038209, Epoch: 2
# Batch 534, Loss:  0.038344, Epoch: 2
# Batch 536, Loss:  0.038490, Epoch: 2
# Batch 538, Loss:  0.038668, Epoch: 2
# Batch 540, Loss:  0.038790, Epoch: 2
# Batch 542, Loss:  0.038903, Epoch: 2
# Batch 544, Loss:  0.039037, Epoch: 2
# Batch 546, Loss:  0.039163, Epoch: 2
# Batch 548, Loss:  0.039298, Epoch: 2
# Batch 550, Loss:  0.039412, Epoch: 2
# Batch 552, Loss:  0.039540, Epoch: 2
# Batch 554, Loss:  0.039688, Epoch: 2
# Batch 556, Loss:  0.039811, Epoch: 2
# Batch 558, Loss:  0.039940, Epoch: 2
# Batch 560, Loss:  0.040079, Epoch: 2
# Batch 562, Loss:  0.040237, Epoch: 2
# Batch 564, Loss:  0.040340, Epoch: 2
# Batch 566, Loss:  0.040495, Epoch: 2
# Batch 568, Loss:  0.040620, Epoch: 2
# Batch 570, Loss:  0.040736, Epoch: 2
# Batch 572, Loss:  0.040852, Epoch: 2
# Batch 574, Loss:  0.041035, Epoch: 2
# Batch 576, Loss:  0.041165, Epoch: 2
# Batch 578, Loss:  0.041295, Epoch: 2
# Batch 580, Loss:  0.041424, Epoch: 2
# Batch 582, Loss:  0.041552, Epoch: 2
# Batch 584, Loss:  0.041683, Epoch: 2
# Batch 586, Loss:  0.041816, Epoch: 2
# Batch 588, Loss:  0.041951, Epoch: 2
# Batch 590, Loss:  0.042143, Epoch: 2
# Batch 592, Loss:  0.042305, Epoch: 2
# Batch 594, Loss:  0.042415, Epoch: 2
# Batch 596, Loss:  0.042565, Epoch: 2
# Batch 598, Loss:  0.042699, Epoch: 2
# Batch 600, Loss:  0.042806, Epoch: 2
# Batch 602, Loss:  0.042925, Epoch: 2
# Batch 604, Loss:  0.043034, Epoch: 2
# Batch 606, Loss:  0.043188, Epoch: 2
# Batch 608, Loss:  0.043328, Epoch: 2
# Batch 610, Loss:  0.043429, Epoch: 2
# Batch 612, Loss:  0.043580, Epoch: 2
# Batch 614, Loss:  0.043709, Epoch: 2
# Batch 616, Loss:  0.043872, Epoch: 2
# Batch 618, Loss:  0.044003, Epoch: 2
# Batch 620, Loss:  0.044133, Epoch: 2
# Batch 622, Loss:  0.044251, Epoch: 2
# Batch 624, Loss:  0.044386, Epoch: 2
# Batch 626, Loss:  0.044582, Epoch: 2
# Batch 628, Loss:  0.044701, Epoch: 2
# Batch 630, Loss:  0.044843, Epoch: 2
# Batch 632, Loss:  0.045026, Epoch: 2
# Batch 634, Loss:  0.045156, Epoch: 2
# Batch 636, Loss:  0.045291, Epoch: 2
# Batch 638, Loss:  0.045402, Epoch: 2
# Batch 640, Loss:  0.045533, Epoch: 2
# Batch 642, Loss:  0.045645, Epoch: 2
# Batch 644, Loss:  0.045778, Epoch: 2
# Batch 646, Loss:  0.045940, Epoch: 2
# Batch 648, Loss:  0.046080, Epoch: 2
# Batch 650, Loss:  0.046210, Epoch: 2
# Batch 652, Loss:  0.046328, Epoch: 2
# Batch 654, Loss:  0.046478, Epoch: 2
# Batch 656, Loss:  0.046661, Epoch: 2
# Batch 658, Loss:  0.046811, Epoch: 2
# Batch 660, Loss:  0.046972, Epoch: 2
# Batch 662, Loss:  0.047117, Epoch: 2
# Batch 664, Loss:  0.047237, Epoch: 2
# Batch 666, Loss:  0.047386, Epoch: 2
# Batch 668, Loss:  0.047537, Epoch: 2
# Batch 670, Loss:  0.047671, Epoch: 2
# Batch 672, Loss:  0.047801, Epoch: 2
# Batch 674, Loss:  0.047967, Epoch: 2
# Batch 676, Loss:  0.048131, Epoch: 2
# Batch 678, Loss:  0.048291, Epoch: 2
# Batch 680, Loss:  0.048433, Epoch: 2
# Batch 682, Loss:  0.048590, Epoch: 2
# Batch 684, Loss:  0.048712, Epoch: 2
# Batch 686, Loss:  0.048843, Epoch: 2
# Batch 688, Loss:  0.048991, Epoch: 2
# Batch 690, Loss:  0.049177, Epoch: 2
# Batch 692, Loss:  0.049316, Epoch: 2
# Batch 694, Loss:  0.049453, Epoch: 2
# Batch 696, Loss:  0.049559, Epoch: 2
# Batch 698, Loss:  0.049699, Epoch: 2
# Batch 700, Loss:  0.049833, Epoch: 2
# Batch 702, Loss:  0.049972, Epoch: 2
# Batch 704, Loss:  0.050162, Epoch: 2
# Batch 706, Loss:  0.050325, Epoch: 2
# Batch 708, Loss:  0.050469, Epoch: 2
# Batch 710, Loss:  0.050621, Epoch: 2
# Batch 712, Loss:  0.050800, Epoch: 2
# Batch 714, Loss:  0.050952, Epoch: 2
# Batch 716, Loss:  0.051045, Epoch: 2
# Batch 718, Loss:  0.051193, Epoch: 2
# Batch 720, Loss:  0.051294, Epoch: 2
# Batch 722, Loss:  0.051463, Epoch: 2
# Batch 724, Loss:  0.051606, Epoch: 2
# Batch 726, Loss:  0.051750, Epoch: 2
# Batch 728, Loss:  0.051873, Epoch: 2
# Batch 730, Loss:  0.052034, Epoch: 2
# Batch 732, Loss:  0.052194, Epoch: 2
# Batch 734, Loss:  0.052311, Epoch: 2
# Batch 736, Loss:  0.052467, Epoch: 2
# Batch 738, Loss:  0.052577, Epoch: 2
# Batch 740, Loss:  0.052716, Epoch: 2
# Batch 742, Loss:  0.052835, Epoch: 2
# Batch 744, Loss:  0.052956, Epoch: 2
# Batch 746, Loss:  0.053130, Epoch: 2
# Batch 748, Loss:  0.053269, Epoch: 2
# Batch 750, Loss:  0.053408, Epoch: 2
# Batch 752, Loss:  0.053536, Epoch: 2
# Batch 754, Loss:  0.053664, Epoch: 2
# Batch 756, Loss:  0.053774, Epoch: 2
# Batch 758, Loss:  0.053903, Epoch: 2
# Batch 760, Loss:  0.054055, Epoch: 2
# Batch 762, Loss:  0.054189, Epoch: 2
# Batch 764, Loss:  0.054314, Epoch: 2
# Batch 766, Loss:  0.054452, Epoch: 2
# Batch 768, Loss:  0.054566, Epoch: 2
# Batch 770, Loss:  0.054725, Epoch: 2
# Batch 772, Loss:  0.054842, Epoch: 2
# Batch 774, Loss:  0.054948, Epoch: 2
# Batch 776, Loss:  0.055123, Epoch: 2
# Batch 778, Loss:  0.055235, Epoch: 2
# Batch 780, Loss:  0.055421, Epoch: 2
# Batch 782, Loss:  0.055541, Epoch: 2
# Batch 784, Loss:  0.055713, Epoch: 2
# Batch 786, Loss:  0.055856, Epoch: 2
# Batch 788, Loss:  0.055987, Epoch: 2
# Batch 790, Loss:  0.056118, Epoch: 2
# Batch 792, Loss:  0.056254, Epoch: 2
# Batch 794, Loss:  0.056396, Epoch: 2
# Batch 796, Loss:  0.056543, Epoch: 2
# Batch 798, Loss:  0.056702, Epoch: 2
# Batch 800, Loss:  0.056818, Epoch: 2
# Batch 802, Loss:  0.056948, Epoch: 2
# Batch 804, Loss:  0.057091, Epoch: 2
# Batch 806, Loss:  0.057295, Epoch: 2
# Batch 808, Loss:  0.057398, Epoch: 2
# ...
# Batch 938, Loss:  0.051839, Epoch: 8
# Batch 940, Loss:  0.051939, Epoch: 8
# Batch 942, Loss:  0.052018, Epoch: 8
# Batch 944, Loss:  0.052109, Epoch: 8
# Batch 946, Loss:  0.052182, Epoch: 8
# Batch 948, Loss:  0.052296, Epoch: 8
# Batch 950, Loss:  0.052393, Epoch: 8
# Batch 952, Loss:  0.052495, Epoch: 8
# Batch 954, Loss:  0.052578, Epoch: 8
# Batch 956, Loss:  0.052662, Epoch: 8
# Batch 958, Loss:  0.052772, Epoch: 8
# Batch 960, Loss:  0.052865, Epoch: 8
# Batch 962, Loss:  0.052989, Epoch: 8
# Batch 964, Loss:  0.053092, Epoch: 8
# Batch 966, Loss:  0.053186, Epoch: 8
# Batch 968, Loss:  0.053293, Epoch: 8
# Batch 970, Loss:  0.053400, Epoch: 8
# Batch 972, Loss:  0.053482, Epoch: 8
# Batch 974, Loss:  0.053581, Epoch: 8
# Batch 976, Loss:  0.053671, Epoch: 8
# Batch 978, Loss:  0.053747, Epoch: 8
# Batch 980, Loss:  0.053839, Epoch: 8
# Batch 982, Loss:  0.053917, Epoch: 8
# Batch 984, Loss:  0.054014, Epoch: 8
# Batch 986, Loss:  0.054098, Epoch: 8
# Batch 988, Loss:  0.054215, Epoch: 8
# Batch 990, Loss:  0.054298, Epoch: 8
# Batch 992, Loss:  0.054408, Epoch: 8
# Batch 994, Loss:  0.054500, Epoch: 8
# Batch 996, Loss:  0.054630, Epoch: 8
# Batch 998, Loss:  0.054735, Epoch: 8
# Batch 1000, Loss:  0.054859, Epoch: 8
# Batch 1002, Loss:  0.054972, Epoch: 8
# Batch 1004, Loss:  0.055078, Epoch: 8
# Batch 1006, Loss:  0.055165, Epoch: 8
# Batch 1008, Loss:  0.055230, Epoch: 8
# Batch 1010, Loss:  0.055354, Epoch: 8
# Batch 1012, Loss:  0.055458, Epoch: 8
# Batch 1014, Loss:  0.055552, Epoch: 8
# Batch 1016, Loss:  0.055639, Epoch: 8
# Batch 1018, Loss:  0.055722, Epoch: 8
# Batch 1020, Loss:  0.055842, Epoch: 8
# Batch 1022, Loss:  0.055936, Epoch: 8
# Batch 1024, Loss:  0.056042, Epoch: 8
# Batch 1026, Loss:  0.056143, Epoch: 8
# Batch 1028, Loss:  0.056252, Epoch: 8
# Batch 1030, Loss:  0.056351, Epoch: 8
# Batch 1032, Loss:  0.056467, Epoch: 8
# Batch 1034, Loss:  0.056568, Epoch: 8
# Batch 1036, Loss:  0.056686, Epoch: 8
# Batch 1038, Loss:  0.056802, Epoch: 8
# Batch 1040, Loss:  0.056932, Epoch: 8
# Batch 1042, Loss:  0.057021, Epoch: 8
# Batch 1044, Loss:  0.057127, Epoch: 8
# Batch 1046, Loss:  0.057255, Epoch: 8
# Batch 1048, Loss:  0.057352, Epoch: 8
# Batch 1050, Loss:  0.057482, Epoch: 8
# Batch 1052, Loss:  0.057599, Epoch: 8
# Batch 1054, Loss:  0.057733, Epoch: 8
# Batch 1056, Loss:  0.057848, Epoch: 8
# Batch 1058, Loss:  0.057970, Epoch: 8
# Batch 1060, Loss:  0.058070, Epoch: 8
# Batch 1062, Loss:  0.058195, Epoch: 8
# Batch 1064, Loss:  0.058335, Epoch: 8
# Batch 1066, Loss:  0.058428, Epoch: 8
# Batch 1068, Loss:  0.058549, Epoch: 8
# Batch 1070, Loss:  0.058661, Epoch: 8
# Batch 1072, Loss:  0.058764, Epoch: 8
# Batch 1074, Loss:  0.058858, Epoch: 8
# Batch 1076, Loss:  0.058934, Epoch: 8
# Batch 1078, Loss:  0.059049, Epoch: 8
# Batch 1080, Loss:  0.059162, Epoch: 8
# Batch 1082, Loss:  0.059275, Epoch: 8
# Batch 1084, Loss:  0.059380, Epoch: 8
# Batch 1086, Loss:  0.059467, Epoch: 8
# Batch 1088, Loss:  0.059565, Epoch: 8
# Batch 1090, Loss:  0.059688, Epoch: 8
# Batch 1092, Loss:  0.059780, Epoch: 8
# Batch 1094, Loss:  0.059911, Epoch: 8
# Batch 1096, Loss:  0.060005, Epoch: 8
# Batch 1098, Loss:  0.060134, Epoch: 8
# Batch 1100, Loss:  0.060237, Epoch: 8
# Batch 1102, Loss:  0.060362, Epoch: 8
# Batch 1104, Loss:  0.060465, Epoch: 8
# Batch 1106, Loss:  0.060582, Epoch: 8
# Batch 1108, Loss:  0.060702, Epoch: 8
# Batch 1110, Loss:  0.060789, Epoch: 8
# Batch 1112, Loss:  0.060906, Epoch: 8
# Batch 1114, Loss:  0.061015, Epoch: 8
# Batch 1116, Loss:  0.061129, Epoch: 8
# Batch 1118, Loss:  0.061238, Epoch: 8
# Batch 1120, Loss:  0.061350, Epoch: 8
# Batch 1122, Loss:  0.061486, Epoch: 8
# Batch 1124, Loss:  0.061556, Epoch: 8
# Batch 1126, Loss:  0.061654, Epoch: 8
# Batch 1128, Loss:  0.061758, Epoch: 8
# Batch 1130, Loss:  0.061863, Epoch: 8
# Batch 1132, Loss:  0.061987, Epoch: 8
# Batch 1134, Loss:  0.062118, Epoch: 8
# Batch 1136, Loss:  0.062210, Epoch: 8
# Batch 1138, Loss:  0.062326, Epoch: 8
# Batch 1140, Loss:  0.062444, Epoch: 8
# Batch 1142, Loss:  0.062594, Epoch: 8
# Batch 1144, Loss:  0.062691, Epoch: 8
# Batch 1146, Loss:  0.062812, Epoch: 8
# Batch 1148, Loss:  0.062926, Epoch: 8
# Batch 1150, Loss:  0.063052, Epoch: 8
# Batch 1152, Loss:  0.063179, Epoch: 8
# Batch 1154, Loss:  0.063269, Epoch: 8
# Batch 1156, Loss:  0.063404, Epoch: 8
# Batch 1158, Loss:  0.063525, Epoch: 8
# Batch 1160, Loss:  0.063640, Epoch: 8
# Batch 1162, Loss:  0.063748, Epoch: 8
# Batch 1164, Loss:  0.063863, Epoch: 8
# Batch 1166, Loss:  0.063962, Epoch: 8
# Batch 1168, Loss:  0.064065, Epoch: 8
# Batch 1170, Loss:  0.064153, Epoch: 8
# Batch 1172, Loss:  0.064285, Epoch: 8
# Batch 1174, Loss:  0.064408, Epoch: 8
# Batch 1176, Loss:  0.064525, Epoch: 8
# Batch 1178, Loss:  0.064658, Epoch: 8
# Batch 1180, Loss:  0.064785, Epoch: 8
# Batch 1182, Loss:  0.064906, Epoch: 8
# Batch 1184, Loss:  0.065004, Epoch: 8
# Batch 1186, Loss:  0.065120, Epoch: 8
# Batch 1188, Loss:  0.065215, Epoch: 8
# Batch 1190, Loss:  0.065324, Epoch: 8
# Batch 1192, Loss:  0.065413, Epoch: 8
# Batch 1194, Loss:  0.065522, Epoch: 8
# Batch 1196, Loss:  0.065611, Epoch: 8
# Batch 1198, Loss:  0.065714, Epoch: 8
# Batch 1200, Loss:  0.065804, Epoch: 8
# Batch 1202, Loss:  0.065930, Epoch: 8
# Batch 1204, Loss:  0.066035, Epoch: 8
# Batch 1206, Loss:  0.066144, Epoch: 8
# Batch 1208, Loss:  0.066237, Epoch: 8
# Batch 1210, Loss:  0.066341, Epoch: 8
# Batch 1212, Loss:  0.066415, Epoch: 8
# Batch 1214, Loss:  0.066512, Epoch: 8
# Batch 1216, Loss:  0.066617, Epoch: 8
# Batch 1218, Loss:  0.066723, Epoch: 8
# Batch 1220, Loss:  0.066814, Epoch: 8
# Batch 1222, Loss:  0.066942, Epoch: 8
# Batch 1224, Loss:  0.067035, Epoch: 8
# Batch 1226, Loss:  0.067119, Epoch: 8
# Batch 1228, Loss:  0.067231, Epoch: 8
# Batch 1230, Loss:  0.067370, Epoch: 8
# Batch 1232, Loss:  0.067481, Epoch: 8
# Batch 1234, Loss:  0.067589, Epoch: 8
# Batch 1236, Loss:  0.067699, Epoch: 8
# Batch 1238, Loss:  0.067809, Epoch: 8
# Batch 1240, Loss:  0.067935, Epoch: 8
# Batch 1242, Loss:  0.068032, Epoch: 8
# Batch 1244, Loss:  0.068113, Epoch: 8
# Batch 1246, Loss:  0.068212, Epoch: 8
# Batch 1248, Loss:  0.068314, Epoch: 8
# Batch 1250, Loss:  0.068381, Epoch: 8
# Batch 1252, Loss:  0.068463, Epoch: 8
# Batch 1254, Loss:  0.068578, Epoch: 8
# Batch 1256, Loss:  0.068662, Epoch: 8
# Batch 1258, Loss:  0.068780, Epoch: 8
# Batch 1260, Loss:  0.068907, Epoch: 8
# Batch 1262, Loss:  0.068980, Epoch: 8
# Batch 1264, Loss:  0.069068, Epoch: 8
# Batch 1266, Loss:  0.069175, Epoch: 8
# Batch 1268, Loss:  0.069248, Epoch: 8
# Batch 1270, Loss:  0.069320, Epoch: 8
# Batch 1272, Loss:  0.069435, Epoch: 8
# Batch 1274, Loss:  0.069507, Epoch: 8
# Batch 1276, Loss:  0.069587, Epoch: 8
# Batch 1278, Loss:  0.069675, Epoch: 8
# Batch 1280, Loss:  0.069754, Epoch: 8
# Batch 1282, Loss:  0.069854, Epoch: 8
# Batch 1284, Loss:  0.069943, Epoch: 8
# Batch 1286, Loss:  0.070069, Epoch: 8
# Batch 1288, Loss:  0.070173, Epoch: 8
# Batch 1290, Loss:  0.070282, Epoch: 8
# Batch 1292, Loss:  0.070415, Epoch: 8
# Batch 1294, Loss:  0.070525, Epoch: 8
# Batch 1296, Loss:  0.070626, Epoch: 8
# Batch 1298, Loss:  0.070728, Epoch: 8
# Batch 1300, Loss:  0.070847, Epoch: 8
# Batch 1302, Loss:  0.070952, Epoch: 8
# Batch 1304, Loss:  0.071047, Epoch: 8
# Batch 1306, Loss:  0.071136, Epoch: 8
# Batch 1308, Loss:  0.071247, Epoch: 8
# Batch 1310, Loss:  0.071354, Epoch: 8
# Batch 1312, Loss:  0.071481, Epoch: 8
# Batch 1314, Loss:  0.071584, Epoch: 8
# Batch 1316, Loss:  0.071711, Epoch: 8
# Batch 1318, Loss:  0.071857, Epoch: 8
# Batch 1320, Loss:  0.071980, Epoch: 8
# Batch 1322, Loss:  0.072073, Epoch: 8
# Batch 1324, Loss:  0.072171, Epoch: 8
# Batch 1326, Loss:  0.072307, Epoch: 8
# Batch 1328, Loss:  0.072438, Epoch: 8
# Batch 1330, Loss:  0.072543, Epoch: 8
# Batch 1332, Loss:  0.072666, Epoch: 8
# Batch 1334, Loss:  0.072749, Epoch: 8
# Batch 1336, Loss:  0.072856, Epoch: 8
# Batch 1338, Loss:  0.072957, Epoch: 8
# Batch 1340, Loss:  0.073060, Epoch: 8
# Batch 1342, Loss:  0.073174, Epoch: 8
# Batch 1344, Loss:  0.073272, Epoch: 8
# Batch 1346, Loss:  0.073376, Epoch: 8
# Batch 1348, Loss:  0.073477, Epoch: 8
# Batch 1350, Loss:  0.073611, Epoch: 8
# Batch 1352, Loss:  0.073719, Epoch: 8
# Batch 1354, Loss:  0.073832, Epoch: 8
# Batch 1356, Loss:  0.073928, Epoch: 8
# Batch 1358, Loss:  0.074037, Epoch: 8
# Batch 1360, Loss:  0.074165, Epoch: 8
# Batch 1362, Loss:  0.074253, Epoch: 8
# Batch 1364, Loss:  0.074385, Epoch: 8
# Batch 1366, Loss:  0.074476, Epoch: 8
# Batch 1368, Loss:  0.074567, Epoch: 8
# Batch 1370, Loss:  0.074664, Epoch: 8
# Batch 1372, Loss:  0.074784, Epoch: 8
# Batch 1374, Loss:  0.074867, Epoch: 8
# Batch 1376, Loss:  0.074972, Epoch: 8
# Batch 1378, Loss:  0.075072, Epoch: 8
# Batch 1380, Loss:  0.075171, Epoch: 8
# Batch 1382, Loss:  0.075279, Epoch: 8
# Batch 1384, Loss:  0.075369, Epoch: 8
# Batch 1386, Loss:  0.075467, Epoch: 8
# Batch 1388, Loss:  0.075593, Epoch: 8
# Batch 1390, Loss:  0.075713, Epoch: 8
# Batch 1392, Loss:  0.075805, Epoch: 8
# Batch 1394, Loss:  0.075915, Epoch: 8
# Batch 1396, Loss:  0.076024, Epoch: 8
# Batch 1398, Loss:  0.076135, Epoch: 8
# Batch 1400, Loss:  0.076228, Epoch: 8
# Batch 1402, Loss:  0.076329, Epoch: 8
# Batch 1404, Loss:  0.076443, Epoch: 8
# Batch 1406, Loss:  0.076542, Epoch: 8
# Batch 1408, Loss:  0.076653, Epoch: 8
# Batch 1410, Loss:  0.076742, Epoch: 8
# Batch 1412, Loss:  0.076825, Epoch: 8
# Batch 1414, Loss:  0.076941, Epoch: 8
# Batch 1416, Loss:  0.077058, Epoch: 8
# Batch 1418, Loss:  0.077176, Epoch: 8
# Batch 1420, Loss:  0.077265, Epoch: 8
# Batch 1422, Loss:  0.077411, Epoch: 8
# Batch 1424, Loss:  0.077517, Epoch: 8
# Batch 1426, Loss:  0.077659, Epoch: 8
# Batch 1428, Loss:  0.077733, Epoch: 8
# Batch 1430, Loss:  0.077828, Epoch: 8
# Batch 1432, Loss:  0.077932, Epoch: 8
# Batch 1434, Loss:  0.078041, Epoch: 8
# Batch 1436, Loss:  0.078150, Epoch: 8
# Batch 1438, Loss:  0.078262, Epoch: 8
# Batch 1440, Loss:  0.078388, Epoch: 8
# Batch 1442, Loss:  0.078505, Epoch: 8
# Batch 1444, Loss:  0.078614, Epoch: 8
# Batch 1446, Loss:  0.078717, Epoch: 8
# Batch 1448, Loss:  0.078809, Epoch: 8
# Batch 1450, Loss:  0.078889, Epoch: 8
# Batch 1452, Loss:  0.078997, Epoch: 8
# Batch 1454, Loss:  0.079120, Epoch: 8
# Batch 1456, Loss:  0.079238, Epoch: 8
# Batch 1458, Loss:  0.079369, Epoch: 8
# Batch 1460, Loss:  0.079470, Epoch: 8
# Batch 1462, Loss:  0.079583, Epoch: 8
# Batch 1464, Loss:  0.079736, Epoch: 8
# Batch 1466, Loss:  0.079864, Epoch: 8
# Batch 1468, Loss:  0.079975, Epoch: 8
# Batch 1470, Loss:  0.080096, Epoch: 8
# Batch 1472, Loss:  0.080198, Epoch: 8
# Batch 1474, Loss:  0.080296, Epoch: 8
# Batch 1476, Loss:  0.080424, Epoch: 8
# Batch 1478, Loss:  0.080544, Epoch: 8
# Batch 1480, Loss:  0.080622, Epoch: 8
# Batch 1482, Loss:  0.080757, Epoch: 8
# Batch 1484, Loss:  0.080863, Epoch: 8
# Batch 1486, Loss:  0.080949, Epoch: 8
# Batch 1488, Loss:  0.081045, Epoch: 8
# Batch 1490, Loss:  0.081102, Epoch: 8
# Batch 1492, Loss:  0.081222, Epoch: 8
# Batch 1494, Loss:  0.081323, Epoch: 8
# Batch 1496, Loss:  0.081439, Epoch: 8
# Batch 1498, Loss:  0.081590, Epoch: 8
# Batch 1500, Loss:  0.081707, Epoch: 8
# Batch 1502, Loss:  0.081820, Epoch: 8
# Batch 1504, Loss:  0.081884, Epoch: 8
# Batch 1506, Loss:  0.082025, Epoch: 8
# Batch 1508, Loss:  0.082111, Epoch: 8
# Batch 1510, Loss:  0.082228, Epoch: 8
# Batch 1512, Loss:  0.082328, Epoch: 8
# Batch 1514, Loss:  0.082490, Epoch: 8
# Batch 1516, Loss:  0.082599, Epoch: 8
# Batch 1518, Loss:  0.082684, Epoch: 8
# Batch 1520, Loss:  0.082827, Epoch: 8
# Batch 1522, Loss:  0.082936, Epoch: 8
# Batch 1524, Loss:  0.083052, Epoch: 8
# Batch 1526, Loss:  0.083123, Epoch: 8
# Batch 1528, Loss:  0.083246, Epoch: 8
# Batch 1530, Loss:  0.083361, Epoch: 8
# Batch 1532, Loss:  0.083456, Epoch: 8
# Batch 1534, Loss:  0.083574, Epoch: 8
# Batch 1536, Loss:  0.083681, Epoch: 8
# Batch 1538, Loss:  0.083783, Epoch: 8
# Batch 1540, Loss:  0.083898, Epoch: 8
# Batch 1542, Loss:  0.084006, Epoch: 8
# Batch 1544, Loss:  0.084084, Epoch: 8
# Batch 1546, Loss:  0.084166, Epoch: 8
# Batch 1548, Loss:  0.084291, Epoch: 8
# Batch 1550, Loss:  0.084388, Epoch: 8
# Batch 1552, Loss:  0.084519, Epoch: 8
# Batch 1554, Loss:  0.084649, Epoch: 8
# Batch 1556, Loss:  0.084756, Epoch: 8
# Batch 1558, Loss:  0.084878, Epoch: 8
# Batch 1560, Loss:  0.084984, Epoch: 8
# Batch 1562, Loss:  0.085091, Epoch: 8
# Batch 1564, Loss:  0.085185, Epoch: 8
# Batch 1566, Loss:  0.085292, Epoch: 8
# Batch 1568, Loss:  0.085374, Epoch: 8
# Batch 1570, Loss:  0.085478, Epoch: 8
# Batch 1572, Loss:  0.085568, Epoch: 8
# Batch 1574, Loss:  0.085682, Epoch: 8
# Batch 1576, Loss:  0.085777, Epoch: 8
# Batch 1578, Loss:  0.085886, Epoch: 8
# Batch 1580, Loss:  0.085994, Epoch: 8
# Batch 1582, Loss:  0.086084, Epoch: 8
# Batch 1584, Loss:  0.086185, Epoch: 8
# Batch 1586, Loss:  0.086292, Epoch: 8
# Batch 1588, Loss:  0.086413, Epoch: 8
# Batch 1590, Loss:  0.086501, Epoch: 8
# Batch 1592, Loss:  0.086610, Epoch: 8
# Batch 1594, Loss:  0.086694, Epoch: 8
# Batch 1596, Loss:  0.086806, Epoch: 8
# Batch 1598, Loss:  0.086927, Epoch: 8
# Batch 1600, Loss:  0.087065, Epoch: 8
# Batch 1602, Loss:  0.087167, Epoch: 8
# Batch 1604, Loss:  0.087259, Epoch: 8
# Batch 1606, Loss:  0.087406, Epoch: 8
# Batch 1608, Loss:  0.087521, Epoch: 8
# Batch 1610, Loss:  0.087628, Epoch: 8
# Batch 1612, Loss:  0.087752, Epoch: 8
# Batch 1614, Loss:  0.087832, Epoch: 8
# Batch 1616, Loss:  0.087928, Epoch: 8
# Batch 1618, Loss:  0.088048, Epoch: 8
# Batch 1620, Loss:  0.088220, Epoch: 8
# Batch 1622, Loss:  0.088358, Epoch: 8
# Batch 1624, Loss:  0.088456, Epoch: 8
# Batch 1626, Loss:  0.088642, Epoch: 8
# Batch 1628, Loss:  0.088765, Epoch: 8
# Batch 1630, Loss:  0.088888, Epoch: 8
# Batch 1632, Loss:  0.089033, Epoch: 8
# Batch 1634, Loss:  0.089161, Epoch: 8
# Batch 1636, Loss:  0.089254, Epoch: 8
# Batch 1638, Loss:  0.089353, Epoch: 8
# Batch 1640, Loss:  0.089476, Epoch: 8
# Batch 1642, Loss:  0.089605, Epoch: 8
# Batch 1644, Loss:  0.089739, Epoch: 8
# Batch 1646, Loss:  0.089854, Epoch: 8
# Batch 1648, Loss:  0.089990, Epoch: 8
# Batch 1650, Loss:  0.090097, Epoch: 8
# Batch 1652, Loss:  0.090202, Epoch: 8
# Batch 1654, Loss:  0.090327, Epoch: 8
# Batch 1656, Loss:  0.090441, Epoch: 8
# Batch 1658, Loss:  0.090525, Epoch: 8
# Batch 1660, Loss:  0.090618, Epoch: 8
# Batch 1662, Loss:  0.090733, Epoch: 8
# Batch 1664, Loss:  0.090855, Epoch: 8
# Batch 1666, Loss:  0.090970, Epoch: 8
# Batch 1668, Loss:  0.091082, Epoch: 8
# Batch 1670, Loss:  0.091182, Epoch: 8
# Batch 1672, Loss:  0.091316, Epoch: 8
# Batch 1674, Loss:  0.091417, Epoch: 8
# Batch 1676, Loss:  0.091512, Epoch: 8
# Batch 1678, Loss:  0.091649, Epoch: 8
# Batch 1680, Loss:  0.091795, Epoch: 8
# Batch 1682, Loss:  0.091889, Epoch: 8
# Batch 1684, Loss:  0.092022, Epoch: 8
# Batch 1686, Loss:  0.092147, Epoch: 8
# Batch 1688, Loss:  0.092234, Epoch: 8
# Batch 1690, Loss:  0.092335, Epoch: 8
# Batch 1692, Loss:  0.092436, Epoch: 8
# Batch 1694, Loss:  0.092566, Epoch: 8
# Batch 1696, Loss:  0.092672, Epoch: 8
# Batch 1698, Loss:  0.092806, Epoch: 8
# Batch 1700, Loss:  0.092916, Epoch: 8
# Batch 1702, Loss:  0.093026, Epoch: 8
# Batch 1704, Loss:  0.093101, Epoch: 8
# Batch 1706, Loss:  0.093223, Epoch: 8
# Batch 1708, Loss:  0.093375, Epoch: 8
# Batch 1710, Loss:  0.093489, Epoch: 8
# Batch 1712, Loss:  0.093604, Epoch: 8
# Batch 1714, Loss:  0.093702, Epoch: 8
# Batch 1716, Loss:  0.093824, Epoch: 8
# Batch 1718, Loss:  0.093935, Epoch: 8
# Batch 1720, Loss:  0.094059, Epoch: 8
# Batch 1722, Loss:  0.094146, Epoch: 8
# Batch 1724, Loss:  0.094245, Epoch: 8
# Batch 1726, Loss:  0.094354, Epoch: 8
# Batch 1728, Loss:  0.094461, Epoch: 8
# Batch 1730, Loss:  0.094589, Epoch: 8
# Batch 1732, Loss:  0.094707, Epoch: 8
# Batch 1734, Loss:  0.094837, Epoch: 8
# Batch 1736, Loss:  0.094948, Epoch: 8
# Batch 1738, Loss:  0.095055, Epoch: 8
# Batch 1740, Loss:  0.095161, Epoch: 8
# Batch 1742, Loss:  0.095265, Epoch: 8
# Batch 1744, Loss:  0.095391, Epoch: 8
# Batch 1746, Loss:  0.095493, Epoch: 8
# Batch 1748, Loss:  0.095623, Epoch: 8
# Batch 1750, Loss:  0.095717, Epoch: 8
# Batch 1752, Loss:  0.095851, Epoch: 8
# Batch 1754, Loss:  0.095933, Epoch: 8
# Batch 1756, Loss:  0.096041, Epoch: 8
# Batch 1758, Loss:  0.096181, Epoch: 8
# Batch 1760, Loss:  0.096286, Epoch: 8
# Batch 1762, Loss:  0.096380, Epoch: 8
# Batch 1764, Loss:  0.096516, Epoch: 8
# Batch 1766, Loss:  0.096628, Epoch: 8
# Validation Loss  0.012
# ###################################################
# Early stopping
# [tensor(0.0094), tensor(0.0137), tensor(0.0072), tensor(0.0097), tensor(0.0109), tensor(0.0125), tensor(0.0140), tensor(0.0119)]
# Best_Validation_Loss tensor(0.0072)

# %% [markdown]
# # LSTM Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

df = pd.read_csv('experimental/Training.csv')
time = df['Time'].values.astype('float32')
time = time[:len(time)-30]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 9))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Angular Speed (rad/s)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

df = pd.read_csv('experimental/Testing.csv')
time = df['Time'].values.astype('float32')
time = time[:len(time)-30]

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Angular Speed (rad/s)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time (s)')
axs[1, 0].set_ylabel('Weight (kg)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time (s)')
axs[1, 1].set_ylabel('Weight (kg)')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the model and furnishing the output data

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

# Define the hyperparameters
input_size = 2
hidden_size = 120
num_stacked_layers = 5
fc_size1 = 140
fc_size2 = 280
fc_size3 = 360
output_size = 2
dropout = 0.1

# Initialize the model
model = LSTMModel(input_size, hidden_size, num_stacked_layers, dropout=0.0, output_size=output_size)

model_path = "model.pth"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
model.load_state_dict(torch.load(model_path))

model.to(device)

model.eval()
# Out:
# cpu
# LSTMModel(
#   (lstm1): LSTM(2, 120, num_layers=5, batch_first=True)
#   (dropout): Dropout(p=0.0, inplace=False)
#   (fc_output1): Sequential(
#     (0): Linear(in_features=120, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=280, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=280, out_features=360, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=360, out_features=1, bias=True)
#   )
#   (fc_output2): Sequential(
#     (0): Linear(in_features=120, out_features=140, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=140, out_features=280, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=280, out_features=360, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=360, out_features=1, bias=True)
#   )
# )

# %%
for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

print("Actual_Data_shape", actual_data.shape, "Predicted_Data_shape", predicted_data.shape)
# Out:
# Actual_Data_shape (52970, 2) Predicted_Data_shape (52970, 2)

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

time = np.linspace(0, 60, len(actual_data))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time Stamp')
axs[0, 0].set_ylabel('Flow')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time Stamp')
axs[0, 1].set_ylabel('Flow')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

time = np.linspace(0, 60, len(actual_data))
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time Stamp')
axs[0, 0].set_ylabel('Flow')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time Stamp')
axs[0, 1].set_ylabel('Flow')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Concatenating the test train and analysing the
print(type(X_train))
X_train = X_train.cpu().numpy()
print(X_train.shape)

X_test = X_test.cpu().numpy()
print(X_test.shape)

# dataset_total = np.concatenate((X_train, X_test))
# print(dataset_total.shape)
inputs = X_train[len(X_train) - 30:]
print(inputs.shape)
# inputs = inputs.reshape(-1, 2)
# print(inputs.shape)
# Out:
# <class 'torch.Tensor'>
# (52970, 30, 2)
# (5970, 30, 2)
# (30, 30, 2)

# %%
input_tensor = torch.from_numpy(inputs).to(device)
print(input_tensor.shape)
model.eval()

with torch.no_grad():
  predicted_number = model(input_tensor)

predicted_number = predicted_number.cpu().numpy()

print("Predicted_Number_shape", predicted_number.shape)
# Out:
# torch.Size([30, 30, 2])
# Predicted_Number_shape (30, 2)

# %%
labels = set_to_scale_labels[len(set_to_scale_labels)-30:]

fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].plot(labels[:, 0], color = 'red', label = 'Last Batch Labels')
ax[0].plot(predicted_number[:, 0], color = 'blue', label = 'Predicted Output Velocity')
ax[0].set_xlabel('Time Stamps (s)')
ax[0].set_ylabel('Labels (rad/sec)')
ax[0].set_title("Real Out Vel last 30 samples")
ax[0].legend()

ax[1].plot(labels[:, 1], color = 'red', label = 'Last Batch Labels')
ax[1].plot(predicted_number[:, 1], color = 'blue', label = 'Predicted Weight on Bit')
ax[1].set_xlabel('Time Stamps (s)')
ax[1].set_ylabel('Weight on bit (kg)')
ax[1].set_title("Predicted Bit Weight last 30 samples")
ax[1].legend()

plt.tight_layout()
plt.show()
