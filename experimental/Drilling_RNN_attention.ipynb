# %% [markdown]
# Time-Series Prediction
# Time series and sequence prediction could be a really amazing to predict/estimate a robot's trajectory which requires temporal data at hand. In this assignemnt we will see how this could be done using Deep Learning.
#
# Given a dataset [link](https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv) for airline passengers prediction problem. Predict the number of international airline passengers in units of 1,000 given a year and a month.
# Here is how the data looks like.

# %%
import netron 
netron.start('models/model_attention.pth')
# Out:
# Serving 'models/model_attention.pth' at http://localhost:8080
# ('localhost', 8080)

# %%
import matplotlib.pyplot as plt
import pandas as pd
file_name = 'experimental/Training.csv' # dataset path
# Reading data using pandas or csv
df = pd.read_csv(file_name)
print(df.columns)
# Out:
# Index(['Time', 'Output Speed', 'Input Torque', 'Input Speed', 'Weight on bit'], dtype='object')

# %%
df
# Out:
#          Time  Output Speed  Input Torque  Input Speed  Weight on bit
# 0       0.000    148.157782      0.546254   104.776226     539.866525
# 1       0.001    148.870922      0.566799   105.120533     537.944529
# 2       0.002    149.556036      0.594301   106.241970     536.005967
# 3       0.003    150.212917      0.628518   108.393450     534.037938
# 4       0.004    150.841484      0.669332   109.377789     532.056127
# ...       ...           ...           ...          ...            ...
# 52995  52.995    141.525790      1.402770   102.036217     448.634747
# 52996  52.996    142.137385      1.391925   101.221814     447.199109
# 52997  52.997    142.726691      1.381913   100.893232     445.788984
# 52998  52.998    143.293376      1.372741   101.865686     444.418114
# 52999  52.999    143.837221      1.364316   102.100991     443.069257
#
# [53000 rows x 5 columns]

# %%
# Converting columns to numpy arrays for plotting
time = df[["Time"]].values.astype('float32')
output_speed = df[["Output Speed"]].values.astype('float32')
input_torque = df[["Input Torque"]].values.astype('float32')
input_speed = df[["Input Speed"]].values.astype('float32')
weight_on_bit = df[["Weight on bit"]].values.astype('float32')

# Plotting the dataset
fig, axs = plt.subplots(2, 2, figsize=(15, 9))

# Plot Input Speed
axs[0, 0].plot(time, input_speed, label='Input Speed')
axs[0, 0].set_title('Input Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Plot Input Torque
axs[0, 1].plot(time, input_torque, label='Input Torque')
axs[0, 1].set_title('Input Torque')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Torque (N-m)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Plot Output Speed
axs[1, 0].plot(time, output_speed, label='Output Speed')
axs[1, 0].set_title('Output Speed')
axs[1, 0].set_xlabel('Time (s)')
axs[1, 0].set_ylabel('Angular Speed (rad/s)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Plot Weight on Bit
axs[1, 1].plot(time, weight_on_bit, label='Weight on Bit')
axs[1, 1].set_title('Weight on Bit')
axs[1, 1].set_xlabel('Time (s)')
axs[1, 1].set_ylabel('Weight (kg)')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # **Pytorch LSTM Implementation**

# %% [markdown]
# # Pre-Processing the Training Data

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

xy = np.loadtxt('experimental/Training.csv', delimiter=",", dtype=np.object_, skiprows=1)

# Convert the data to a 2D NumPy array of floats
features = np.array(xy[:, 1:], dtype=np.float32)

from sklearn.preprocessing import MinMaxScaler
feature_scaler = MinMaxScaler(feature_range=(0,1))
scaled_features = feature_scaler.fit_transform(features)

# Convert the NumPy array to a PyTorch tensor
Training_set = torch.from_numpy(scaled_features).to(device)

print("=================Creating_Dataset==================\n", Training_set.shape, "\n")

set_to_scale_features = []
set_to_scale_labels = []

# # Loop through the array to create the feature and label sets
for i in range(30, Training_set.shape[0]):
    set_to_scale_features.append(Training_set[i-30:i, [1, 2]].cpu().numpy())
    set_to_scale_labels.append(Training_set[i, [0, 3]].cpu().numpy())

# # Convert lists to NumPy arrays
set_to_scale_features = np.array(set_to_scale_features)
set_to_scale_labels = np.array(set_to_scale_labels)


print("=================Creating Features and Labels==================\n", set_to_scale_features.shape, "\n", set_to_scale_labels.shape, "\n" )

# # Reshape the feature set
X_train = torch.from_numpy(set_to_scale_features.reshape(set_to_scale_features.shape[0], set_to_scale_features.shape[1], 2)).to(device)

# # Convert labels to PyTorch tensor
Y_train = torch.from_numpy(set_to_scale_labels.reshape(set_to_scale_labels.shape[0], 2)).to(device)

print("=================Converting Features and Labels to Tensors==================\n", X_train.shape, "\n", Y_train.shape, "\n" )

# set_to_scale_labels = set_to_scale_labels.unsqueeze(1)
# print("Unsqueezed the labels to combine", set_to_scale_labels.shape)
# Out:
# =================Creating_Dataset==================
#  torch.Size([53000, 4])
#
# =================Creating Features and Labels==================
#  (52970, 30, 2)
#  (52970, 2)
#
# =================Converting Features and Labels to Tensors==================
#  torch.Size([52970, 30, 2])
#  torch.Size([52970, 2])

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

xy = np.loadtxt('experimental/Testing.csv', delimiter=",", dtype=np.object_, skiprows=1)

# Convert the data to a 2D NumPy array of floats
test_features = np.array(xy[:, 1:], dtype=np.float32)

scaled_test_features = feature_scaler.transform(test_features)

# Convert the NumPy array to a PyTorch tensor
Testing_set = torch.from_numpy(scaled_test_features).to(device)

print("=================Creating_Dataset==================\n", Testing_set.shape, "\n")

set_to_scale_test_features = []
set_to_scale_test_labels = []

# # Loop through the array to create the feature and label sets
for i in range(30, Testing_set.shape[0]):
    set_to_scale_test_features.append(Testing_set[i-30:i, [1, 2]].cpu().numpy())
    set_to_scale_test_labels.append(Testing_set[i, [0, 3]].cpu().numpy())

# # Convert lists to NumPy arrays
set_to_scale_test_features = np.array(set_to_scale_test_features)
set_to_scale_test_labels = np.array(set_to_scale_test_labels)


print("=================Creating Features and Labels==================\n", set_to_scale_test_features.shape, "\n", set_to_scale_test_labels.shape, "\n" )

# # Reshape the feature set
X_test = torch.from_numpy(set_to_scale_test_features.reshape(set_to_scale_test_features.shape[0], set_to_scale_test_features.shape[1], 2)).to(device)

# # Convert labels to PyTorch tensor
Y_test = torch.from_numpy(set_to_scale_test_labels.reshape(set_to_scale_test_labels.shape[0], 2)).to(device)

print("=================Converting Features and Labels to Tensors==================\n", X_test.shape, "\n", Y_test.shape, "\n" )
# Out:
# =================Creating_Dataset==================
#  torch.Size([6000, 4])
#
# =================Creating Features and Labels==================
#  (5970, 30, 2)
#  (5970, 2)
#
# =================Converting Features and Labels to Tensors==================
#  torch.Size([5970, 30, 2])
#  torch.Size([5970, 2])

# %%
# # Creating dataset objects to process nn data through pytorch
from torch.utils.data import Dataset

class TSA(Dataset):
  def __init__(self, X, Y):
    self.X = X
    self.Y = Y

  def __getitem__(self, index) :
    return self.X[index], self.Y[index]

  def __len__(self):
    return len(self.X)

train_dataset = TSA(X_train, Y_train)
test_dataset = TSA(X_test, Y_test)

# train_dataset

# # Using data_loader to classify data in required format
from torch.utils.data import DataLoader

batch_size = 30

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# # Print the batch sizes to confirm
for _, batch in enumerate(train_loader):
  x_batch, y_batch = batch[0].to(device), batch[1].to(device)
  print(x_batch.shape, y_batch.shape)
  break
# Out:
# torch.Size([30, 30, 2]) torch.Size([30, 2])

# %% [markdown]
# # LSTM Training

# %%
import numpy as np
import torch
import torch.nn as nn

# Define the hyperparameters
input_size = 2
hidden_size = 120
num_stacked_layers = 5
fc_size1 = 140
fc_size2 = 280
fc_size3 = 360
output_size = 2
dropout = 0.1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ResidualLSTM(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.residual = nn.Linear(input_size, hidden_size) if input_size != hidden_size else nn.Identity()

    def forward(self, x):
        residual = self.residual(x)
        out, (hn, cn) = self.lstm(x)
        return out + residual, (hn, cn)

class ResidualFC(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.fc = nn.Linear(in_features, out_features)
        self.residual = nn.Linear(in_features, out_features) if in_features != out_features else nn.Identity()
        self.relu = nn.ReLU()

    def forward(self, x):
        residual = self.residual(x)
        out = self.fc(x)
        return self.relu(out + residual)

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers, dropout, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        # Stacked LSTM layers with residual connections
        self.lstm_layers = nn.ModuleList([
            ResidualLSTM(input_size if i == 0 else hidden_size, hidden_size)
            for i in range(num_stacked_layers)
        ])

        self.dropout = nn.Dropout(dropout)

        # Attention mechanism
        self.attention = nn.Sequential(
            nn.Linear(hidden_size, 1),
            nn.Tanh()
        )

        # Separate fully connected layers for each output with residual connections
        self.fc_output1 = nn.Sequential(
            ResidualFC(hidden_size, fc_size1),
            ResidualFC(fc_size1, fc_size2),
            ResidualFC(fc_size2, fc_size3),
            nn.Linear(fc_size3, 1)
        )

        self.fc_output2 = nn.Sequential(
            ResidualFC(hidden_size, fc_size1),
            ResidualFC(fc_size1, fc_size2),
            ResidualFC(fc_size2, fc_size3),
            nn.Linear(fc_size3, 1)
        )

    def forward(self, x):
        # Process through LSTM layers
        for lstm_layer in self.lstm_layers:
            x, _ = lstm_layer(x)

        # Apply attention mechanism
        attention_weights = self.attention(x).squeeze(-1)
        attention_weights = torch.softmax(attention_weights, dim=1)
        x_weighted = torch.sum(x * attention_weights.unsqueeze(-1), dim=1)

        x = self.dropout(x_weighted)

        # Apply separate fully connected layers for each output
        output1 = self.fc_output1(x)
        output2 = self.fc_output2(x)

        # Concatenate the outputs
        return torch.cat((output1, output2), dim=1)

# Initialize the model
model = LSTMModel(input_size, hidden_size, num_stacked_layers, dropout, output_size=output_size)
model.to(device)

# Print model summary
print(model)
# Out:
# LSTMModel(
#   (lstm_layers): ModuleList(
#     (0): ResidualLSTM(
#       (lstm): LSTM(2, 120, batch_first=True)
#       (residual): Linear(in_features=2, out_features=120, bias=True)
#     )
#     (1-4): 4 x ResidualLSTM(
#       (lstm): LSTM(120, 120, batch_first=True)
#       (residual): Identity()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (attention): Sequential(
#     (0): Linear(in_features=120, out_features=1, bias=True)
#     (1): Tanh()
#   )
#   (fc_output1): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
#   (fc_output2): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
# )

# %%
import torch.optim as optim
import time

learning_rate = 0.001
num_epochs = 20

best_val_loss = float('inf')
patience = 5
counter = 0

val_loss_list = []

# Define your loss function
loss_function = nn.MSELoss()

# Define your optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

start_time = time.time()
# Running epochs
for epoch in range(num_epochs):
    # Set model to training mode
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # print(batch_index)
        if batch_index % 2 == 1:
          avg_loss_across_batches = running_loss / 100
          print('Batch {0}, Loss: {1: .6f}, Epoch: {2}'.format(batch_index+1, avg_loss_across_batches, epoch+1))

# Validate every epoch
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
          output = model(x_batch)
          loss = loss_function(output, y_batch)
          running_loss += loss

    val_loss = running_loss / len(test_loader)
    print('Validation Loss {0: .3f}'.format(val_loss))

    print('###################################################')

    running_loss = 0.0

    val_loss_list.append(val_loss)

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping")
            print(val_loss_list)
            print("Best_Validation_Loss", best_val_loss)
            break

end_time = time.time()
# Save the model
model_save_path = 'model.pth'
torch.save(model.state_dict(), model_save_path)

print("Training time: ", end_time - start_time)
# Out:
# Epoch: 1
# Batch 2, Loss:  0.004358, Epoch: 1
# Batch 4, Loss:  0.005737, Epoch: 1
# Batch 6, Loss:  0.006607, Epoch: 1
# Batch 8, Loss:  0.007473, Epoch: 1
# Batch 10, Loss:  0.008094, Epoch: 1
# Batch 12, Loss:  0.008700, Epoch: 1
# Batch 14, Loss:  0.009330, Epoch: 1
# Batch 16, Loss:  0.009967, Epoch: 1
# Batch 18, Loss:  0.010576, Epoch: 1
# Batch 20, Loss:  0.011078, Epoch: 1
# Batch 22, Loss:  0.011689, Epoch: 1
# Batch 24, Loss:  0.012386, Epoch: 1
# Batch 26, Loss:  0.012931, Epoch: 1
# Batch 28, Loss:  0.013659, Epoch: 1
# Batch 30, Loss:  0.014146, Epoch: 1
# Batch 32, Loss:  0.014793, Epoch: 1
# Batch 34, Loss:  0.015338, Epoch: 1
# Batch 36, Loss:  0.015734, Epoch: 1
# Batch 38, Loss:  0.016415, Epoch: 1
# Batch 40, Loss:  0.016940, Epoch: 1
# Batch 42, Loss:  0.017413, Epoch: 1
# Batch 44, Loss:  0.017938, Epoch: 1
# Batch 46, Loss:  0.018445, Epoch: 1
# Batch 48, Loss:  0.018964, Epoch: 1
# Batch 50, Loss:  0.019626, Epoch: 1
# Batch 52, Loss:  0.020255, Epoch: 1
# Batch 54, Loss:  0.020823, Epoch: 1
# Batch 56, Loss:  0.021246, Epoch: 1
# Batch 58, Loss:  0.021748, Epoch: 1
# Batch 60, Loss:  0.022326, Epoch: 1
# Batch 62, Loss:  0.022906, Epoch: 1
# Batch 64, Loss:  0.023399, Epoch: 1
# Batch 66, Loss:  0.023921, Epoch: 1
# Batch 68, Loss:  0.024438, Epoch: 1
# Batch 70, Loss:  0.024902, Epoch: 1
# Batch 72, Loss:  0.025437, Epoch: 1
# Batch 74, Loss:  0.026022, Epoch: 1
# Batch 76, Loss:  0.026541, Epoch: 1
# Batch 78, Loss:  0.027118, Epoch: 1
# Batch 80, Loss:  0.027656, Epoch: 1
# Batch 82, Loss:  0.028195, Epoch: 1
# Batch 84, Loss:  0.028716, Epoch: 1
# Batch 86, Loss:  0.029175, Epoch: 1
# Batch 88, Loss:  0.029694, Epoch: 1
# Batch 90, Loss:  0.030150, Epoch: 1
# Batch 92, Loss:  0.030697, Epoch: 1
# Batch 94, Loss:  0.031240, Epoch: 1
# Batch 96, Loss:  0.031826, Epoch: 1
# Batch 98, Loss:  0.032302, Epoch: 1
# Batch 100, Loss:  0.032815, Epoch: 1
# Batch 102, Loss:  0.033351, Epoch: 1
# Batch 104, Loss:  0.033875, Epoch: 1
# Batch 106, Loss:  0.034411, Epoch: 1
# Batch 108, Loss:  0.034858, Epoch: 1
# Batch 110, Loss:  0.035417, Epoch: 1
# Batch 112, Loss:  0.035830, Epoch: 1
# Batch 114, Loss:  0.036345, Epoch: 1
# Batch 116, Loss:  0.036783, Epoch: 1
# Batch 118, Loss:  0.037354, Epoch: 1
# Batch 120, Loss:  0.037818, Epoch: 1
# Batch 122, Loss:  0.038278, Epoch: 1
# Batch 124, Loss:  0.038744, Epoch: 1
# Batch 126, Loss:  0.039372, Epoch: 1
# Batch 128, Loss:  0.039839, Epoch: 1
# Batch 130, Loss:  0.040410, Epoch: 1
# Batch 132, Loss:  0.040836, Epoch: 1
# Batch 134, Loss:  0.041220, Epoch: 1
# Batch 136, Loss:  0.041874, Epoch: 1
# Batch 138, Loss:  0.042444, Epoch: 1
# Batch 140, Loss:  0.043021, Epoch: 1
# Batch 142, Loss:  0.043362, Epoch: 1
# Batch 144, Loss:  0.043970, Epoch: 1
# Batch 146, Loss:  0.044416, Epoch: 1
# Batch 148, Loss:  0.044981, Epoch: 1
# Batch 150, Loss:  0.045513, Epoch: 1
# Batch 152, Loss:  0.046066, Epoch: 1
# Batch 154, Loss:  0.046629, Epoch: 1
# Batch 156, Loss:  0.047122, Epoch: 1
# Batch 158, Loss:  0.047590, Epoch: 1
# Batch 160, Loss:  0.048052, Epoch: 1
# Batch 162, Loss:  0.048449, Epoch: 1
# Batch 164, Loss:  0.049006, Epoch: 1
# Batch 166, Loss:  0.049479, Epoch: 1
# Batch 168, Loss:  0.049982, Epoch: 1
# Batch 170, Loss:  0.050504, Epoch: 1
# Batch 172, Loss:  0.050973, Epoch: 1
# Batch 174, Loss:  0.051365, Epoch: 1
# Batch 176, Loss:  0.051899, Epoch: 1
# Batch 178, Loss:  0.052332, Epoch: 1
# Batch 180, Loss:  0.052944, Epoch: 1
# Batch 182, Loss:  0.053404, Epoch: 1
# Batch 184, Loss:  0.053868, Epoch: 1
# Batch 186, Loss:  0.054330, Epoch: 1
# Batch 188, Loss:  0.054738, Epoch: 1
# Batch 190, Loss:  0.055247, Epoch: 1
# Batch 192, Loss:  0.055638, Epoch: 1
# Batch 194, Loss:  0.056031, Epoch: 1
# Batch 196, Loss:  0.056438, Epoch: 1
# Batch 198, Loss:  0.056942, Epoch: 1
# Batch 200, Loss:  0.057413, Epoch: 1
# Batch 202, Loss:  0.057868, Epoch: 1
# Batch 204, Loss:  0.058342, Epoch: 1
# Batch 206, Loss:  0.058814, Epoch: 1
# Batch 208, Loss:  0.059324, Epoch: 1
# Batch 210, Loss:  0.059781, Epoch: 1
# Batch 212, Loss:  0.060177, Epoch: 1
# Batch 214, Loss:  0.060670, Epoch: 1
# Batch 216, Loss:  0.061084, Epoch: 1
# Batch 218, Loss:  0.061530, Epoch: 1
# Batch 220, Loss:  0.061970, Epoch: 1
# Batch 222, Loss:  0.062452, Epoch: 1
# Batch 224, Loss:  0.063009, Epoch: 1
# Batch 226, Loss:  0.063468, Epoch: 1
# Batch 228, Loss:  0.063846, Epoch: 1
# Batch 230, Loss:  0.064239, Epoch: 1
# Batch 232, Loss:  0.064629, Epoch: 1
# Batch 234, Loss:  0.065043, Epoch: 1
# Batch 236, Loss:  0.065420, Epoch: 1
# Batch 238, Loss:  0.065793, Epoch: 1
# Batch 240, Loss:  0.066330, Epoch: 1
# Batch 242, Loss:  0.066842, Epoch: 1
# Batch 244, Loss:  0.067257, Epoch: 1
# Batch 246, Loss:  0.067790, Epoch: 1
# Batch 248, Loss:  0.068161, Epoch: 1
# Batch 250, Loss:  0.068595, Epoch: 1
# Batch 252, Loss:  0.069104, Epoch: 1
# Batch 254, Loss:  0.069558, Epoch: 1
# Batch 256, Loss:  0.070001, Epoch: 1
# Batch 258, Loss:  0.070426, Epoch: 1
# Batch 260, Loss:  0.070865, Epoch: 1
# Batch 262, Loss:  0.071220, Epoch: 1
# Batch 264, Loss:  0.071670, Epoch: 1
# Batch 266, Loss:  0.072056, Epoch: 1
# Batch 268, Loss:  0.072496, Epoch: 1
# Batch 270, Loss:  0.072862, Epoch: 1
# Batch 272, Loss:  0.073345, Epoch: 1
# Batch 274, Loss:  0.073854, Epoch: 1
# Batch 276, Loss:  0.074395, Epoch: 1
# Batch 278, Loss:  0.074860, Epoch: 1
# Batch 280, Loss:  0.075281, Epoch: 1
# Batch 282, Loss:  0.075658, Epoch: 1
# Batch 284, Loss:  0.076038, Epoch: 1
# Batch 286, Loss:  0.076601, Epoch: 1
# Batch 288, Loss:  0.077190, Epoch: 1
# Batch 290, Loss:  0.077625, Epoch: 1
# Batch 292, Loss:  0.078092, Epoch: 1
# Batch 294, Loss:  0.078564, Epoch: 1
# Batch 296, Loss:  0.079017, Epoch: 1
# Batch 298, Loss:  0.079457, Epoch: 1
# Batch 300, Loss:  0.079963, Epoch: 1
# Batch 302, Loss:  0.080404, Epoch: 1
# Batch 304, Loss:  0.080818, Epoch: 1
# Batch 306, Loss:  0.081274, Epoch: 1
# Batch 308, Loss:  0.081792, Epoch: 1
# Batch 310, Loss:  0.082233, Epoch: 1
# Batch 312, Loss:  0.082763, Epoch: 1
# Batch 314, Loss:  0.083123, Epoch: 1
# Batch 316, Loss:  0.083566, Epoch: 1
# Batch 318, Loss:  0.083956, Epoch: 1
# Batch 320, Loss:  0.084384, Epoch: 1
# Batch 322, Loss:  0.084739, Epoch: 1
# Batch 324, Loss:  0.085210, Epoch: 1
# Batch 326, Loss:  0.085771, Epoch: 1
# Batch 328, Loss:  0.086143, Epoch: 1
# Batch 330, Loss:  0.086534, Epoch: 1
# Batch 332, Loss:  0.086984, Epoch: 1
# Batch 334, Loss:  0.087528, Epoch: 1
# Batch 336, Loss:  0.088011, Epoch: 1
# Batch 338, Loss:  0.088461, Epoch: 1
# Batch 340, Loss:  0.088839, Epoch: 1
# Batch 342, Loss:  0.089278, Epoch: 1
# Batch 344, Loss:  0.089693, Epoch: 1
# Batch 346, Loss:  0.090220, Epoch: 1
# Batch 348, Loss:  0.090557, Epoch: 1
# Batch 350, Loss:  0.090991, Epoch: 1
# Batch 352, Loss:  0.091421, Epoch: 1
# Batch 354, Loss:  0.091856, Epoch: 1
# Batch 356, Loss:  0.092223, Epoch: 1
# Batch 358, Loss:  0.092724, Epoch: 1
# Batch 360, Loss:  0.093081, Epoch: 1
# Batch 362, Loss:  0.093519, Epoch: 1
# Batch 364, Loss:  0.093855, Epoch: 1
# Batch 366, Loss:  0.094163, Epoch: 1
# Batch 368, Loss:  0.094517, Epoch: 1
# Batch 370, Loss:  0.094951, Epoch: 1
# Batch 372, Loss:  0.095258, Epoch: 1
# Batch 374, Loss:  0.095612, Epoch: 1
# Batch 376, Loss:  0.096050, Epoch: 1
# Batch 378, Loss:  0.096480, Epoch: 1
# Batch 380, Loss:  0.096870, Epoch: 1
# Batch 382, Loss:  0.097270, Epoch: 1
# Batch 384, Loss:  0.097748, Epoch: 1
# Batch 386, Loss:  0.098150, Epoch: 1
# Batch 388, Loss:  0.098602, Epoch: 1
# Batch 390, Loss:  0.099048, Epoch: 1
# Batch 392, Loss:  0.099454, Epoch: 1
# Batch 394, Loss:  0.099818, Epoch: 1
# Batch 396, Loss:  0.100388, Epoch: 1
# Batch 398, Loss:  0.100757, Epoch: 1
# Batch 400, Loss:  0.101056, Epoch: 1
# Batch 402, Loss:  0.101393, Epoch: 1
# Batch 404, Loss:  0.101865, Epoch: 1
# Batch 406, Loss:  0.102207, Epoch: 1
# Batch 408, Loss:  0.102594, Epoch: 1
# Batch 410, Loss:  0.102975, Epoch: 1
# Batch 412, Loss:  0.103393, Epoch: 1
# Batch 414, Loss:  0.103710, Epoch: 1
# Batch 416, Loss:  0.104106, Epoch: 1
# Batch 418, Loss:  0.104440, Epoch: 1
# Batch 420, Loss:  0.104809, Epoch: 1
# Batch 422, Loss:  0.105308, Epoch: 1
# Batch 424, Loss:  0.105728, Epoch: 1
# Batch 426, Loss:  0.106066, Epoch: 1
# Batch 428, Loss:  0.106412, Epoch: 1
# Batch 430, Loss:  0.106804, Epoch: 1
# Batch 432, Loss:  0.107132, Epoch: 1
# Batch 434, Loss:  0.107538, Epoch: 1
# Batch 436, Loss:  0.107948, Epoch: 1
# Batch 438, Loss:  0.108323, Epoch: 1
# Batch 440, Loss:  0.108653, Epoch: 1
# Batch 442, Loss:  0.108989, Epoch: 1
# Batch 444, Loss:  0.109372, Epoch: 1
# Batch 446, Loss:  0.109656, Epoch: 1
# Batch 448, Loss:  0.110058, Epoch: 1
# Batch 450, Loss:  0.110439, Epoch: 1
# Batch 452, Loss:  0.110822, Epoch: 1
# Batch 454, Loss:  0.111248, Epoch: 1
# Batch 456, Loss:  0.111643, Epoch: 1
# Batch 458, Loss:  0.112063, Epoch: 1
# Batch 460, Loss:  0.112456, Epoch: 1
# Batch 462, Loss:  0.112856, Epoch: 1
# Batch 464, Loss:  0.113316, Epoch: 1
# Batch 466, Loss:  0.113569, Epoch: 1
# Batch 468, Loss:  0.113930, Epoch: 1
# Batch 470, Loss:  0.114314, Epoch: 1
# Batch 472, Loss:  0.114684, Epoch: 1
# Batch 474, Loss:  0.115039, Epoch: 1
# Batch 476, Loss:  0.115349, Epoch: 1
# Batch 478, Loss:  0.115650, Epoch: 1
# Batch 480, Loss:  0.115965, Epoch: 1
# Batch 482, Loss:  0.116305, Epoch: 1
# Batch 484, Loss:  0.116717, Epoch: 1
# Batch 486, Loss:  0.117024, Epoch: 1
# Batch 488, Loss:  0.117361, Epoch: 1
# Batch 490, Loss:  0.117747, Epoch: 1
# Batch 492, Loss:  0.118015, Epoch: 1
# Batch 494, Loss:  0.118403, Epoch: 1
# Batch 496, Loss:  0.118748, Epoch: 1
# Batch 498, Loss:  0.119061, Epoch: 1
# Batch 500, Loss:  0.119322, Epoch: 1
# Batch 502, Loss:  0.119705, Epoch: 1
# Batch 504, Loss:  0.120025, Epoch: 1
# Batch 506, Loss:  0.120335, Epoch: 1
# Batch 508, Loss:  0.120696, Epoch: 1
# Batch 510, Loss:  0.121015, Epoch: 1
# Batch 512, Loss:  0.121458, Epoch: 1
# Batch 514, Loss:  0.121787, Epoch: 1
# Batch 516, Loss:  0.122197, Epoch: 1
# Batch 518, Loss:  0.122500, Epoch: 1
# Batch 520, Loss:  0.122828, Epoch: 1
# Batch 522, Loss:  0.123134, Epoch: 1
# Batch 524, Loss:  0.123511, Epoch: 1
# Batch 526, Loss:  0.123838, Epoch: 1
# Batch 528, Loss:  0.124165, Epoch: 1
# Batch 530, Loss:  0.124411, Epoch: 1
# Batch 532, Loss:  0.124715, Epoch: 1
# Batch 534, Loss:  0.125045, Epoch: 1
# Batch 536, Loss:  0.125347, Epoch: 1
# Batch 538, Loss:  0.125615, Epoch: 1
# Batch 540, Loss:  0.125965, Epoch: 1
# Batch 542, Loss:  0.126519, Epoch: 1
# Batch 544, Loss:  0.126890, Epoch: 1
# Batch 546, Loss:  0.127355, Epoch: 1
# Batch 548, Loss:  0.127763, Epoch: 1
# Batch 550, Loss:  0.128127, Epoch: 1
# Batch 552, Loss:  0.128417, Epoch: 1
# Batch 554, Loss:  0.128808, Epoch: 1
# Batch 556, Loss:  0.129214, Epoch: 1
# Batch 558, Loss:  0.129711, Epoch: 1
# Batch 560, Loss:  0.129981, Epoch: 1
# Batch 562, Loss:  0.130272, Epoch: 1
# Batch 564, Loss:  0.130592, Epoch: 1
# Batch 566, Loss:  0.130954, Epoch: 1
# Batch 568, Loss:  0.131316, Epoch: 1
# Batch 570, Loss:  0.131627, Epoch: 1
# Batch 572, Loss:  0.131951, Epoch: 1
# Batch 574, Loss:  0.132215, Epoch: 1
# Batch 576, Loss:  0.132629, Epoch: 1
# Batch 578, Loss:  0.133036, Epoch: 1
# Batch 580, Loss:  0.133320, Epoch: 1
# Batch 582, Loss:  0.133671, Epoch: 1
# Batch 584, Loss:  0.133954, Epoch: 1
# Batch 586, Loss:  0.134206, Epoch: 1
# Batch 588, Loss:  0.134605, Epoch: 1
# Batch 590, Loss:  0.134910, Epoch: 1
# Batch 592, Loss:  0.135226, Epoch: 1
# Batch 594, Loss:  0.135605, Epoch: 1
# Batch 596, Loss:  0.135841, Epoch: 1
# Batch 598, Loss:  0.136138, Epoch: 1
# Batch 600, Loss:  0.136405, Epoch: 1
# Batch 602, Loss:  0.136702, Epoch: 1
# Batch 604, Loss:  0.136972, Epoch: 1
# Batch 606, Loss:  0.137357, Epoch: 1
# Batch 608, Loss:  0.137629, Epoch: 1
# Batch 610, Loss:  0.137935, Epoch: 1
# Batch 612, Loss:  0.138198, Epoch: 1
# Batch 614, Loss:  0.138473, Epoch: 1
# Batch 616, Loss:  0.138716, Epoch: 1
# Batch 618, Loss:  0.138980, Epoch: 1
# Batch 620, Loss:  0.139224, Epoch: 1
# Batch 622, Loss:  0.139457, Epoch: 1
# Batch 624, Loss:  0.139694, Epoch: 1
# Batch 626, Loss:  0.139905, Epoch: 1
# Batch 628, Loss:  0.140155, Epoch: 1
# Batch 630, Loss:  0.140392, Epoch: 1
# Batch 632, Loss:  0.140687, Epoch: 1
# Batch 634, Loss:  0.140929, Epoch: 1
# Batch 636, Loss:  0.141182, Epoch: 1
# Batch 638, Loss:  0.141425, Epoch: 1
# Batch 640, Loss:  0.141666, Epoch: 1
# Batch 642, Loss:  0.141894, Epoch: 1
# Batch 644, Loss:  0.142121, Epoch: 1
# Batch 646, Loss:  0.142385, Epoch: 1
# Batch 648, Loss:  0.142584, Epoch: 1
# Batch 650, Loss:  0.142792, Epoch: 1
# Batch 652, Loss:  0.143059, Epoch: 1
# Batch 654, Loss:  0.143278, Epoch: 1
# Batch 656, Loss:  0.143577, Epoch: 1
# Batch 658, Loss:  0.143921, Epoch: 1
# Batch 660, Loss:  0.144226, Epoch: 1
# Batch 662, Loss:  0.144555, Epoch: 1
# Batch 664, Loss:  0.144768, Epoch: 1
# Batch 666, Loss:  0.145006, Epoch: 1
# Batch 668, Loss:  0.145261, Epoch: 1
# Batch 670, Loss:  0.145496, Epoch: 1
# Batch 672, Loss:  0.145719, Epoch: 1
# Batch 674, Loss:  0.145885, Epoch: 1
# Batch 676, Loss:  0.146139, Epoch: 1
# Batch 678, Loss:  0.146321, Epoch: 1
# Batch 680, Loss:  0.146486, Epoch: 1
# Batch 682, Loss:  0.146687, Epoch: 1
# Batch 684, Loss:  0.146844, Epoch: 1
# Batch 686, Loss:  0.147038, Epoch: 1
# Batch 688, Loss:  0.147203, Epoch: 1
# Batch 690, Loss:  0.147374, Epoch: 1
# Batch 692, Loss:  0.147527, Epoch: 1
# Batch 694, Loss:  0.147726, Epoch: 1
# Batch 696, Loss:  0.147863, Epoch: 1
# Batch 698, Loss:  0.148009, Epoch: 1
# Batch 700, Loss:  0.148166, Epoch: 1
# Batch 702, Loss:  0.148341, Epoch: 1
# Batch 704, Loss:  0.148592, Epoch: 1
# Batch 706, Loss:  0.148772, Epoch: 1
# Batch 708, Loss:  0.148951, Epoch: 1
# Batch 710, Loss:  0.149113, Epoch: 1
# Batch 712, Loss:  0.149303, Epoch: 1
# Batch 714, Loss:  0.149481, Epoch: 1
# Batch 716, Loss:  0.149657, Epoch: 1
# Batch 718, Loss:  0.149843, Epoch: 1
# Batch 720, Loss:  0.149998, Epoch: 1
# Batch 722, Loss:  0.150186, Epoch: 1
# Batch 724, Loss:  0.150391, Epoch: 1
# Batch 726, Loss:  0.150557, Epoch: 1
# Batch 728, Loss:  0.150734, Epoch: 1
# Batch 730, Loss:  0.150931, Epoch: 1
# Batch 732, Loss:  0.151066, Epoch: 1
# Batch 734, Loss:  0.151240, Epoch: 1
# Batch 736, Loss:  0.151404, Epoch: 1
# Batch 738, Loss:  0.151569, Epoch: 1
# Batch 740, Loss:  0.151686, Epoch: 1
# Batch 742, Loss:  0.151831, Epoch: 1
# Batch 744, Loss:  0.152013, Epoch: 1
# Batch 746, Loss:  0.152137, Epoch: 1
# Batch 748, Loss:  0.152276, Epoch: 1
# Batch 750, Loss:  0.152421, Epoch: 1
# Batch 752, Loss:  0.152624, Epoch: 1
# Batch 754, Loss:  0.152740, Epoch: 1
# Batch 756, Loss:  0.152927, Epoch: 1
# Batch 758, Loss:  0.153087, Epoch: 1
# Batch 760, Loss:  0.153198, Epoch: 1
# Batch 762, Loss:  0.153390, Epoch: 1
# Batch 764, Loss:  0.153539, Epoch: 1
# Batch 766, Loss:  0.153671, Epoch: 1
# Batch 768, Loss:  0.153793, Epoch: 1
# Batch 770, Loss:  0.153931, Epoch: 1
# Batch 772, Loss:  0.154060, Epoch: 1
# Batch 774, Loss:  0.154176, Epoch: 1
# Batch 776, Loss:  0.154343, Epoch: 1
# Batch 778, Loss:  0.154486, Epoch: 1
# Batch 780, Loss:  0.154677, Epoch: 1
# Batch 782, Loss:  0.154806, Epoch: 1
# Batch 784, Loss:  0.154975, Epoch: 1
# Batch 786, Loss:  0.155084, Epoch: 1
# Batch 788, Loss:  0.155241, Epoch: 1
# Batch 790, Loss:  0.155387, Epoch: 1
# Batch 792, Loss:  0.155548, Epoch: 1
# Batch 794, Loss:  0.155687, Epoch: 1
# Batch 796, Loss:  0.155864, Epoch: 1
# Batch 798, Loss:  0.155963, Epoch: 1
# Batch 800, Loss:  0.156175, Epoch: 1
# Batch 802, Loss:  0.156376, Epoch: 1
# Batch 804, Loss:  0.156535, Epoch: 1
# Batch 806, Loss:  0.156709, Epoch: 1
# Batch 808, Loss:  0.156847, Epoch: 1
# Batch 810, Loss:  0.156990, Epoch: 1
# Batch 812, Loss:  0.157158, Epoch: 1
# Batch 814, Loss:  0.157310, Epoch: 1
# Batch 816, Loss:  0.157489, Epoch: 1
# Batch 818, Loss:  0.157680, Epoch: 1
# Batch 820, Loss:  0.157826, Epoch: 1
# Batch 822, Loss:  0.158018, Epoch: 1
# Batch 824, Loss:  0.158196, Epoch: 1
# Batch 826, Loss:  0.158329, Epoch: 1
# Batch 828, Loss:  0.158457, Epoch: 1
# Batch 830, Loss:  0.158602, Epoch: 1
# Batch 832, Loss:  0.158769, Epoch: 1
# Batch 834, Loss:  0.158878, Epoch: 1
# Batch 836, Loss:  0.159013, Epoch: 1
# Batch 838, Loss:  0.159151, Epoch: 1
# Batch 840, Loss:  0.159256, Epoch: 1
# Batch 842, Loss:  0.159406, Epoch: 1
# Batch 844, Loss:  0.159575, Epoch: 1
# Batch 846, Loss:  0.159707, Epoch: 1
# Batch 848, Loss:  0.159870, Epoch: 1
# Batch 850, Loss:  0.160027, Epoch: 1
# Batch 852, Loss:  0.160198, Epoch: 1
# Batch 854, Loss:  0.160316, Epoch: 1
# Batch 856, Loss:  0.160450, Epoch: 1
# Batch 858, Loss:  0.160598, Epoch: 1
# Batch 860, Loss:  0.160788, Epoch: 1
# Batch 862, Loss:  0.160918, Epoch: 1
# Batch 864, Loss:  0.161068, Epoch: 1
# Batch 866, Loss:  0.161204, Epoch: 1
# Batch 868, Loss:  0.161365, Epoch: 1
# Batch 870, Loss:  0.161508, Epoch: 1
# Batch 872, Loss:  0.161643, Epoch: 1
# Batch 874, Loss:  0.161763, Epoch: 1
# Batch 876, Loss:  0.161910, Epoch: 1
# Batch 878, Loss:  0.162030, Epoch: 1
# Batch 880, Loss:  0.162166, Epoch: 1
# Batch 882, Loss:  0.162323, Epoch: 1
# Batch 884, Loss:  0.162493, Epoch: 1
# Batch 886, Loss:  0.162634, Epoch: 1
# Batch 888, Loss:  0.162765, Epoch: 1
# Batch 890, Loss:  0.162940, Epoch: 1
# Batch 892, Loss:  0.163101, Epoch: 1
# Batch 894, Loss:  0.163319, Epoch: 1
# Batch 896, Loss:  0.163468, Epoch: 1
# Batch 898, Loss:  0.163625, Epoch: 1
# Batch 900, Loss:  0.163758, Epoch: 1
# Batch 902, Loss:  0.163911, Epoch: 1
# Batch 904, Loss:  0.164077, Epoch: 1
# Batch 906, Loss:  0.164231, Epoch: 1
# Batch 908, Loss:  0.164390, Epoch: 1
# Batch 910, Loss:  0.164564, Epoch: 1
# Batch 912, Loss:  0.164700, Epoch: 1
# Batch 914, Loss:  0.164863, Epoch: 1
# Batch 916, Loss:  0.165004, Epoch: 1
# Batch 918, Loss:  0.165140, Epoch: 1
# Batch 920, Loss:  0.165280, Epoch: 1
# Batch 922, Loss:  0.165428, Epoch: 1
# Batch 924, Loss:  0.165565, Epoch: 1
# Batch 926, Loss:  0.165704, Epoch: 1
# Batch 928, Loss:  0.165864, Epoch: 1
# Batch 930, Loss:  0.166011, Epoch: 1
# Batch 932, Loss:  0.166114, Epoch: 1
# Batch 934, Loss:  0.166208, Epoch: 1
# Batch 936, Loss:  0.166368, Epoch: 1
# Batch 938, Loss:  0.166575, Epoch: 1
# Batch 940, Loss:  0.166736, Epoch: 1
# Batch 942, Loss:  0.166906, Epoch: 1
# Batch 944, Loss:  0.167055, Epoch: 1
# Batch 946, Loss:  0.167207, Epoch: 1
# Batch 948, Loss:  0.167379, Epoch: 1
# Batch 950, Loss:  0.167562, Epoch: 1
# Batch 952, Loss:  0.167703, Epoch: 1
# Batch 954, Loss:  0.167856, Epoch: 1
# Batch 956, Loss:  0.167994, Epoch: 1
# Batch 958, Loss:  0.168121, Epoch: 1
# Batch 960, Loss:  0.168308, Epoch: 1
# Batch 962, Loss:  0.168474, Epoch: 1
# Batch 964, Loss:  0.168656, Epoch: 1
# Batch 966, Loss:  0.168858, Epoch: 1
# Batch 968, Loss:  0.169008, Epoch: 1
# Batch 970, Loss:  0.169209, Epoch: 1
# Batch 972, Loss:  0.169376, Epoch: 1
# Batch 974, Loss:  0.169499, Epoch: 1
# Batch 976, Loss:  0.169663, Epoch: 1
# Batch 978, Loss:  0.169819, Epoch: 1
# Batch 980, Loss:  0.169929, Epoch: 1
# Batch 982, Loss:  0.170050, Epoch: 1
# Batch 984, Loss:  0.170190, Epoch: 1
# Batch 986, Loss:  0.170314, Epoch: 1
# Batch 988, Loss:  0.170483, Epoch: 1
# Batch 990, Loss:  0.170618, Epoch: 1
# Batch 992, Loss:  0.170731, Epoch: 1
# Batch 994, Loss:  0.170883, Epoch: 1
# Batch 996, Loss:  0.171027, Epoch: 1
# Batch 998, Loss:  0.171177, Epoch: 1
# Batch 1000, Loss:  0.171309, Epoch: 1
# Batch 1002, Loss:  0.171453, Epoch: 1
# Batch 1004, Loss:  0.171605, Epoch: 1
# Batch 1006, Loss:  0.171738, Epoch: 1
# Batch 1008, Loss:  0.171875, Epoch: 1
# Batch 1010, Loss:  0.172019, Epoch: 1
# Batch 1012, Loss:  0.172130, Epoch: 1
# Batch 1014, Loss:  0.172288, Epoch: 1
# Batch 1016, Loss:  0.172409, Epoch: 1
# Batch 1018, Loss:  0.172549, Epoch: 1
# Batch 1020, Loss:  0.172672, Epoch: 1
# Batch 1022, Loss:  0.172776, Epoch: 1
# Batch 1024, Loss:  0.172889, Epoch: 1
# Batch 1026, Loss:  0.172989, Epoch: 1
# Batch 1028, Loss:  0.173113, Epoch: 1
# Batch 1030, Loss:  0.173232, Epoch: 1
# Batch 1032, Loss:  0.173315, Epoch: 1
# Batch 1034, Loss:  0.173442, Epoch: 1
# Batch 1036, Loss:  0.173557, Epoch: 1
# Batch 1038, Loss:  0.173678, Epoch: 1
# Batch 1040, Loss:  0.173781, Epoch: 1
# Batch 1042, Loss:  0.173944, Epoch: 1
# Batch 1044, Loss:  0.174066, Epoch: 1
# Batch 1046, Loss:  0.174218, Epoch: 1
# Batch 1048, Loss:  0.174339, Epoch: 1
# Batch 1050, Loss:  0.174452, Epoch: 1
# Batch 1052, Loss:  0.174580, Epoch: 1
# Batch 1054, Loss:  0.174738, Epoch: 1
# Batch 1056, Loss:  0.174873, Epoch: 1
# Batch 1058, Loss:  0.175028, Epoch: 1
# Batch 1060, Loss:  0.175150, Epoch: 1
# Batch 1062, Loss:  0.175277, Epoch: 1
# Batch 1064, Loss:  0.175379, Epoch: 1
# Batch 1066, Loss:  0.175549, Epoch: 1
# Batch 1068, Loss:  0.175697, Epoch: 1
# Batch 1070, Loss:  0.175813, Epoch: 1
# Batch 1072, Loss:  0.175939, Epoch: 1
# Batch 1074, Loss:  0.176100, Epoch: 1
# Batch 1076, Loss:  0.176241, Epoch: 1
# Batch 1078, Loss:  0.176417, Epoch: 1
# Batch 1080, Loss:  0.176518, Epoch: 1
# Batch 1082, Loss:  0.176628, Epoch: 1
# Batch 1084, Loss:  0.176800, Epoch: 1
# Batch 1086, Loss:  0.176941, Epoch: 1
# Batch 1088, Loss:  0.177116, Epoch: 1
# Batch 1090, Loss:  0.177243, Epoch: 1
# Batch 1092, Loss:  0.177406, Epoch: 1
# Batch 1094, Loss:  0.177540, Epoch: 1
# Batch 1096, Loss:  0.177676, Epoch: 1
# Batch 1098, Loss:  0.177819, Epoch: 1
# Batch 1100, Loss:  0.177989, Epoch: 1
# Batch 1102, Loss:  0.178122, Epoch: 1
# Batch 1104, Loss:  0.178242, Epoch: 1
# Batch 1106, Loss:  0.178370, Epoch: 1
# Batch 1108, Loss:  0.178485, Epoch: 1
# Batch 1110, Loss:  0.178661, Epoch: 1
# Batch 1112, Loss:  0.178808, Epoch: 1
# Batch 1114, Loss:  0.178958, Epoch: 1
# Batch 1116, Loss:  0.179101, Epoch: 1
# Batch 1118, Loss:  0.179267, Epoch: 1
# Batch 1120, Loss:  0.179429, Epoch: 1
# Batch 1122, Loss:  0.179559, Epoch: 1
# Batch 1124, Loss:  0.179715, Epoch: 1
# Batch 1126, Loss:  0.179855, Epoch: 1
# Batch 1128, Loss:  0.180004, Epoch: 1
# Batch 1130, Loss:  0.180129, Epoch: 1
# Batch 1132, Loss:  0.180271, Epoch: 1
# Batch 1134, Loss:  0.180405, Epoch: 1
# Batch 1136, Loss:  0.180553, Epoch: 1
# Batch 1138, Loss:  0.180683, Epoch: 1
# Batch 1140, Loss:  0.180815, Epoch: 1
# Batch 1142, Loss:  0.180996, Epoch: 1
# Batch 1144, Loss:  0.181110, Epoch: 1
# Batch 1146, Loss:  0.181216, Epoch: 1
# Batch 1148, Loss:  0.181394, Epoch: 1
# Batch 1150, Loss:  0.181503, Epoch: 1
# Batch 1152, Loss:  0.181644, Epoch: 1
# Batch 1154, Loss:  0.181769, Epoch: 1
# Batch 1156, Loss:  0.181903, Epoch: 1
# Batch 1158, Loss:  0.182029, Epoch: 1
# Batch 1160, Loss:  0.182163, Epoch: 1
# Batch 1162, Loss:  0.182275, Epoch: 1
# Batch 1164, Loss:  0.182425, Epoch: 1
# Batch 1166, Loss:  0.182581, Epoch: 1
# Batch 1168, Loss:  0.182714, Epoch: 1
# Batch 1170, Loss:  0.182810, Epoch: 1
# Batch 1172, Loss:  0.182925, Epoch: 1
# Batch 1174, Loss:  0.183089, Epoch: 1
# Batch 1176, Loss:  0.183225, Epoch: 1
# Batch 1178, Loss:  0.183348, Epoch: 1
# Batch 1180, Loss:  0.183510, Epoch: 1
# Batch 1182, Loss:  0.183647, Epoch: 1
# Batch 1184, Loss:  0.183762, Epoch: 1
# Batch 1186, Loss:  0.183909, Epoch: 1
# Batch 1188, Loss:  0.184034, Epoch: 1
# Batch 1190, Loss:  0.184202, Epoch: 1
# Batch 1192, Loss:  0.184385, Epoch: 1
# Batch 1194, Loss:  0.184504, Epoch: 1
# Batch 1196, Loss:  0.184647, Epoch: 1
# Batch 1198, Loss:  0.184781, Epoch: 1
# Batch 1200, Loss:  0.184907, Epoch: 1
# Batch 1202, Loss:  0.185036, Epoch: 1
# Batch 1204, Loss:  0.185153, Epoch: 1
# Batch 1206, Loss:  0.185269, Epoch: 1
# Batch 1208, Loss:  0.185388, Epoch: 1
# Batch 1210, Loss:  0.185517, Epoch: 1
# Batch 1212, Loss:  0.185660, Epoch: 1
# Batch 1214, Loss:  0.185808, Epoch: 1
# Batch 1216, Loss:  0.185948, Epoch: 1
# Batch 1218, Loss:  0.186108, Epoch: 1
# Batch 1220, Loss:  0.186252, Epoch: 1
# Batch 1222, Loss:  0.186401, Epoch: 1
# Batch 1224, Loss:  0.186526, Epoch: 1
# Batch 1226, Loss:  0.186634, Epoch: 1
# Batch 1228, Loss:  0.186775, Epoch: 1
# Batch 1230, Loss:  0.186911, Epoch: 1
# Batch 1232, Loss:  0.187095, Epoch: 1
# Batch 1234, Loss:  0.187258, Epoch: 1
# Batch 1236, Loss:  0.187366, Epoch: 1
# Batch 1238, Loss:  0.187461, Epoch: 1
# Batch 1240, Loss:  0.187587, Epoch: 1
# Batch 1242, Loss:  0.187732, Epoch: 1
# Batch 1244, Loss:  0.187917, Epoch: 1
# Batch 1246, Loss:  0.188051, Epoch: 1
# Batch 1248, Loss:  0.188162, Epoch: 1
# Batch 1250, Loss:  0.188311, Epoch: 1
# Batch 1252, Loss:  0.188453, Epoch: 1
# Batch 1254, Loss:  0.188575, Epoch: 1
# Batch 1256, Loss:  0.188671, Epoch: 1
# Batch 1258, Loss:  0.188794, Epoch: 1
# Batch 1260, Loss:  0.188925, Epoch: 1
# Batch 1262, Loss:  0.189051, Epoch: 1
# Batch 1264, Loss:  0.189180, Epoch: 1
# Batch 1266, Loss:  0.189347, Epoch: 1
# Batch 1268, Loss:  0.189483, Epoch: 1
# Batch 1270, Loss:  0.189601, Epoch: 1
# Batch 1272, Loss:  0.189745, Epoch: 1
# Batch 1274, Loss:  0.189871, Epoch: 1
# Batch 1276, Loss:  0.189997, Epoch: 1
# Batch 1278, Loss:  0.190114, Epoch: 1
# Batch 1280, Loss:  0.190263, Epoch: 1
# Batch 1282, Loss:  0.190396, Epoch: 1
# Batch 1284, Loss:  0.190589, Epoch: 1
# Batch 1286, Loss:  0.190756, Epoch: 1
# Batch 1288, Loss:  0.190875, Epoch: 1
# Batch 1290, Loss:  0.191087, Epoch: 1
# Batch 1292, Loss:  0.191218, Epoch: 1
# Batch 1294, Loss:  0.191350, Epoch: 1
# Batch 1296, Loss:  0.191536, Epoch: 1
# Batch 1298, Loss:  0.191651, Epoch: 1
# Batch 1300, Loss:  0.191806, Epoch: 1
# Batch 1302, Loss:  0.191950, Epoch: 1
# Batch 1304, Loss:  0.192102, Epoch: 1
# Batch 1306, Loss:  0.192259, Epoch: 1
# Batch 1308, Loss:  0.192383, Epoch: 1
# Batch 1310, Loss:  0.192542, Epoch: 1
# Batch 1312, Loss:  0.192683, Epoch: 1
# Batch 1314, Loss:  0.192812, Epoch: 1
# Batch 1316, Loss:  0.192975, Epoch: 1
# Batch 1318, Loss:  0.193119, Epoch: 1
# Batch 1320, Loss:  0.193257, Epoch: 1
# Batch 1322, Loss:  0.193365, Epoch: 1
# Batch 1324, Loss:  0.193492, Epoch: 1
# Batch 1326, Loss:  0.193647, Epoch: 1
# Batch 1328, Loss:  0.193814, Epoch: 1
# Batch 1330, Loss:  0.193966, Epoch: 1
# Batch 1332, Loss:  0.194125, Epoch: 1
# Batch 1334, Loss:  0.194274, Epoch: 1
# Batch 1336, Loss:  0.194420, Epoch: 1
# Batch 1338, Loss:  0.194555, Epoch: 1
# Batch 1340, Loss:  0.194666, Epoch: 1
# Batch 1342, Loss:  0.194800, Epoch: 1
# Batch 1344, Loss:  0.194896, Epoch: 1
# Batch 1346, Loss:  0.195052, Epoch: 1
# Batch 1348, Loss:  0.195178, Epoch: 1
# Batch 1350, Loss:  0.195325, Epoch: 1
# Batch 1352, Loss:  0.195451, Epoch: 1
# Batch 1354, Loss:  0.195594, Epoch: 1
# Batch 1356, Loss:  0.195741, Epoch: 1
# Batch 1358, Loss:  0.195866, Epoch: 1
# Batch 1360, Loss:  0.195996, Epoch: 1
# Batch 1362, Loss:  0.196118, Epoch: 1
# Batch 1364, Loss:  0.196235, Epoch: 1
# Batch 1366, Loss:  0.196407, Epoch: 1
# Batch 1368, Loss:  0.196528, Epoch: 1
# Batch 1370, Loss:  0.196636, Epoch: 1
# Batch 1372, Loss:  0.196775, Epoch: 1
# Batch 1374, Loss:  0.196943, Epoch: 1
# Batch 1376, Loss:  0.197067, Epoch: 1
# Batch 1378, Loss:  0.197192, Epoch: 1
# Batch 1380, Loss:  0.197362, Epoch: 1
# Batch 1382, Loss:  0.197494, Epoch: 1
# Batch 1384, Loss:  0.197615, Epoch: 1
# Batch 1386, Loss:  0.197719, Epoch: 1
# Batch 1388, Loss:  0.197882, Epoch: 1
# Batch 1390, Loss:  0.198011, Epoch: 1
# Batch 1392, Loss:  0.198157, Epoch: 1
# Batch 1394, Loss:  0.198291, Epoch: 1
# Batch 1396, Loss:  0.198406, Epoch: 1
# Batch 1398, Loss:  0.198537, Epoch: 1
# Batch 1400, Loss:  0.198644, Epoch: 1
# Batch 1402, Loss:  0.198784, Epoch: 1
# Batch 1404, Loss:  0.198914, Epoch: 1
# Batch 1406, Loss:  0.199059, Epoch: 1
# Batch 1408, Loss:  0.199220, Epoch: 1
# Batch 1410, Loss:  0.199376, Epoch: 1
# Batch 1412, Loss:  0.199550, Epoch: 1
# Batch 1414, Loss:  0.199697, Epoch: 1
# Batch 1416, Loss:  0.199803, Epoch: 1
# Batch 1418, Loss:  0.199920, Epoch: 1
# Batch 1420, Loss:  0.200017, Epoch: 1
# Batch 1422, Loss:  0.200129, Epoch: 1
# Batch 1424, Loss:  0.200246, Epoch: 1
# Batch 1426, Loss:  0.200371, Epoch: 1
# Batch 1428, Loss:  0.200482, Epoch: 1
# Batch 1430, Loss:  0.200586, Epoch: 1
# Batch 1432, Loss:  0.200695, Epoch: 1
# Batch 1434, Loss:  0.200827, Epoch: 1
# Batch 1436, Loss:  0.200916, Epoch: 1
# Batch 1438, Loss:  0.201046, Epoch: 1
# Batch 1440, Loss:  0.201182, Epoch: 1
# Batch 1442, Loss:  0.201319, Epoch: 1
# Batch 1444, Loss:  0.201425, Epoch: 1
# Batch 1446, Loss:  0.201573, Epoch: 1
# Batch 1448, Loss:  0.201691, Epoch: 1
# Batch 1450, Loss:  0.201848, Epoch: 1
# Batch 1452, Loss:  0.202006, Epoch: 1
# Batch 1454, Loss:  0.202126, Epoch: 1
# Batch 1456, Loss:  0.202266, Epoch: 1
# Batch 1458, Loss:  0.202411, Epoch: 1
# Batch 1460, Loss:  0.202572, Epoch: 1
# Batch 1462, Loss:  0.202717, Epoch: 1
# Batch 1464, Loss:  0.202848, Epoch: 1
# Batch 1466, Loss:  0.202950, Epoch: 1
# Batch 1468, Loss:  0.203062, Epoch: 1
# Batch 1470, Loss:  0.203165, Epoch: 1
# Batch 1472, Loss:  0.203298, Epoch: 1
# Batch 1474, Loss:  0.203456, Epoch: 1
# Batch 1476, Loss:  0.203604, Epoch: 1
# Batch 1478, Loss:  0.203726, Epoch: 1
# Batch 1480, Loss:  0.203839, Epoch: 1
# Batch 1482, Loss:  0.203929, Epoch: 1
# Batch 1484, Loss:  0.204075, Epoch: 1
# Batch 1486, Loss:  0.204163, Epoch: 1
# Batch 1488, Loss:  0.204292, Epoch: 1
# Batch 1490, Loss:  0.204428, Epoch: 1
# Batch 1492, Loss:  0.204521, Epoch: 1
# Batch 1494, Loss:  0.204683, Epoch: 1
# Batch 1496, Loss:  0.204845, Epoch: 1
# Batch 1498, Loss:  0.204992, Epoch: 1
# Batch 1500, Loss:  0.205150, Epoch: 1
# Batch 1502, Loss:  0.205266, Epoch: 1
# Batch 1504, Loss:  0.205418, Epoch: 1
# Batch 1506, Loss:  0.205571, Epoch: 1
# Batch 1508, Loss:  0.205700, Epoch: 1
# Batch 1510, Loss:  0.205844, Epoch: 1
# Batch 1512, Loss:  0.205968, Epoch: 1
# Batch 1514, Loss:  0.206136, Epoch: 1
# Batch 1516, Loss:  0.206243, Epoch: 1
# Batch 1518, Loss:  0.206414, Epoch: 1
# Batch 1520, Loss:  0.206544, Epoch: 1
# Batch 1522, Loss:  0.206670, Epoch: 1
# Batch 1524, Loss:  0.206760, Epoch: 1
# Batch 1526, Loss:  0.206900, Epoch: 1
# Batch 1528, Loss:  0.207033, Epoch: 1
# Batch 1530, Loss:  0.207163, Epoch: 1
# Batch 1532, Loss:  0.207259, Epoch: 1
# Batch 1534, Loss:  0.207360, Epoch: 1
# Batch 1536, Loss:  0.207506, Epoch: 1
# Batch 1538, Loss:  0.207633, Epoch: 1
# Batch 1540, Loss:  0.207763, Epoch: 1
# Batch 1542, Loss:  0.207854, Epoch: 1
# Batch 1544, Loss:  0.208014, Epoch: 1
# Batch 1546, Loss:  0.208191, Epoch: 1
# Batch 1548, Loss:  0.208322, Epoch: 1
# Batch 1550, Loss:  0.208431, Epoch: 1
# Batch 1552, Loss:  0.208572, Epoch: 1
# Batch 1554, Loss:  0.208711, Epoch: 1
# Batch 1556, Loss:  0.208851, Epoch: 1
# Batch 1558, Loss:  0.208984, Epoch: 1
# Batch 1560, Loss:  0.209118, Epoch: 1
# Batch 1562, Loss:  0.209262, Epoch: 1
# Batch 1564, Loss:  0.209361, Epoch: 1
# Batch 1566, Loss:  0.209529, Epoch: 1
# Batch 1568, Loss:  0.209628, Epoch: 1
# Batch 1570, Loss:  0.209762, Epoch: 1
# Batch 1572, Loss:  0.209925, Epoch: 1
# Batch 1574, Loss:  0.210046, Epoch: 1
# Batch 1576, Loss:  0.210193, Epoch: 1
# Batch 1578, Loss:  0.210330, Epoch: 1
# Batch 1580, Loss:  0.210435, Epoch: 1
# Batch 1582, Loss:  0.210584, Epoch: 1
# Batch 1584, Loss:  0.210709, Epoch: 1
# Batch 1586, Loss:  0.210815, Epoch: 1
# Batch 1588, Loss:  0.210981, Epoch: 1
# Batch 1590, Loss:  0.211098, Epoch: 1
# Batch 1592, Loss:  0.211201, Epoch: 1
# Batch 1594, Loss:  0.211315, Epoch: 1
# Batch 1596, Loss:  0.211442, Epoch: 1
# Batch 1598, Loss:  0.211526, Epoch: 1
# Batch 1600, Loss:  0.211647, Epoch: 1
# Batch 1602, Loss:  0.211765, Epoch: 1
# Batch 1604, Loss:  0.211898, Epoch: 1
# Batch 1606, Loss:  0.212039, Epoch: 1
# Batch 1608, Loss:  0.212170, Epoch: 1
# Batch 1610, Loss:  0.212292, Epoch: 1
# Batch 1612, Loss:  0.212391, Epoch: 1
# Batch 1614, Loss:  0.212524, Epoch: 1
# Batch 1616, Loss:  0.212631, Epoch: 1
# Batch 1618, Loss:  0.212729, Epoch: 1
# Batch 1620, Loss:  0.212837, Epoch: 1
# Batch 1622, Loss:  0.212984, Epoch: 1
# Batch 1624, Loss:  0.213089, Epoch: 1
# Batch 1626, Loss:  0.213239, Epoch: 1
# Batch 1628, Loss:  0.213315, Epoch: 1
# Batch 1630, Loss:  0.213427, Epoch: 1
# Batch 1632, Loss:  0.213530, Epoch: 1
# Batch 1634, Loss:  0.213657, Epoch: 1
# Batch 1636, Loss:  0.213785, Epoch: 1
# Batch 1638, Loss:  0.213915, Epoch: 1
# Batch 1640, Loss:  0.214034, Epoch: 1
# Batch 1642, Loss:  0.214144, Epoch: 1
# Batch 1644, Loss:  0.214281, Epoch: 1
# Batch 1646, Loss:  0.214411, Epoch: 1
# Batch 1648, Loss:  0.214578, Epoch: 1
# Batch 1650, Loss:  0.214668, Epoch: 1
# Batch 1652, Loss:  0.214791, Epoch: 1
# Batch 1654, Loss:  0.214892, Epoch: 1
# Batch 1656, Loss:  0.215000, Epoch: 1
# Batch 1658, Loss:  0.215113, Epoch: 1
# Batch 1660, Loss:  0.215256, Epoch: 1
# Batch 1662, Loss:  0.215377, Epoch: 1
# Batch 1664, Loss:  0.215501, Epoch: 1
# Batch 1666, Loss:  0.215614, Epoch: 1
# Batch 1668, Loss:  0.215754, Epoch: 1
# Batch 1670, Loss:  0.215897, Epoch: 1
# Batch 1672, Loss:  0.216035, Epoch: 1
# Batch 1674, Loss:  0.216168, Epoch: 1
# Batch 1676, Loss:  0.216286, Epoch: 1
# Batch 1678, Loss:  0.216424, Epoch: 1
# Batch 1680, Loss:  0.216566, Epoch: 1
# Batch 1682, Loss:  0.216697, Epoch: 1
# Batch 1684, Loss:  0.216870, Epoch: 1
# Batch 1686, Loss:  0.216962, Epoch: 1
# Batch 1688, Loss:  0.217117, Epoch: 1
# Batch 1690, Loss:  0.217285, Epoch: 1
# Batch 1692, Loss:  0.217418, Epoch: 1
# Batch 1694, Loss:  0.217541, Epoch: 1
# Batch 1696, Loss:  0.217701, Epoch: 1
# Batch 1698, Loss:  0.217829, Epoch: 1
# Batch 1700, Loss:  0.217977, Epoch: 1
# Batch 1702, Loss:  0.218117, Epoch: 1
# Batch 1704, Loss:  0.218288, Epoch: 1
# Batch 1706, Loss:  0.218443, Epoch: 1
# Batch 1708, Loss:  0.218580, Epoch: 1
# Batch 1710, Loss:  0.218741, Epoch: 1
# Batch 1712, Loss:  0.218857, Epoch: 1
# Batch 1714, Loss:  0.218985, Epoch: 1
# Batch 1716, Loss:  0.219134, Epoch: 1
# Batch 1718, Loss:  0.219282, Epoch: 1
# Batch 1720, Loss:  0.219435, Epoch: 1
# Batch 1722, Loss:  0.219622, Epoch: 1
# Batch 1724, Loss:  0.219749, Epoch: 1
# Batch 1726, Loss:  0.219909, Epoch: 1
# Batch 1728, Loss:  0.220052, Epoch: 1
# Batch 1730, Loss:  0.220192, Epoch: 1
# Batch 1732, Loss:  0.220305, Epoch: 1
# Batch 1734, Loss:  0.220443, Epoch: 1
# Batch 1736, Loss:  0.220568, Epoch: 1
# Batch 1738, Loss:  0.220714, Epoch: 1
# Batch 1740, Loss:  0.220838, Epoch: 1
# Batch 1742, Loss:  0.220963, Epoch: 1
# Batch 1744, Loss:  0.221094, Epoch: 1
# Batch 1746, Loss:  0.221217, Epoch: 1
# Batch 1748, Loss:  0.221342, Epoch: 1
# Batch 1750, Loss:  0.221463, Epoch: 1
# Batch 1752, Loss:  0.221589, Epoch: 1
# Batch 1754, Loss:  0.221754, Epoch: 1
# Batch 1756, Loss:  0.221876, Epoch: 1
# Batch 1758, Loss:  0.222051, Epoch: 1
# Batch 1760, Loss:  0.222233, Epoch: 1
# Batch 1762, Loss:  0.222352, Epoch: 1
# Batch 1764, Loss:  0.222477, Epoch: 1
# Batch 1766, Loss:  0.222600, Epoch: 1
# Validation Loss  0.009
# ###################################################
# Epoch: 2
# Batch 2, Loss:  0.000193, Epoch: 2
# Batch 4, Loss:  0.000364, Epoch: 2
# Batch 6, Loss:  0.000501, Epoch: 2
# Batch 8, Loss:  0.000651, Epoch: 2
# Batch 10, Loss:  0.000817, Epoch: 2
# Batch 12, Loss:  0.000987, Epoch: 2
# Batch 14, Loss:  0.001126, Epoch: 2
# Batch 16, Loss:  0.001249, Epoch: 2
# Batch 18, Loss:  0.001428, Epoch: 2
# Batch 20, Loss:  0.001559, Epoch: 2
# Batch 22, Loss:  0.001681, Epoch: 2
# Batch 24, Loss:  0.001791, Epoch: 2
# Batch 26, Loss:  0.001921, Epoch: 2
# Batch 28, Loss:  0.002056, Epoch: 2
# Batch 30, Loss:  0.002208, Epoch: 2
# Batch 32, Loss:  0.002365, Epoch: 2
# Batch 34, Loss:  0.002502, Epoch: 2
# Batch 36, Loss:  0.002657, Epoch: 2
# Batch 38, Loss:  0.002794, Epoch: 2
# Batch 40, Loss:  0.002920, Epoch: 2
# Batch 42, Loss:  0.003053, Epoch: 2
# Batch 44, Loss:  0.003186, Epoch: 2
# Batch 46, Loss:  0.003292, Epoch: 2
# Batch 48, Loss:  0.003403, Epoch: 2
# Batch 50, Loss:  0.003532, Epoch: 2
# Batch 52, Loss:  0.003682, Epoch: 2
# Batch 54, Loss:  0.003808, Epoch: 2
# Batch 56, Loss:  0.003918, Epoch: 2
# Batch 58, Loss:  0.004068, Epoch: 2
# Batch 60, Loss:  0.004207, Epoch: 2
# Batch 62, Loss:  0.004308, Epoch: 2
# Batch 64, Loss:  0.004441, Epoch: 2
# Batch 66, Loss:  0.004579, Epoch: 2
# Batch 68, Loss:  0.004713, Epoch: 2
# Batch 70, Loss:  0.004854, Epoch: 2
# Batch 72, Loss:  0.004976, Epoch: 2
# Batch 74, Loss:  0.005096, Epoch: 2
# Batch 76, Loss:  0.005234, Epoch: 2
# Batch 78, Loss:  0.005365, Epoch: 2
# Batch 80, Loss:  0.005493, Epoch: 2
# Batch 82, Loss:  0.005602, Epoch: 2
# Batch 84, Loss:  0.005742, Epoch: 2
# Batch 86, Loss:  0.005855, Epoch: 2
# Batch 88, Loss:  0.005950, Epoch: 2
# Batch 90, Loss:  0.006087, Epoch: 2
# Batch 92, Loss:  0.006225, Epoch: 2
# Batch 94, Loss:  0.006348, Epoch: 2
# Batch 96, Loss:  0.006455, Epoch: 2
# Batch 98, Loss:  0.006565, Epoch: 2
# Batch 100, Loss:  0.006690, Epoch: 2
# Batch 102, Loss:  0.006809, Epoch: 2
# Batch 104, Loss:  0.006963, Epoch: 2
# Batch 106, Loss:  0.007085, Epoch: 2
# Batch 108, Loss:  0.007278, Epoch: 2
# Batch 110, Loss:  0.007450, Epoch: 2
# Batch 112, Loss:  0.007549, Epoch: 2
# Batch 114, Loss:  0.007732, Epoch: 2
# Batch 116, Loss:  0.007853, Epoch: 2
# Batch 118, Loss:  0.007973, Epoch: 2
# Batch 120, Loss:  0.008114, Epoch: 2
# Batch 122, Loss:  0.008241, Epoch: 2
# Batch 124, Loss:  0.008397, Epoch: 2
# Batch 126, Loss:  0.008506, Epoch: 2
# Batch 128, Loss:  0.008635, Epoch: 2
# Batch 130, Loss:  0.008770, Epoch: 2
# Batch 132, Loss:  0.008885, Epoch: 2
# Batch 134, Loss:  0.009013, Epoch: 2
# Batch 136, Loss:  0.009129, Epoch: 2
# Batch 138, Loss:  0.009244, Epoch: 2
# Batch 140, Loss:  0.009348, Epoch: 2
# Batch 142, Loss:  0.009473, Epoch: 2
# Batch 144, Loss:  0.009603, Epoch: 2
# Batch 146, Loss:  0.009727, Epoch: 2
# Batch 148, Loss:  0.009890, Epoch: 2
# Batch 150, Loss:  0.010011, Epoch: 2
# Batch 152, Loss:  0.010157, Epoch: 2
# Batch 154, Loss:  0.010295, Epoch: 2
# Batch 156, Loss:  0.010412, Epoch: 2
# Batch 158, Loss:  0.010576, Epoch: 2
# Batch 160, Loss:  0.010704, Epoch: 2
# Batch 162, Loss:  0.010829, Epoch: 2
# Batch 164, Loss:  0.010969, Epoch: 2
# Batch 166, Loss:  0.011102, Epoch: 2
# Batch 168, Loss:  0.011235, Epoch: 2
# Batch 170, Loss:  0.011400, Epoch: 2
# Batch 172, Loss:  0.011514, Epoch: 2
# Batch 174, Loss:  0.011700, Epoch: 2
# Batch 176, Loss:  0.011803, Epoch: 2
# Batch 178, Loss:  0.011911, Epoch: 2
# Batch 180, Loss:  0.012012, Epoch: 2
# Batch 182, Loss:  0.012153, Epoch: 2
# Batch 184, Loss:  0.012255, Epoch: 2
# Batch 186, Loss:  0.012392, Epoch: 2
# Batch 188, Loss:  0.012520, Epoch: 2
# Batch 190, Loss:  0.012610, Epoch: 2
# Batch 192, Loss:  0.012753, Epoch: 2
# Batch 194, Loss:  0.012884, Epoch: 2
# Batch 196, Loss:  0.013039, Epoch: 2
# Batch 198, Loss:  0.013164, Epoch: 2
# Batch 200, Loss:  0.013353, Epoch: 2
# Batch 202, Loss:  0.013516, Epoch: 2
# Batch 204, Loss:  0.013657, Epoch: 2
# Batch 206, Loss:  0.013774, Epoch: 2
# Batch 208, Loss:  0.013907, Epoch: 2
# Batch 210, Loss:  0.014046, Epoch: 2
# Batch 212, Loss:  0.014177, Epoch: 2
# Batch 214, Loss:  0.014305, Epoch: 2
# Batch 216, Loss:  0.014418, Epoch: 2
# Batch 218, Loss:  0.014526, Epoch: 2
# Batch 220, Loss:  0.014636, Epoch: 2
# Batch 222, Loss:  0.014751, Epoch: 2
# Batch 224, Loss:  0.014896, Epoch: 2
# Batch 226, Loss:  0.015028, Epoch: 2
# Batch 228, Loss:  0.015147, Epoch: 2
# Batch 230, Loss:  0.015288, Epoch: 2
# Batch 232, Loss:  0.015415, Epoch: 2
# Batch 234, Loss:  0.015535, Epoch: 2
# Batch 236, Loss:  0.015699, Epoch: 2
# Batch 238, Loss:  0.015854, Epoch: 2
# Batch 240, Loss:  0.015970, Epoch: 2
# Batch 242, Loss:  0.016088, Epoch: 2
# Batch 244, Loss:  0.016190, Epoch: 2
# Batch 246, Loss:  0.016366, Epoch: 2
# Batch 248, Loss:  0.016492, Epoch: 2
# Batch 250, Loss:  0.016635, Epoch: 2
# Batch 252, Loss:  0.016769, Epoch: 2
# Batch 254, Loss:  0.016906, Epoch: 2
# Batch 256, Loss:  0.017065, Epoch: 2
# Batch 258, Loss:  0.017244, Epoch: 2
# Batch 260, Loss:  0.017374, Epoch: 2
# Batch 262, Loss:  0.017489, Epoch: 2
# Batch 264, Loss:  0.017619, Epoch: 2
# Batch 266, Loss:  0.017741, Epoch: 2
# Batch 268, Loss:  0.017862, Epoch: 2
# Batch 270, Loss:  0.018028, Epoch: 2
# Batch 272, Loss:  0.018141, Epoch: 2
# Batch 274, Loss:  0.018284, Epoch: 2
# Batch 276, Loss:  0.018420, Epoch: 2
# Batch 278, Loss:  0.018556, Epoch: 2
# Batch 280, Loss:  0.018670, Epoch: 2
# Batch 282, Loss:  0.018781, Epoch: 2
# Batch 284, Loss:  0.018960, Epoch: 2
# Batch 286, Loss:  0.019067, Epoch: 2
# Batch 288, Loss:  0.019208, Epoch: 2
# Batch 290, Loss:  0.019334, Epoch: 2
# Batch 292, Loss:  0.019444, Epoch: 2
# Batch 294, Loss:  0.019547, Epoch: 2
# Batch 296, Loss:  0.019677, Epoch: 2
# Batch 298, Loss:  0.019794, Epoch: 2
# Batch 300, Loss:  0.019887, Epoch: 2
# Batch 302, Loss:  0.020045, Epoch: 2
# Batch 304, Loss:  0.020160, Epoch: 2
# Batch 306, Loss:  0.020307, Epoch: 2
# Batch 308, Loss:  0.020480, Epoch: 2
# Batch 310, Loss:  0.020589, Epoch: 2
# Batch 312, Loss:  0.020740, Epoch: 2
# Batch 314, Loss:  0.020874, Epoch: 2
# Batch 316, Loss:  0.020996, Epoch: 2
# Batch 318, Loss:  0.021164, Epoch: 2
# Batch 320, Loss:  0.021342, Epoch: 2
# Batch 322, Loss:  0.021456, Epoch: 2
# Batch 324, Loss:  0.021598, Epoch: 2
# Batch 326, Loss:  0.021726, Epoch: 2
# Batch 328, Loss:  0.021833, Epoch: 2
# Batch 330, Loss:  0.021957, Epoch: 2
# Batch 332, Loss:  0.022118, Epoch: 2
# Batch 334, Loss:  0.022242, Epoch: 2
# Batch 336, Loss:  0.022354, Epoch: 2
# Batch 338, Loss:  0.022479, Epoch: 2
# Batch 340, Loss:  0.022605, Epoch: 2
# Batch 342, Loss:  0.022746, Epoch: 2
# Batch 344, Loss:  0.022836, Epoch: 2
# Batch 346, Loss:  0.022966, Epoch: 2
# Batch 348, Loss:  0.023058, Epoch: 2
# Batch 350, Loss:  0.023184, Epoch: 2
# Batch 352, Loss:  0.023297, Epoch: 2
# Batch 354, Loss:  0.023387, Epoch: 2
# Batch 356, Loss:  0.023558, Epoch: 2
# Batch 358, Loss:  0.023677, Epoch: 2
# Batch 360, Loss:  0.023807, Epoch: 2
# Batch 362, Loss:  0.023935, Epoch: 2
# Batch 364, Loss:  0.024035, Epoch: 2
# Batch 366, Loss:  0.024144, Epoch: 2
# Batch 368, Loss:  0.024294, Epoch: 2
# Batch 370, Loss:  0.024426, Epoch: 2
# Batch 372, Loss:  0.024538, Epoch: 2
# Batch 374, Loss:  0.024641, Epoch: 2
# Batch 376, Loss:  0.024743, Epoch: 2
# Batch 378, Loss:  0.024862, Epoch: 2
# Batch 380, Loss:  0.024975, Epoch: 2
# Batch 382, Loss:  0.025069, Epoch: 2
# Batch 384, Loss:  0.025226, Epoch: 2
# Batch 386, Loss:  0.025382, Epoch: 2
# Batch 388, Loss:  0.025512, Epoch: 2
# Batch 390, Loss:  0.025635, Epoch: 2
# Batch 392, Loss:  0.025756, Epoch: 2
# Batch 394, Loss:  0.025875, Epoch: 2
# Batch 396, Loss:  0.025999, Epoch: 2
# Batch 398, Loss:  0.026125, Epoch: 2
# Batch 400, Loss:  0.026251, Epoch: 2
# Batch 402, Loss:  0.026367, Epoch: 2
# Batch 404, Loss:  0.026483, Epoch: 2
# Batch 406, Loss:  0.026593, Epoch: 2
# Batch 408, Loss:  0.026698, Epoch: 2
# Batch 410, Loss:  0.026837, Epoch: 2
# Batch 412, Loss:  0.026952, Epoch: 2
# Batch 414, Loss:  0.027072, Epoch: 2
# Batch 416, Loss:  0.027147, Epoch: 2
# Batch 418, Loss:  0.027291, Epoch: 2
# Batch 420, Loss:  0.027390, Epoch: 2
# Batch 422, Loss:  0.027518, Epoch: 2
# Batch 424, Loss:  0.027650, Epoch: 2
# Batch 426, Loss:  0.027775, Epoch: 2
# Batch 428, Loss:  0.027882, Epoch: 2
# Batch 430, Loss:  0.028024, Epoch: 2
# Batch 432, Loss:  0.028168, Epoch: 2
# Batch 434, Loss:  0.028285, Epoch: 2
# Batch 436, Loss:  0.028401, Epoch: 2
# Batch 438, Loss:  0.028519, Epoch: 2
# Batch 440, Loss:  0.028679, Epoch: 2
# Batch 442, Loss:  0.028856, Epoch: 2
# Batch 444, Loss:  0.028954, Epoch: 2
# Batch 446, Loss:  0.029121, Epoch: 2
# Batch 448, Loss:  0.029234, Epoch: 2
# Batch 450, Loss:  0.029383, Epoch: 2
# Batch 452, Loss:  0.029547, Epoch: 2
# Batch 454, Loss:  0.029691, Epoch: 2
# Batch 456, Loss:  0.029836, Epoch: 2
# Batch 458, Loss:  0.029974, Epoch: 2
# Batch 460, Loss:  0.030075, Epoch: 2
# Batch 462, Loss:  0.030203, Epoch: 2
# Batch 464, Loss:  0.030362, Epoch: 2
# Batch 466, Loss:  0.030508, Epoch: 2
# Batch 468, Loss:  0.030618, Epoch: 2
# Batch 470, Loss:  0.030704, Epoch: 2
# Batch 472, Loss:  0.030854, Epoch: 2
# Batch 474, Loss:  0.031003, Epoch: 2
# Batch 476, Loss:  0.031154, Epoch: 2
# Batch 478, Loss:  0.031246, Epoch: 2
# Batch 480, Loss:  0.031360, Epoch: 2
# Batch 482, Loss:  0.031465, Epoch: 2
# Batch 484, Loss:  0.031574, Epoch: 2
# Batch 486, Loss:  0.031755, Epoch: 2
# Batch 488, Loss:  0.031868, Epoch: 2
# Batch 490, Loss:  0.031993, Epoch: 2
# Batch 492, Loss:  0.032129, Epoch: 2
# Batch 494, Loss:  0.032278, Epoch: 2
# Batch 496, Loss:  0.032420, Epoch: 2
# Batch 498, Loss:  0.032521, Epoch: 2
# Batch 500, Loss:  0.032632, Epoch: 2
# Batch 502, Loss:  0.032766, Epoch: 2
# Batch 504, Loss:  0.032901, Epoch: 2
# Batch 506, Loss:  0.033020, Epoch: 2
# Batch 508, Loss:  0.033151, Epoch: 2
# Batch 510, Loss:  0.033303, Epoch: 2
# Batch 512, Loss:  0.033447, Epoch: 2
# Batch 514, Loss:  0.033556, Epoch: 2
# Batch 516, Loss:  0.033680, Epoch: 2
# Batch 518, Loss:  0.033787, Epoch: 2
# Batch 520, Loss:  0.033944, Epoch: 2
# Batch 522, Loss:  0.034064, Epoch: 2
# Batch 524, Loss:  0.034218, Epoch: 2
# Batch 526, Loss:  0.034362, Epoch: 2
# Batch 528, Loss:  0.034517, Epoch: 2
# Batch 530, Loss:  0.034653, Epoch: 2
# Batch 532, Loss:  0.034798, Epoch: 2
# Batch 534, Loss:  0.034925, Epoch: 2
# Batch 536, Loss:  0.035083, Epoch: 2
# Batch 538, Loss:  0.035196, Epoch: 2
# Batch 540, Loss:  0.035296, Epoch: 2
# Batch 542, Loss:  0.035428, Epoch: 2
# Batch 544, Loss:  0.035516, Epoch: 2
# Batch 546, Loss:  0.035626, Epoch: 2
# Batch 548, Loss:  0.035772, Epoch: 2
# Batch 550, Loss:  0.035881, Epoch: 2
# Batch 552, Loss:  0.036039, Epoch: 2
# Batch 554, Loss:  0.036185, Epoch: 2
# Batch 556, Loss:  0.036352, Epoch: 2
# Batch 558, Loss:  0.036452, Epoch: 2
# Batch 560, Loss:  0.036593, Epoch: 2
# Batch 562, Loss:  0.036738, Epoch: 2
# Batch 564, Loss:  0.036869, Epoch: 2
# Batch 566, Loss:  0.037003, Epoch: 2
# Batch 568, Loss:  0.037152, Epoch: 2
# Batch 570, Loss:  0.037253, Epoch: 2
# Batch 572, Loss:  0.037372, Epoch: 2
# Batch 574, Loss:  0.037502, Epoch: 2
# Batch 576, Loss:  0.037649, Epoch: 2
# Batch 578, Loss:  0.037826, Epoch: 2
# Batch 580, Loss:  0.037929, Epoch: 2
# Batch 582, Loss:  0.038056, Epoch: 2
# Batch 584, Loss:  0.038223, Epoch: 2
# Batch 586, Loss:  0.038329, Epoch: 2
# Batch 588, Loss:  0.038438, Epoch: 2
# Batch 590, Loss:  0.038590, Epoch: 2
# Batch 592, Loss:  0.038704, Epoch: 2
# Batch 594, Loss:  0.038837, Epoch: 2
# Batch 596, Loss:  0.038988, Epoch: 2
# Batch 598, Loss:  0.039099, Epoch: 2
# Batch 600, Loss:  0.039243, Epoch: 2
# Batch 602, Loss:  0.039374, Epoch: 2
# Batch 604, Loss:  0.039533, Epoch: 2
# Batch 606, Loss:  0.039676, Epoch: 2
# Batch 608, Loss:  0.039818, Epoch: 2
# Batch 610, Loss:  0.039981, Epoch: 2
# Batch 612, Loss:  0.040059, Epoch: 2
# Batch 614, Loss:  0.040213, Epoch: 2
# Batch 616, Loss:  0.040331, Epoch: 2
# Batch 618, Loss:  0.040475, Epoch: 2
# Batch 620, Loss:  0.040607, Epoch: 2
# Batch 622, Loss:  0.040763, Epoch: 2
# Batch 624, Loss:  0.040910, Epoch: 2
# Batch 626, Loss:  0.041032, Epoch: 2
# Batch 628, Loss:  0.041138, Epoch: 2
# Batch 630, Loss:  0.041266, Epoch: 2
# Batch 632, Loss:  0.041385, Epoch: 2
# Batch 634, Loss:  0.041517, Epoch: 2
# Batch 636, Loss:  0.041660, Epoch: 2
# Batch 638, Loss:  0.041806, Epoch: 2
# Batch 640, Loss:  0.041953, Epoch: 2
# Batch 642, Loss:  0.042093, Epoch: 2
# Batch 644, Loss:  0.042224, Epoch: 2
# Batch 646, Loss:  0.042336, Epoch: 2
# Batch 648, Loss:  0.042466, Epoch: 2
# Batch 650, Loss:  0.042566, Epoch: 2
# Batch 652, Loss:  0.042665, Epoch: 2
# Batch 654, Loss:  0.042802, Epoch: 2
# Batch 656, Loss:  0.042929, Epoch: 2
# Batch 658, Loss:  0.043043, Epoch: 2
# Batch 660, Loss:  0.043219, Epoch: 2
# Batch 662, Loss:  0.043320, Epoch: 2
# Batch 664, Loss:  0.043499, Epoch: 2
# Batch 666, Loss:  0.043604, Epoch: 2
# Batch 668, Loss:  0.043715, Epoch: 2
# Batch 670, Loss:  0.043807, Epoch: 2
# Batch 672, Loss:  0.043930, Epoch: 2
# Batch 674, Loss:  0.044033, Epoch: 2
# Batch 676, Loss:  0.044147, Epoch: 2
# Batch 678, Loss:  0.044276, Epoch: 2
# Batch 680, Loss:  0.044371, Epoch: 2
# Batch 682, Loss:  0.044498, Epoch: 2
# Batch 684, Loss:  0.044610, Epoch: 2
# Batch 686, Loss:  0.044716, Epoch: 2
# Batch 688, Loss:  0.044821, Epoch: 2
# Batch 690, Loss:  0.044996, Epoch: 2
# Batch 692, Loss:  0.045146, Epoch: 2
# Batch 694, Loss:  0.045277, Epoch: 2
# Batch 696, Loss:  0.045371, Epoch: 2
# Batch 698, Loss:  0.045510, Epoch: 2
# Batch 700, Loss:  0.045650, Epoch: 2
# Batch 702, Loss:  0.045772, Epoch: 2
# Batch 704, Loss:  0.045880, Epoch: 2
# Batch 706, Loss:  0.045982, Epoch: 2
# Batch 708, Loss:  0.046097, Epoch: 2
# Batch 710, Loss:  0.046212, Epoch: 2
# Batch 712, Loss:  0.046319, Epoch: 2
# Batch 714, Loss:  0.046463, Epoch: 2
# Batch 716, Loss:  0.046580, Epoch: 2
# Batch 718, Loss:  0.046721, Epoch: 2
# Batch 720, Loss:  0.046831, Epoch: 2
# Batch 722, Loss:  0.046959, Epoch: 2
# Batch 724, Loss:  0.047084, Epoch: 2
# Batch 726, Loss:  0.047180, Epoch: 2
# Batch 728, Loss:  0.047309, Epoch: 2
# Batch 730, Loss:  0.047428, Epoch: 2
# Batch 732, Loss:  0.047526, Epoch: 2
# Batch 734, Loss:  0.047693, Epoch: 2
# Batch 736, Loss:  0.047793, Epoch: 2
# Batch 738, Loss:  0.047889, Epoch: 2
# Batch 740, Loss:  0.048013, Epoch: 2
# Batch 742, Loss:  0.048136, Epoch: 2
# Batch 744, Loss:  0.048243, Epoch: 2
# Batch 746, Loss:  0.048331, Epoch: 2
# Batch 748, Loss:  0.048453, Epoch: 2
# Batch 750, Loss:  0.048575, Epoch: 2
# Batch 752, Loss:  0.048701, Epoch: 2
# Batch 754, Loss:  0.048809, Epoch: 2
# Batch 756, Loss:  0.048920, Epoch: 2
# Batch 758, Loss:  0.049030, Epoch: 2
# Batch 760, Loss:  0.049144, Epoch: 2
# Batch 762, Loss:  0.049277, Epoch: 2
# Batch 764, Loss:  0.049407, Epoch: 2
# Batch 766, Loss:  0.049492, Epoch: 2
# Batch 768, Loss:  0.049591, Epoch: 2
# Batch 770, Loss:  0.049718, Epoch: 2
# Batch 772, Loss:  0.049834, Epoch: 2
# Batch 774, Loss:  0.049933, Epoch: 2
# Batch 776, Loss:  0.050030, Epoch: 2
# Batch 778, Loss:  0.050153, Epoch: 2
# Batch 780, Loss:  0.050281, Epoch: 2
# Batch 782, Loss:  0.050397, Epoch: 2
# Batch 784, Loss:  0.050535, Epoch: 2
# Batch 786, Loss:  0.050669, Epoch: 2
# Batch 788, Loss:  0.050794, Epoch: 2
# Batch 790, Loss:  0.050924, Epoch: 2
# Batch 792, Loss:  0.051083, Epoch: 2
# Batch 794, Loss:  0.051201, Epoch: 2
# Batch 796, Loss:  0.051338, Epoch: 2
# Batch 798, Loss:  0.051450, Epoch: 2
# Batch 800, Loss:  0.051582, Epoch: 2
# Batch 802, Loss:  0.051708, Epoch: 2
# Batch 804, Loss:  0.051814, Epoch: 2
# Batch 806, Loss:  0.051971, Epoch: 2
# Batch 808, Loss:  0.052076, Epoch: 2
# ...
# Batch 938, Loss:  0.046687, Epoch: 6
# Batch 940, Loss:  0.046782, Epoch: 6
# Batch 942, Loss:  0.046877, Epoch: 6
# Batch 944, Loss:  0.046964, Epoch: 6
# Batch 946, Loss:  0.047044, Epoch: 6
# Batch 948, Loss:  0.047149, Epoch: 6
# Batch 950, Loss:  0.047254, Epoch: 6
# Batch 952, Loss:  0.047336, Epoch: 6
# Batch 954, Loss:  0.047427, Epoch: 6
# Batch 956, Loss:  0.047539, Epoch: 6
# Batch 958, Loss:  0.047649, Epoch: 6
# Batch 960, Loss:  0.047763, Epoch: 6
# Batch 962, Loss:  0.047875, Epoch: 6
# Batch 964, Loss:  0.047983, Epoch: 6
# Batch 966, Loss:  0.048092, Epoch: 6
# Batch 968, Loss:  0.048151, Epoch: 6
# Batch 970, Loss:  0.048263, Epoch: 6
# Batch 972, Loss:  0.048370, Epoch: 6
# Batch 974, Loss:  0.048474, Epoch: 6
# Batch 976, Loss:  0.048588, Epoch: 6
# Batch 978, Loss:  0.048710, Epoch: 6
# Batch 980, Loss:  0.048805, Epoch: 6
# Batch 982, Loss:  0.048908, Epoch: 6
# Batch 984, Loss:  0.049001, Epoch: 6
# Batch 986, Loss:  0.049117, Epoch: 6
# Batch 988, Loss:  0.049201, Epoch: 6
# Batch 990, Loss:  0.049282, Epoch: 6
# Batch 992, Loss:  0.049340, Epoch: 6
# Batch 994, Loss:  0.049428, Epoch: 6
# Batch 996, Loss:  0.049530, Epoch: 6
# Batch 998, Loss:  0.049608, Epoch: 6
# Batch 1000, Loss:  0.049748, Epoch: 6
# Batch 1002, Loss:  0.049862, Epoch: 6
# Batch 1004, Loss:  0.049962, Epoch: 6
# Batch 1006, Loss:  0.050046, Epoch: 6
# Batch 1008, Loss:  0.050141, Epoch: 6
# Batch 1010, Loss:  0.050265, Epoch: 6
# Batch 1012, Loss:  0.050369, Epoch: 6
# Batch 1014, Loss:  0.050476, Epoch: 6
# Batch 1016, Loss:  0.050573, Epoch: 6
# Batch 1018, Loss:  0.050645, Epoch: 6
# Batch 1020, Loss:  0.050770, Epoch: 6
# Batch 1022, Loss:  0.050883, Epoch: 6
# Batch 1024, Loss:  0.050985, Epoch: 6
# Batch 1026, Loss:  0.051096, Epoch: 6
# Batch 1028, Loss:  0.051193, Epoch: 6
# Batch 1030, Loss:  0.051304, Epoch: 6
# Batch 1032, Loss:  0.051411, Epoch: 6
# Batch 1034, Loss:  0.051500, Epoch: 6
# Batch 1036, Loss:  0.051591, Epoch: 6
# Batch 1038, Loss:  0.051699, Epoch: 6
# Batch 1040, Loss:  0.051808, Epoch: 6
# Batch 1042, Loss:  0.051896, Epoch: 6
# Batch 1044, Loss:  0.052011, Epoch: 6
# Batch 1046, Loss:  0.052127, Epoch: 6
# Batch 1048, Loss:  0.052223, Epoch: 6
# Batch 1050, Loss:  0.052342, Epoch: 6
# Batch 1052, Loss:  0.052435, Epoch: 6
# Batch 1054, Loss:  0.052553, Epoch: 6
# Batch 1056, Loss:  0.052645, Epoch: 6
# Batch 1058, Loss:  0.052742, Epoch: 6
# Batch 1060, Loss:  0.052845, Epoch: 6
# Batch 1062, Loss:  0.052945, Epoch: 6
# Batch 1064, Loss:  0.053019, Epoch: 6
# Batch 1066, Loss:  0.053098, Epoch: 6
# Batch 1068, Loss:  0.053202, Epoch: 6
# Batch 1070, Loss:  0.053312, Epoch: 6
# Batch 1072, Loss:  0.053383, Epoch: 6
# Batch 1074, Loss:  0.053486, Epoch: 6
# Batch 1076, Loss:  0.053585, Epoch: 6
# Batch 1078, Loss:  0.053701, Epoch: 6
# Batch 1080, Loss:  0.053775, Epoch: 6
# Batch 1082, Loss:  0.053861, Epoch: 6
# Batch 1084, Loss:  0.053944, Epoch: 6
# Batch 1086, Loss:  0.054050, Epoch: 6
# Batch 1088, Loss:  0.054181, Epoch: 6
# Batch 1090, Loss:  0.054279, Epoch: 6
# Batch 1092, Loss:  0.054391, Epoch: 6
# Batch 1094, Loss:  0.054491, Epoch: 6
# Batch 1096, Loss:  0.054592, Epoch: 6
# Batch 1098, Loss:  0.054725, Epoch: 6
# Batch 1100, Loss:  0.054842, Epoch: 6
# Batch 1102, Loss:  0.054961, Epoch: 6
# Batch 1104, Loss:  0.055054, Epoch: 6
# Batch 1106, Loss:  0.055138, Epoch: 6
# Batch 1108, Loss:  0.055244, Epoch: 6
# Batch 1110, Loss:  0.055339, Epoch: 6
# Batch 1112, Loss:  0.055445, Epoch: 6
# Batch 1114, Loss:  0.055554, Epoch: 6
# Batch 1116, Loss:  0.055656, Epoch: 6
# Batch 1118, Loss:  0.055739, Epoch: 6
# Batch 1120, Loss:  0.055848, Epoch: 6
# Batch 1122, Loss:  0.055947, Epoch: 6
# Batch 1124, Loss:  0.056059, Epoch: 6
# Batch 1126, Loss:  0.056148, Epoch: 6
# Batch 1128, Loss:  0.056247, Epoch: 6
# Batch 1130, Loss:  0.056382, Epoch: 6
# Batch 1132, Loss:  0.056455, Epoch: 6
# Batch 1134, Loss:  0.056541, Epoch: 6
# Batch 1136, Loss:  0.056649, Epoch: 6
# Batch 1138, Loss:  0.056742, Epoch: 6
# Batch 1140, Loss:  0.056835, Epoch: 6
# Batch 1142, Loss:  0.056946, Epoch: 6
# Batch 1144, Loss:  0.057050, Epoch: 6
# Batch 1146, Loss:  0.057149, Epoch: 6
# Batch 1148, Loss:  0.057243, Epoch: 6
# Batch 1150, Loss:  0.057345, Epoch: 6
# Batch 1152, Loss:  0.057433, Epoch: 6
# Batch 1154, Loss:  0.057497, Epoch: 6
# Batch 1156, Loss:  0.057605, Epoch: 6
# Batch 1158, Loss:  0.057687, Epoch: 6
# Batch 1160, Loss:  0.057778, Epoch: 6
# Batch 1162, Loss:  0.057876, Epoch: 6
# Batch 1164, Loss:  0.057998, Epoch: 6
# Batch 1166, Loss:  0.058084, Epoch: 6
# Batch 1168, Loss:  0.058186, Epoch: 6
# Batch 1170, Loss:  0.058298, Epoch: 6
# Batch 1172, Loss:  0.058407, Epoch: 6
# Batch 1174, Loss:  0.058483, Epoch: 6
# Batch 1176, Loss:  0.058592, Epoch: 6
# Batch 1178, Loss:  0.058682, Epoch: 6
# Batch 1180, Loss:  0.058777, Epoch: 6
# Batch 1182, Loss:  0.058903, Epoch: 6
# Batch 1184, Loss:  0.059024, Epoch: 6
# Batch 1186, Loss:  0.059113, Epoch: 6
# Batch 1188, Loss:  0.059220, Epoch: 6
# Batch 1190, Loss:  0.059318, Epoch: 6
# Batch 1192, Loss:  0.059433, Epoch: 6
# Batch 1194, Loss:  0.059547, Epoch: 6
# Batch 1196, Loss:  0.059640, Epoch: 6
# Batch 1198, Loss:  0.059749, Epoch: 6
# Batch 1200, Loss:  0.059840, Epoch: 6
# Batch 1202, Loss:  0.059932, Epoch: 6
# Batch 1204, Loss:  0.060054, Epoch: 6
# Batch 1206, Loss:  0.060127, Epoch: 6
# Batch 1208, Loss:  0.060212, Epoch: 6
# Batch 1210, Loss:  0.060288, Epoch: 6
# Batch 1212, Loss:  0.060404, Epoch: 6
# Batch 1214, Loss:  0.060496, Epoch: 6
# Batch 1216, Loss:  0.060585, Epoch: 6
# Batch 1218, Loss:  0.060673, Epoch: 6
# Batch 1220, Loss:  0.060774, Epoch: 6
# Batch 1222, Loss:  0.060877, Epoch: 6
# Batch 1224, Loss:  0.060961, Epoch: 6
# Batch 1226, Loss:  0.061044, Epoch: 6
# Batch 1228, Loss:  0.061128, Epoch: 6
# Batch 1230, Loss:  0.061227, Epoch: 6
# Batch 1232, Loss:  0.061296, Epoch: 6
# Batch 1234, Loss:  0.061402, Epoch: 6
# Batch 1236, Loss:  0.061517, Epoch: 6
# Batch 1238, Loss:  0.061626, Epoch: 6
# Batch 1240, Loss:  0.061720, Epoch: 6
# Batch 1242, Loss:  0.061842, Epoch: 6
# Batch 1244, Loss:  0.061933, Epoch: 6
# Batch 1246, Loss:  0.062026, Epoch: 6
# Batch 1248, Loss:  0.062110, Epoch: 6
# Batch 1250, Loss:  0.062232, Epoch: 6
# Batch 1252, Loss:  0.062319, Epoch: 6
# Batch 1254, Loss:  0.062397, Epoch: 6
# Batch 1256, Loss:  0.062534, Epoch: 6
# Batch 1258, Loss:  0.062629, Epoch: 6
# Batch 1260, Loss:  0.062726, Epoch: 6
# Batch 1262, Loss:  0.062822, Epoch: 6
# Batch 1264, Loss:  0.062931, Epoch: 6
# Batch 1266, Loss:  0.063033, Epoch: 6
# Batch 1268, Loss:  0.063130, Epoch: 6
# Batch 1270, Loss:  0.063238, Epoch: 6
# Batch 1272, Loss:  0.063350, Epoch: 6
# Batch 1274, Loss:  0.063423, Epoch: 6
# Batch 1276, Loss:  0.063492, Epoch: 6
# Batch 1278, Loss:  0.063589, Epoch: 6
# Batch 1280, Loss:  0.063690, Epoch: 6
# Batch 1282, Loss:  0.063786, Epoch: 6
# Batch 1284, Loss:  0.063862, Epoch: 6
# Batch 1286, Loss:  0.063922, Epoch: 6
# Batch 1288, Loss:  0.064032, Epoch: 6
# Batch 1290, Loss:  0.064115, Epoch: 6
# Batch 1292, Loss:  0.064212, Epoch: 6
# Batch 1294, Loss:  0.064285, Epoch: 6
# Batch 1296, Loss:  0.064407, Epoch: 6
# Batch 1298, Loss:  0.064510, Epoch: 6
# Batch 1300, Loss:  0.064583, Epoch: 6
# Batch 1302, Loss:  0.064680, Epoch: 6
# Batch 1304, Loss:  0.064754, Epoch: 6
# Batch 1306, Loss:  0.064852, Epoch: 6
# Batch 1308, Loss:  0.064928, Epoch: 6
# Batch 1310, Loss:  0.065045, Epoch: 6
# Batch 1312, Loss:  0.065125, Epoch: 6
# Batch 1314, Loss:  0.065202, Epoch: 6
# Batch 1316, Loss:  0.065297, Epoch: 6
# Batch 1318, Loss:  0.065387, Epoch: 6
# Batch 1320, Loss:  0.065497, Epoch: 6
# Batch 1322, Loss:  0.065602, Epoch: 6
# Batch 1324, Loss:  0.065730, Epoch: 6
# Batch 1326, Loss:  0.065819, Epoch: 6
# Batch 1328, Loss:  0.065949, Epoch: 6
# Batch 1330, Loss:  0.066062, Epoch: 6
# Batch 1332, Loss:  0.066181, Epoch: 6
# Batch 1334, Loss:  0.066269, Epoch: 6
# Batch 1336, Loss:  0.066359, Epoch: 6
# Batch 1338, Loss:  0.066467, Epoch: 6
# Batch 1340, Loss:  0.066565, Epoch: 6
# Batch 1342, Loss:  0.066668, Epoch: 6
# Batch 1344, Loss:  0.066769, Epoch: 6
# Batch 1346, Loss:  0.066896, Epoch: 6
# Batch 1348, Loss:  0.067005, Epoch: 6
# Batch 1350, Loss:  0.067134, Epoch: 6
# Batch 1352, Loss:  0.067229, Epoch: 6
# Batch 1354, Loss:  0.067296, Epoch: 6
# Batch 1356, Loss:  0.067393, Epoch: 6
# Batch 1358, Loss:  0.067501, Epoch: 6
# Batch 1360, Loss:  0.067609, Epoch: 6
# Batch 1362, Loss:  0.067692, Epoch: 6
# Batch 1364, Loss:  0.067805, Epoch: 6
# Batch 1366, Loss:  0.067906, Epoch: 6
# Batch 1368, Loss:  0.068005, Epoch: 6
# Batch 1370, Loss:  0.068098, Epoch: 6
# Batch 1372, Loss:  0.068176, Epoch: 6
# Batch 1374, Loss:  0.068268, Epoch: 6
# Batch 1376, Loss:  0.068365, Epoch: 6
# Batch 1378, Loss:  0.068461, Epoch: 6
# Batch 1380, Loss:  0.068572, Epoch: 6
# Batch 1382, Loss:  0.068692, Epoch: 6
# Batch 1384, Loss:  0.068802, Epoch: 6
# Batch 1386, Loss:  0.068893, Epoch: 6
# Batch 1388, Loss:  0.068986, Epoch: 6
# Batch 1390, Loss:  0.069058, Epoch: 6
# Batch 1392, Loss:  0.069147, Epoch: 6
# Batch 1394, Loss:  0.069268, Epoch: 6
# Batch 1396, Loss:  0.069386, Epoch: 6
# Batch 1398, Loss:  0.069494, Epoch: 6
# Batch 1400, Loss:  0.069582, Epoch: 6
# Batch 1402, Loss:  0.069692, Epoch: 6
# Batch 1404, Loss:  0.069799, Epoch: 6
# Batch 1406, Loss:  0.069881, Epoch: 6
# Batch 1408, Loss:  0.069967, Epoch: 6
# Batch 1410, Loss:  0.070058, Epoch: 6
# Batch 1412, Loss:  0.070176, Epoch: 6
# Batch 1414, Loss:  0.070272, Epoch: 6
# Batch 1416, Loss:  0.070371, Epoch: 6
# Batch 1418, Loss:  0.070472, Epoch: 6
# Batch 1420, Loss:  0.070602, Epoch: 6
# Batch 1422, Loss:  0.070709, Epoch: 6
# Batch 1424, Loss:  0.070810, Epoch: 6
# Batch 1426, Loss:  0.070903, Epoch: 6
# Batch 1428, Loss:  0.071018, Epoch: 6
# Batch 1430, Loss:  0.071093, Epoch: 6
# Batch 1432, Loss:  0.071173, Epoch: 6
# Batch 1434, Loss:  0.071275, Epoch: 6
# Batch 1436, Loss:  0.071357, Epoch: 6
# Batch 1438, Loss:  0.071450, Epoch: 6
# Batch 1440, Loss:  0.071565, Epoch: 6
# Batch 1442, Loss:  0.071663, Epoch: 6
# Batch 1444, Loss:  0.071768, Epoch: 6
# Batch 1446, Loss:  0.071846, Epoch: 6
# Batch 1448, Loss:  0.071925, Epoch: 6
# Batch 1450, Loss:  0.072019, Epoch: 6
# Batch 1452, Loss:  0.072102, Epoch: 6
# Batch 1454, Loss:  0.072185, Epoch: 6
# Batch 1456, Loss:  0.072291, Epoch: 6
# Batch 1458, Loss:  0.072419, Epoch: 6
# Batch 1460, Loss:  0.072483, Epoch: 6
# Batch 1462, Loss:  0.072576, Epoch: 6
# Batch 1464, Loss:  0.072658, Epoch: 6
# Batch 1466, Loss:  0.072726, Epoch: 6
# Batch 1468, Loss:  0.072837, Epoch: 6
# Batch 1470, Loss:  0.072912, Epoch: 6
# Batch 1472, Loss:  0.073008, Epoch: 6
# Batch 1474, Loss:  0.073098, Epoch: 6
# Batch 1476, Loss:  0.073188, Epoch: 6
# Batch 1478, Loss:  0.073265, Epoch: 6
# Batch 1480, Loss:  0.073367, Epoch: 6
# Batch 1482, Loss:  0.073449, Epoch: 6
# Batch 1484, Loss:  0.073580, Epoch: 6
# Batch 1486, Loss:  0.073662, Epoch: 6
# Batch 1488, Loss:  0.073753, Epoch: 6
# Batch 1490, Loss:  0.073870, Epoch: 6
# Batch 1492, Loss:  0.074002, Epoch: 6
# Batch 1494, Loss:  0.074097, Epoch: 6
# Batch 1496, Loss:  0.074206, Epoch: 6
# Batch 1498, Loss:  0.074332, Epoch: 6
# Batch 1500, Loss:  0.074411, Epoch: 6
# Batch 1502, Loss:  0.074532, Epoch: 6
# Batch 1504, Loss:  0.074601, Epoch: 6
# Batch 1506, Loss:  0.074691, Epoch: 6
# Batch 1508, Loss:  0.074791, Epoch: 6
# Batch 1510, Loss:  0.074868, Epoch: 6
# Batch 1512, Loss:  0.074970, Epoch: 6
# Batch 1514, Loss:  0.075113, Epoch: 6
# Batch 1516, Loss:  0.075235, Epoch: 6
# Batch 1518, Loss:  0.075356, Epoch: 6
# Batch 1520, Loss:  0.075438, Epoch: 6
# Batch 1522, Loss:  0.075519, Epoch: 6
# Batch 1524, Loss:  0.075639, Epoch: 6
# Batch 1526, Loss:  0.075741, Epoch: 6
# Batch 1528, Loss:  0.075811, Epoch: 6
# Batch 1530, Loss:  0.075887, Epoch: 6
# Batch 1532, Loss:  0.075987, Epoch: 6
# Batch 1534, Loss:  0.076095, Epoch: 6
# Batch 1536, Loss:  0.076190, Epoch: 6
# Batch 1538, Loss:  0.076293, Epoch: 6
# Batch 1540, Loss:  0.076403, Epoch: 6
# Batch 1542, Loss:  0.076501, Epoch: 6
# Batch 1544, Loss:  0.076590, Epoch: 6
# Batch 1546, Loss:  0.076673, Epoch: 6
# Batch 1548, Loss:  0.076779, Epoch: 6
# Batch 1550, Loss:  0.076859, Epoch: 6
# Batch 1552, Loss:  0.076953, Epoch: 6
# Batch 1554, Loss:  0.077023, Epoch: 6
# Batch 1556, Loss:  0.077138, Epoch: 6
# Batch 1558, Loss:  0.077250, Epoch: 6
# Batch 1560, Loss:  0.077340, Epoch: 6
# Batch 1562, Loss:  0.077475, Epoch: 6
# Batch 1564, Loss:  0.077575, Epoch: 6
# Batch 1566, Loss:  0.077663, Epoch: 6
# Batch 1568, Loss:  0.077765, Epoch: 6
# Batch 1570, Loss:  0.077855, Epoch: 6
# Batch 1572, Loss:  0.077972, Epoch: 6
# Batch 1574, Loss:  0.078084, Epoch: 6
# Batch 1576, Loss:  0.078191, Epoch: 6
# Batch 1578, Loss:  0.078280, Epoch: 6
# Batch 1580, Loss:  0.078382, Epoch: 6
# Batch 1582, Loss:  0.078491, Epoch: 6
# Batch 1584, Loss:  0.078597, Epoch: 6
# Batch 1586, Loss:  0.078675, Epoch: 6
# Batch 1588, Loss:  0.078767, Epoch: 6
# Batch 1590, Loss:  0.078870, Epoch: 6
# Batch 1592, Loss:  0.078945, Epoch: 6
# Batch 1594, Loss:  0.079032, Epoch: 6
# Batch 1596, Loss:  0.079152, Epoch: 6
# Batch 1598, Loss:  0.079258, Epoch: 6
# Batch 1600, Loss:  0.079346, Epoch: 6
# Batch 1602, Loss:  0.079429, Epoch: 6
# Batch 1604, Loss:  0.079511, Epoch: 6
# Batch 1606, Loss:  0.079632, Epoch: 6
# Batch 1608, Loss:  0.079730, Epoch: 6
# Batch 1610, Loss:  0.079809, Epoch: 6
# Batch 1612, Loss:  0.079903, Epoch: 6
# Batch 1614, Loss:  0.080002, Epoch: 6
# Batch 1616, Loss:  0.080095, Epoch: 6
# Batch 1618, Loss:  0.080193, Epoch: 6
# Batch 1620, Loss:  0.080268, Epoch: 6
# Batch 1622, Loss:  0.080376, Epoch: 6
# Batch 1624, Loss:  0.080487, Epoch: 6
# Batch 1626, Loss:  0.080587, Epoch: 6
# Batch 1628, Loss:  0.080683, Epoch: 6
# Batch 1630, Loss:  0.080805, Epoch: 6
# Batch 1632, Loss:  0.080892, Epoch: 6
# Batch 1634, Loss:  0.080972, Epoch: 6
# Batch 1636, Loss:  0.081099, Epoch: 6
# Batch 1638, Loss:  0.081206, Epoch: 6
# Batch 1640, Loss:  0.081301, Epoch: 6
# Batch 1642, Loss:  0.081391, Epoch: 6
# Batch 1644, Loss:  0.081485, Epoch: 6
# Batch 1646, Loss:  0.081558, Epoch: 6
# Batch 1648, Loss:  0.081651, Epoch: 6
# Batch 1650, Loss:  0.081738, Epoch: 6
# Batch 1652, Loss:  0.081824, Epoch: 6
# Batch 1654, Loss:  0.081946, Epoch: 6
# Batch 1656, Loss:  0.082038, Epoch: 6
# Batch 1658, Loss:  0.082140, Epoch: 6
# Batch 1660, Loss:  0.082204, Epoch: 6
# Batch 1662, Loss:  0.082289, Epoch: 6
# Batch 1664, Loss:  0.082378, Epoch: 6
# Batch 1666, Loss:  0.082467, Epoch: 6
# Batch 1668, Loss:  0.082549, Epoch: 6
# Batch 1670, Loss:  0.082630, Epoch: 6
# Batch 1672, Loss:  0.082731, Epoch: 6
# Batch 1674, Loss:  0.082812, Epoch: 6
# Batch 1676, Loss:  0.082914, Epoch: 6
# Batch 1678, Loss:  0.083041, Epoch: 6
# Batch 1680, Loss:  0.083159, Epoch: 6
# Batch 1682, Loss:  0.083231, Epoch: 6
# Batch 1684, Loss:  0.083313, Epoch: 6
# Batch 1686, Loss:  0.083416, Epoch: 6
# Batch 1688, Loss:  0.083516, Epoch: 6
# Batch 1690, Loss:  0.083604, Epoch: 6
# Batch 1692, Loss:  0.083723, Epoch: 6
# Batch 1694, Loss:  0.083799, Epoch: 6
# Batch 1696, Loss:  0.083885, Epoch: 6
# Batch 1698, Loss:  0.083967, Epoch: 6
# Batch 1700, Loss:  0.084069, Epoch: 6
# Batch 1702, Loss:  0.084143, Epoch: 6
# Batch 1704, Loss:  0.084263, Epoch: 6
# Batch 1706, Loss:  0.084372, Epoch: 6
# Batch 1708, Loss:  0.084459, Epoch: 6
# Batch 1710, Loss:  0.084576, Epoch: 6
# Batch 1712, Loss:  0.084695, Epoch: 6
# Batch 1714, Loss:  0.084797, Epoch: 6
# Batch 1716, Loss:  0.084884, Epoch: 6
# Batch 1718, Loss:  0.085010, Epoch: 6
# Batch 1720, Loss:  0.085101, Epoch: 6
# Batch 1722, Loss:  0.085184, Epoch: 6
# Batch 1724, Loss:  0.085275, Epoch: 6
# Batch 1726, Loss:  0.085372, Epoch: 6
# Batch 1728, Loss:  0.085461, Epoch: 6
# Batch 1730, Loss:  0.085550, Epoch: 6
# Batch 1732, Loss:  0.085657, Epoch: 6
# Batch 1734, Loss:  0.085744, Epoch: 6
# Batch 1736, Loss:  0.085849, Epoch: 6
# Batch 1738, Loss:  0.085982, Epoch: 6
# Batch 1740, Loss:  0.086066, Epoch: 6
# Batch 1742, Loss:  0.086176, Epoch: 6
# Batch 1744, Loss:  0.086258, Epoch: 6
# Batch 1746, Loss:  0.086388, Epoch: 6
# Batch 1748, Loss:  0.086471, Epoch: 6
# Batch 1750, Loss:  0.086572, Epoch: 6
# Batch 1752, Loss:  0.086683, Epoch: 6
# Batch 1754, Loss:  0.086789, Epoch: 6
# Batch 1756, Loss:  0.086888, Epoch: 6
# Batch 1758, Loss:  0.086989, Epoch: 6
# Batch 1760, Loss:  0.087093, Epoch: 6
# Batch 1762, Loss:  0.087179, Epoch: 6
# Batch 1764, Loss:  0.087262, Epoch: 6
# Batch 1766, Loss:  0.087366, Epoch: 6
# Validation Loss  0.009
# ###################################################
# Early stopping
# [tensor(0.0088), tensor(0.0107), tensor(0.0096), tensor(0.0115), tensor(0.0108), tensor(0.0091)]
# Best_Validation_Loss tensor(0.0088)
# Training time:  623.1816527843475

# %%
print("Train time in minutes: ", (end_time - start_time)/60)
# Out:
# Train time in minutes:  10.386360879739126

# %% [markdown]
# # LSTM Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

df = pd.read_csv('experimental/Training.csv')
time = df['Time'].values.astype('float32')
time = time[:len(time)-30]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 9))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Angular Speed (rad/s)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

df = pd.read_csv('experimental/Testing.csv')
time = df['Time'].values.astype('float32')
time = time[:len(time)-30]

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Angular Speed (rad/s)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time (s)')
axs[1, 0].set_ylabel('Weight (kg)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time (s)')
axs[1, 1].set_ylabel('Weight (kg)')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the model and furnishing the output data

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

# Define the hyperparameters
input_size = 2
hidden_size = 120
num_stacked_layers = 5
fc_size1 = 140
fc_size2 = 280
fc_size3 = 360
output_size = 2
dropout = 0.1

# Initialize the model
model = LSTMModel(input_size, hidden_size, num_stacked_layers, dropout=0.0, output_size=output_size)

model_path = "model.pth"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
model.load_state_dict(torch.load(model_path))

model.to(device)

model.eval()
# Out:
# cpu
# LSTMModel(
#   (lstm_layers): ModuleList(
#     (0): ResidualLSTM(
#       (lstm): LSTM(2, 120, batch_first=True)
#       (residual): Linear(in_features=2, out_features=120, bias=True)
#     )
#     (1-4): 4 x ResidualLSTM(
#       (lstm): LSTM(120, 120, batch_first=True)
#       (residual): Identity()
#     )
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (attention): Sequential(
#     (0): Linear(in_features=120, out_features=1, bias=True)
#     (1): Tanh()
#   )
#   (fc_output1): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
#   (fc_output2): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
# )

# %%
for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

print("Actual_Data_shape", actual_data.shape, "Predicted_Data_shape", predicted_data.shape)
# Out:
# Actual_Data_shape (52970, 2) Predicted_Data_shape (52970, 2)

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

time = np.linspace(0, 60, len(actual_data))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time Stamp')
axs[0, 0].set_ylabel('Flow')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time Stamp')
axs[0, 1].set_ylabel('Flow')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

time = np.linspace(0, 60, len(actual_data))
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time Stamp')
axs[0, 0].set_ylabel('Flow')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time Stamp')
axs[0, 1].set_ylabel('Flow')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Concatenating the test train and analysing the
print(type(X_train))
X_train = X_train.cpu().numpy()
print(X_train.shape)

X_test = X_test.cpu().numpy()
print(X_test.shape)

# dataset_total = np.concatenate((X_train, X_test))
# print(dataset_total.shape)
inputs = X_train[len(X_train) - 30:]
print(inputs.shape)
# inputs = inputs.reshape(-1, 2)
# print(inputs.shape)
# Out:
# <class 'torch.Tensor'>
# (52970, 30, 2)
# (5970, 30, 2)
# (30, 30, 2)

# %%
input_tensor = torch.from_numpy(inputs).to(device)
print(input_tensor.shape)
model.eval()

with torch.no_grad():
  predicted_number = model(input_tensor)

predicted_number = predicted_number.cpu().numpy()

print("Predicted_Number_shape", predicted_number.shape)
# Out:
# torch.Size([30, 30, 2])
# Predicted_Number_shape (30, 2)

# %%
labels = set_to_scale_labels[len(set_to_scale_labels)-30:]

fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].plot(labels[:, 0], color = 'red', label = 'Last Batch Labels')
ax[0].plot(predicted_number[:, 0], color = 'blue', label = 'Predicted Output Velocity')
ax[0].set_xlabel('Time Stamps (s)')
ax[0].set_ylabel('Labels (rad/sec)')
ax[0].set_title("Real Out Vel last 30 samples")
ax[0].legend()

ax[1].plot(labels[:, 1], color = 'red', label = 'Last Batch Labels')
ax[1].plot(predicted_number[:, 1], color = 'blue', label = 'Predicted Weight on Bit')
ax[1].set_xlabel('Time Stamps (s)')
ax[1].set_ylabel('Weight on bit (kg)')
ax[1].set_title("Predicted Bit Weight last 30 samples")
ax[1].legend()

plt.tight_layout()
plt.show()
