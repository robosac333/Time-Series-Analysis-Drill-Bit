# %% [markdown]
# Time-Series Prediction
# Time series and sequence prediction could be a really amazing to predict/estimate a robot's trajectory which requires temporal data at hand. In this assignemnt we will see how this could be done using Deep Learning.
#
# Given a dataset [link](https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv) for airline passengers prediction problem. Predict the number of international airline passengers in units of 1,000 given a year and a month.
# Here is how the data looks like.

# %%
import netron 
netron.start('rnnmodel.onnx')
# Out:
# Serving 'rnnmodel.onnx' at http://localhost:8080
# ('localhost', 8080)

# %%
import matplotlib.pyplot as plt
import pandas as pd
file_name = 'experimental/Training.csv' # dataset path
# Reading data using pandas or csv
df = pd.read_csv(file_name)
print(df.columns)
# Out:
# Index(['Time', 'Output Speed', 'Input Torque', 'Input Speed', 'Weight on bit'], dtype='object')

# %%
df
# Out:
#          Time  Output Speed  Input Torque  Input Speed  Weight on bit
# 0       0.000    148.157782      0.546254   104.776226     539.866525
# 1       0.001    148.870922      0.566799   105.120533     537.944529
# 2       0.002    149.556036      0.594301   106.241970     536.005967
# 3       0.003    150.212917      0.628518   108.393450     534.037938
# 4       0.004    150.841484      0.669332   109.377789     532.056127
# ...       ...           ...           ...          ...            ...
# 52995  52.995    141.525790      1.402770   102.036217     448.634747
# 52996  52.996    142.137385      1.391925   101.221814     447.199109
# 52997  52.997    142.726691      1.381913   100.893232     445.788984
# 52998  52.998    143.293376      1.372741   101.865686     444.418114
# 52999  52.999    143.837221      1.364316   102.100991     443.069257
#
# [53000 rows x 5 columns]

# %%
# Converting columns to numpy arrays for plotting
time = df[["Time"]].values.astype('float32')
output_speed = df[["Output Speed"]].values.astype('float32')
input_torque = df[["Input Torque"]].values.astype('float32')
input_speed = df[["Input Speed"]].values.astype('float32')
weight_on_bit = df[["Weight on bit"]].values.astype('float32')

# Plotting the dataset
fig, axs = plt.subplots(2, 2, figsize=(15, 9))

# Plot Input Speed
axs[0, 0].plot(time, input_speed, label='Input Speed')
axs[0, 0].set_title('Input Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Plot Input Torque
axs[0, 1].plot(time, input_torque, label='Input Torque')
axs[0, 1].set_title('Input Torque')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Torque (N-m)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Plot Output Speed
axs[1, 0].plot(time, output_speed, label='Output Speed')
axs[1, 0].set_title('Output Speed')
axs[1, 0].set_xlabel('Time (s)')
axs[1, 0].set_ylabel('Angular Speed (rad/s)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Plot Weight on Bit
axs[1, 1].plot(time, weight_on_bit, label='Weight on Bit')
axs[1, 1].set_title('Weight on Bit')
axs[1, 1].set_xlabel('Time (s)')
axs[1, 1].set_ylabel('Weight (kg)')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # **Pytorch LSTM Implementation**

# %% [markdown]
# # Pre-Processing the Training Data

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

xy = np.loadtxt('experimental/Training.csv', delimiter=",", dtype=np.object_, skiprows=1)

# Convert the data to a 2D NumPy array of floats
features = np.array(xy[:, 1:], dtype=np.float32)

from sklearn.preprocessing import MinMaxScaler
feature_scaler = MinMaxScaler(feature_range=(0,1))
scaled_features = feature_scaler.fit_transform(features)

# Convert the NumPy array to a PyTorch tensor
Training_set = torch.from_numpy(scaled_features).to(device)

print("=================Creating_Dataset==================\n", Training_set.shape, "\n")

set_to_scale_features = []
set_to_scale_labels = []

# # Loop through the array to create the feature and label sets
for i in range(30, Training_set.shape[0]):
    set_to_scale_features.append(Training_set[i-30:i, [1, 2]].cpu().numpy())
    set_to_scale_labels.append(Training_set[i, [0, 3]].cpu().numpy())

# # Convert lists to NumPy arrays
set_to_scale_features = np.array(set_to_scale_features)
set_to_scale_labels = np.array(set_to_scale_labels)


print("=================Creating Features and Labels==================\n", set_to_scale_features.shape, "\n", set_to_scale_labels.shape, "\n" )

# # Reshape the feature set
X_train = torch.from_numpy(set_to_scale_features.reshape(set_to_scale_features.shape[0], set_to_scale_features.shape[1], 2)).to(device)

# # Convert labels to PyTorch tensor
Y_train = torch.from_numpy(set_to_scale_labels.reshape(set_to_scale_labels.shape[0], 2)).to(device)

print("=================Converting Features and Labels to Tensors==================\n", X_train.shape, "\n", Y_train.shape, "\n" )

# set_to_scale_labels = set_to_scale_labels.unsqueeze(1)
# print("Unsqueezed the labels to combine", set_to_scale_labels.shape)
# Out:
# =================Creating_Dataset==================
#  torch.Size([53000, 4])
#
# =================Creating Features and Labels==================
#  (52970, 30, 2)
#  (52970, 2)
#
# =================Converting Features and Labels to Tensors==================
#  torch.Size([52970, 30, 2])
#  torch.Size([52970, 2])

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import math
from sklearn.model_selection import train_test_split

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

xy = np.loadtxt('experimental/Testing.csv', delimiter=",", dtype=np.object_, skiprows=1)

# Convert the data to a 2D NumPy array of floats
test_features = np.array(xy[:, 1:], dtype=np.float32)

scaled_test_features = feature_scaler.transform(test_features)

# Convert the NumPy array to a PyTorch tensor
Testing_set = torch.from_numpy(scaled_test_features).to(device)

print("=================Creating_Dataset==================\n", Testing_set.shape, "\n")

set_to_scale_test_features = []
set_to_scale_test_labels = []

# # Loop through the array to create the feature and label sets
for i in range(30, Testing_set.shape[0]):
    set_to_scale_test_features.append(Testing_set[i-30:i, [1, 2]].cpu().numpy())
    set_to_scale_test_labels.append(Testing_set[i, [0, 3]].cpu().numpy())

# # Convert lists to NumPy arrays
set_to_scale_test_features = np.array(set_to_scale_test_features)
set_to_scale_test_labels = np.array(set_to_scale_test_labels)


print("=================Creating Features and Labels==================\n", set_to_scale_test_features.shape, "\n", set_to_scale_test_labels.shape, "\n" )

# # Reshape the feature set
X_test = torch.from_numpy(set_to_scale_test_features.reshape(set_to_scale_test_features.shape[0], set_to_scale_test_features.shape[1], 2)).to(device)

# # Convert labels to PyTorch tensor
Y_test = torch.from_numpy(set_to_scale_test_labels.reshape(set_to_scale_test_labels.shape[0], 2)).to(device)

print("=================Converting Features and Labels to Tensors==================\n", X_test.shape, "\n", Y_test.shape, "\n" )
# Out:
# =================Creating_Dataset==================
#  torch.Size([6000, 4])
#
# =================Creating Features and Labels==================
#  (5970, 30, 2)
#  (5970, 2)
#
# =================Converting Features and Labels to Tensors==================
#  torch.Size([5970, 30, 2])
#  torch.Size([5970, 2])

# %%
# # Creating dataset objects to process nn data through pytorch
from torch.utils.data import Dataset

class TSA(Dataset):
  def __init__(self, X, Y):
    self.X = X
    self.Y = Y

  def __getitem__(self, index) :
    return self.X[index], self.Y[index]

  def __len__(self):
    return len(self.X)

train_dataset = TSA(X_train, Y_train)
test_dataset = TSA(X_test, Y_test)

# train_dataset

# # Using data_loader to classify data in required format
from torch.utils.data import DataLoader

batch_size = 30

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# # Print the batch sizes to confirm
for _, batch in enumerate(train_loader):
  x_batch, y_batch = batch[0].to(device), batch[1].to(device)
  print(x_batch.shape, y_batch.shape)
  break
# Out:
# torch.Size([30, 30, 2]) torch.Size([30, 2])

# %% [markdown]
# # LSTM Training

# %%
import numpy as np
import torch
import torch.nn as nn

# Define the hyperparameters
input_size = 2
hidden_size = 120
num_stacked_layers = 5
fc_size1 = 140
fc_size2 = 280
fc_size3 = 360
output_size = 2
dropout = 0.1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ResidualLSTM(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.residual = nn.Linear(input_size, hidden_size) if input_size != hidden_size else nn.Identity()

    def forward(self, x):
        residual = self.residual(x)
        out, (hn, cn) = self.lstm(x)
        return out + residual, (hn, cn)

class ResidualFC(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.fc = nn.Linear(in_features, out_features)
        self.residual = nn.Linear(in_features, out_features) if in_features != out_features else nn.Identity()
        self.relu = nn.ReLU()

    def forward(self, x):
        residual = self.residual(x)
        out = self.fc(x)
        return self.relu(out + residual)

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers, dropout, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        # Stacked LSTM layers with residual connections
        self.lstm_layers = nn.ModuleList([
            ResidualLSTM(input_size if i == 0 else hidden_size, hidden_size)
            for i in range(num_stacked_layers)
        ])

        self.dropout = nn.Dropout(dropout)

        # Separate fully connected layers for each output with residual connections
        self.fc_output1 = nn.Sequential(
            ResidualFC(hidden_size, fc_size1),
            ResidualFC(fc_size1, fc_size2),
            ResidualFC(fc_size2, fc_size3),
            nn.Linear(fc_size3, 1)
        )

        self.fc_output2 = nn.Sequential(
            ResidualFC(hidden_size, fc_size1),
            ResidualFC(fc_size1, fc_size2),
            ResidualFC(fc_size2, fc_size3),
            nn.Linear(fc_size3, 1)
        )

    def forward(self, x):
        # Process through LSTM layers
        for lstm_layer in self.lstm_layers:
            x, _ = lstm_layer(x)

        x = self.dropout(x[:, -1, :])  # Use only the last time step output

        # Apply separate fully connected layers for each output
        output1 = self.fc_output1(x)
        output2 = self.fc_output2(x)

        # Concatenate the outputs
        return torch.cat((output1, output2), dim=1)

# Initialize the model
model = LSTMModel(input_size, hidden_size, num_stacked_layers, dropout, output_size=output_size)
model.to(device)

# Print model summary
print(model)
# Out:
# LSTMModel(
#   (lstm_layers): ModuleList(
#     (0): ResidualLSTM(
#       (lstm): LSTM(2, 120, batch_first=True)
#       (residual): Linear(in_features=2, out_features=120, bias=True)
#     )
#     (1-4): 4 x ResidualLSTM(
#       (lstm): LSTM(120, 120, batch_first=True)
#       (residual): Identity()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc_output1): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
#   (fc_output2): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
# )

# %%
import torch.optim as optim
learning_rate = 0.001
num_epochs = 20

best_val_loss = float('inf')
patience = 5
counter = 0

val_loss_list = []

# Define your loss function
loss_function = nn.MSELoss()

# Define your optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Running epochs
for epoch in range(num_epochs):
    # Set model to training mode
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # print(batch_index)
        if batch_index % 2 == 1:
          avg_loss_across_batches = running_loss / 100
          print('Batch {0}, Loss: {1: .6f}, Epoch: {2}'.format(batch_index+1, avg_loss_across_batches, epoch+1))

# Validate every epoch
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
          output = model(x_batch)
          loss = loss_function(output, y_batch)
          running_loss += loss

    val_loss = running_loss / len(test_loader)
    print('Validation Loss {0: .3f}'.format(val_loss))

    print('###################################################')

    running_loss = 0.0

    val_loss_list.append(val_loss)

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping")
            print(val_loss_list)
            print("Best_Validation_Loss", best_val_loss)
            break

# Save the model
model_save_path = 'model.pth'
torch.save(model.state_dict(), model_save_path)
# Out:
# Epoch: 1
# Batch 2, Loss:  0.003781, Epoch: 1
# Batch 4, Loss:  0.004998, Epoch: 1
# Batch 6, Loss:  0.006003, Epoch: 1
# Batch 8, Loss:  0.006951, Epoch: 1
# Batch 10, Loss:  0.007423, Epoch: 1
# Batch 12, Loss:  0.007872, Epoch: 1
# Batch 14, Loss:  0.008315, Epoch: 1
# Batch 16, Loss:  0.008757, Epoch: 1
# Batch 18, Loss:  0.009242, Epoch: 1
# Batch 20, Loss:  0.009615, Epoch: 1
# Batch 22, Loss:  0.010109, Epoch: 1
# Batch 24, Loss:  0.010438, Epoch: 1
# Batch 26, Loss:  0.010816, Epoch: 1
# Batch 28, Loss:  0.011304, Epoch: 1
# Batch 30, Loss:  0.011732, Epoch: 1
# Batch 32, Loss:  0.012252, Epoch: 1
# Batch 34, Loss:  0.012562, Epoch: 1
# Batch 36, Loss:  0.012933, Epoch: 1
# Batch 38, Loss:  0.013262, Epoch: 1
# Batch 40, Loss:  0.013686, Epoch: 1
# Batch 42, Loss:  0.014012, Epoch: 1
# Batch 44, Loss:  0.014412, Epoch: 1
# Batch 46, Loss:  0.014789, Epoch: 1
# Batch 48, Loss:  0.015308, Epoch: 1
# Batch 50, Loss:  0.015698, Epoch: 1
# Batch 52, Loss:  0.016072, Epoch: 1
# Batch 54, Loss:  0.016457, Epoch: 1
# Batch 56, Loss:  0.016903, Epoch: 1
# Batch 58, Loss:  0.017348, Epoch: 1
# Batch 60, Loss:  0.017824, Epoch: 1
# Batch 62, Loss:  0.018319, Epoch: 1
# Batch 64, Loss:  0.018839, Epoch: 1
# Batch 66, Loss:  0.019278, Epoch: 1
# Batch 68, Loss:  0.019800, Epoch: 1
# Batch 70, Loss:  0.020231, Epoch: 1
# Batch 72, Loss:  0.020717, Epoch: 1
# Batch 74, Loss:  0.021090, Epoch: 1
# Batch 76, Loss:  0.021532, Epoch: 1
# Batch 78, Loss:  0.021902, Epoch: 1
# Batch 80, Loss:  0.022329, Epoch: 1
# Batch 82, Loss:  0.022710, Epoch: 1
# Batch 84, Loss:  0.023142, Epoch: 1
# Batch 86, Loss:  0.023431, Epoch: 1
# Batch 88, Loss:  0.023837, Epoch: 1
# Batch 90, Loss:  0.024183, Epoch: 1
# Batch 92, Loss:  0.024616, Epoch: 1
# Batch 94, Loss:  0.025018, Epoch: 1
# Batch 96, Loss:  0.025472, Epoch: 1
# Batch 98, Loss:  0.025866, Epoch: 1
# Batch 100, Loss:  0.026306, Epoch: 1
# Batch 102, Loss:  0.026746, Epoch: 1
# Batch 104, Loss:  0.027041, Epoch: 1
# Batch 106, Loss:  0.027512, Epoch: 1
# Batch 108, Loss:  0.027840, Epoch: 1
# Batch 110, Loss:  0.028198, Epoch: 1
# Batch 112, Loss:  0.028612, Epoch: 1
# Batch 114, Loss:  0.029081, Epoch: 1
# Batch 116, Loss:  0.029452, Epoch: 1
# Batch 118, Loss:  0.029773, Epoch: 1
# Batch 120, Loss:  0.030080, Epoch: 1
# Batch 122, Loss:  0.030511, Epoch: 1
# Batch 124, Loss:  0.030864, Epoch: 1
# Batch 126, Loss:  0.031326, Epoch: 1
# Batch 128, Loss:  0.031710, Epoch: 1
# Batch 130, Loss:  0.032102, Epoch: 1
# Batch 132, Loss:  0.032450, Epoch: 1
# Batch 134, Loss:  0.032916, Epoch: 1
# Batch 136, Loss:  0.033263, Epoch: 1
# Batch 138, Loss:  0.033634, Epoch: 1
# Batch 140, Loss:  0.034025, Epoch: 1
# Batch 142, Loss:  0.034356, Epoch: 1
# Batch 144, Loss:  0.034695, Epoch: 1
# Batch 146, Loss:  0.035073, Epoch: 1
# Batch 148, Loss:  0.035392, Epoch: 1
# Batch 150, Loss:  0.035842, Epoch: 1
# Batch 152, Loss:  0.036200, Epoch: 1
# Batch 154, Loss:  0.036503, Epoch: 1
# Batch 156, Loss:  0.036890, Epoch: 1
# Batch 158, Loss:  0.037304, Epoch: 1
# Batch 160, Loss:  0.037702, Epoch: 1
# Batch 162, Loss:  0.038068, Epoch: 1
# Batch 164, Loss:  0.038418, Epoch: 1
# Batch 166, Loss:  0.038661, Epoch: 1
# Batch 168, Loss:  0.039085, Epoch: 1
# Batch 170, Loss:  0.039482, Epoch: 1
# Batch 172, Loss:  0.039943, Epoch: 1
# Batch 174, Loss:  0.040227, Epoch: 1
# Batch 176, Loss:  0.040666, Epoch: 1
# Batch 178, Loss:  0.041106, Epoch: 1
# Batch 180, Loss:  0.041437, Epoch: 1
# Batch 182, Loss:  0.041808, Epoch: 1
# Batch 184, Loss:  0.042175, Epoch: 1
# Batch 186, Loss:  0.042566, Epoch: 1
# Batch 188, Loss:  0.043014, Epoch: 1
# Batch 190, Loss:  0.043529, Epoch: 1
# Batch 192, Loss:  0.043945, Epoch: 1
# Batch 194, Loss:  0.044293, Epoch: 1
# Batch 196, Loss:  0.044659, Epoch: 1
# Batch 198, Loss:  0.044983, Epoch: 1
# Batch 200, Loss:  0.045303, Epoch: 1
# Batch 202, Loss:  0.045655, Epoch: 1
# Batch 204, Loss:  0.045993, Epoch: 1
# Batch 206, Loss:  0.046318, Epoch: 1
# Batch 208, Loss:  0.046668, Epoch: 1
# Batch 210, Loss:  0.047047, Epoch: 1
# Batch 212, Loss:  0.047407, Epoch: 1
# Batch 214, Loss:  0.047705, Epoch: 1
# Batch 216, Loss:  0.048106, Epoch: 1
# Batch 218, Loss:  0.048486, Epoch: 1
# Batch 220, Loss:  0.048781, Epoch: 1
# Batch 222, Loss:  0.049270, Epoch: 1
# Batch 224, Loss:  0.049639, Epoch: 1
# Batch 226, Loss:  0.050083, Epoch: 1
# Batch 228, Loss:  0.050487, Epoch: 1
# Batch 230, Loss:  0.051018, Epoch: 1
# Batch 232, Loss:  0.051543, Epoch: 1
# Batch 234, Loss:  0.052019, Epoch: 1
# Batch 236, Loss:  0.052507, Epoch: 1
# Batch 238, Loss:  0.052875, Epoch: 1
# Batch 240, Loss:  0.053218, Epoch: 1
# Batch 242, Loss:  0.053605, Epoch: 1
# Batch 244, Loss:  0.053942, Epoch: 1
# Batch 246, Loss:  0.054278, Epoch: 1
# Batch 248, Loss:  0.054696, Epoch: 1
# Batch 250, Loss:  0.055020, Epoch: 1
# Batch 252, Loss:  0.055389, Epoch: 1
# Batch 254, Loss:  0.055847, Epoch: 1
# Batch 256, Loss:  0.056181, Epoch: 1
# Batch 258, Loss:  0.056572, Epoch: 1
# Batch 260, Loss:  0.056934, Epoch: 1
# Batch 262, Loss:  0.057316, Epoch: 1
# Batch 264, Loss:  0.057725, Epoch: 1
# Batch 266, Loss:  0.058086, Epoch: 1
# Batch 268, Loss:  0.058532, Epoch: 1
# Batch 270, Loss:  0.058848, Epoch: 1
# Batch 396, Loss:  0.081305, Epoch: 1
# Batch 398, Loss:  0.081759, Epoch: 1
# Batch 400, Loss:  0.082229, Epoch: 1
# Batch 402, Loss:  0.082631, Epoch: 1
# Batch 404, Loss:  0.083132, Epoch: 1
# Batch 406, Loss:  0.083543, Epoch: 1
# Batch 408, Loss:  0.084038, Epoch: 1
# Batch 410, Loss:  0.084531, Epoch: 1
# Batch 412, Loss:  0.084919, Epoch: 1
# Batch 414, Loss:  0.085310, Epoch: 1
# Batch 416, Loss:  0.085640, Epoch: 1
# Batch 418, Loss:  0.086014, Epoch: 1
# Batch 420, Loss:  0.086286, Epoch: 1
# Batch 422, Loss:  0.086675, Epoch: 1
# Batch 424, Loss:  0.087104, Epoch: 1
# Batch 426, Loss:  0.087503, Epoch: 1
# Batch 428, Loss:  0.087956, Epoch: 1
# Batch 430, Loss:  0.088305, Epoch: 1
# Batch 432, Loss:  0.088640, Epoch: 1
# Batch 434, Loss:  0.089015, Epoch: 1
# Batch 436, Loss:  0.089321, Epoch: 1
# Batch 438, Loss:  0.089675, Epoch: 1
# Batch 440, Loss:  0.090033, Epoch: 1
# Batch 442, Loss:  0.090325, Epoch: 1
# Batch 444, Loss:  0.090721, Epoch: 1
# Batch 446, Loss:  0.091153, Epoch: 1
# Batch 448, Loss:  0.091457, Epoch: 1
# Batch 450, Loss:  0.091793, Epoch: 1
# Batch 452, Loss:  0.092162, Epoch: 1
# Batch 454, Loss:  0.092539, Epoch: 1
# Batch 456, Loss:  0.092969, Epoch: 1
# Batch 458, Loss:  0.093409, Epoch: 1
# Batch 460, Loss:  0.093802, Epoch: 1
# Batch 462, Loss:  0.094080, Epoch: 1
# Batch 464, Loss:  0.094452, Epoch: 1
# Batch 466, Loss:  0.094856, Epoch: 1
# Batch 468, Loss:  0.095220, Epoch: 1
# Batch 470, Loss:  0.095609, Epoch: 1
# Batch 472, Loss:  0.096049, Epoch: 1
# Batch 474, Loss:  0.096486, Epoch: 1
# Batch 476, Loss:  0.096902, Epoch: 1
# Batch 478, Loss:  0.097245, Epoch: 1
# Batch 480, Loss:  0.097586, Epoch: 1
# Batch 482, Loss:  0.097889, Epoch: 1
# Batch 484, Loss:  0.098219, Epoch: 1
# Batch 486, Loss:  0.098569, Epoch: 1
# Batch 488, Loss:  0.098969, Epoch: 1
# Batch 490, Loss:  0.099295, Epoch: 1
# Batch 492, Loss:  0.099709, Epoch: 1
# Batch 494, Loss:  0.100046, Epoch: 1
# Batch 496, Loss:  0.100405, Epoch: 1
# Batch 498, Loss:  0.100727, Epoch: 1
# Batch 500, Loss:  0.101010, Epoch: 1
# Batch 502, Loss:  0.101357, Epoch: 1
# Batch 504, Loss:  0.101607, Epoch: 1
# Batch 506, Loss:  0.101923, Epoch: 1
# Batch 508, Loss:  0.102209, Epoch: 1
# Batch 510, Loss:  0.102557, Epoch: 1
# Batch 512, Loss:  0.102842, Epoch: 1
# Batch 514, Loss:  0.103187, Epoch: 1
# Batch 516, Loss:  0.103445, Epoch: 1
# Batch 518, Loss:  0.103795, Epoch: 1
# Batch 520, Loss:  0.104081, Epoch: 1
# Batch 522, Loss:  0.104418, Epoch: 1
# Batch 524, Loss:  0.104738, Epoch: 1
# Batch 526, Loss:  0.105020, Epoch: 1
# Batch 528, Loss:  0.105307, Epoch: 1
# Batch 530, Loss:  0.105653, Epoch: 1
# Batch 532, Loss:  0.105927, Epoch: 1
# Batch 534, Loss:  0.106200, Epoch: 1
# Batch 536, Loss:  0.106573, Epoch: 1
# Batch 538, Loss:  0.106879, Epoch: 1
# Batch 540, Loss:  0.107143, Epoch: 1
# Batch 542, Loss:  0.107499, Epoch: 1
# Batch 544, Loss:  0.107853, Epoch: 1
# Batch 546, Loss:  0.108350, Epoch: 1
# Batch 548, Loss:  0.108689, Epoch: 1
# Batch 550, Loss:  0.109067, Epoch: 1
# Batch 552, Loss:  0.109361, Epoch: 1
# Batch 554, Loss:  0.109641, Epoch: 1
# Batch 556, Loss:  0.109960, Epoch: 1
# Batch 558, Loss:  0.110295, Epoch: 1
# Batch 560, Loss:  0.110604, Epoch: 1
# Batch 562, Loss:  0.110896, Epoch: 1
# Batch 564, Loss:  0.111193, Epoch: 1
# Batch 566, Loss:  0.111504, Epoch: 1
# Batch 568, Loss:  0.111769, Epoch: 1
# Batch 570, Loss:  0.112043, Epoch: 1
# Batch 572, Loss:  0.112459, Epoch: 1
# Batch 574, Loss:  0.112729, Epoch: 1
# Batch 576, Loss:  0.113061, Epoch: 1
# Batch 578, Loss:  0.113284, Epoch: 1
# Batch 580, Loss:  0.113585, Epoch: 1
# Batch 582, Loss:  0.113877, Epoch: 1
# Batch 584, Loss:  0.114151, Epoch: 1
# Batch 586, Loss:  0.114434, Epoch: 1
# Batch 588, Loss:  0.114626, Epoch: 1
# Batch 590, Loss:  0.114850, Epoch: 1
# Batch 592, Loss:  0.115161, Epoch: 1
# Batch 594, Loss:  0.115409, Epoch: 1
# Batch 596, Loss:  0.115723, Epoch: 1
# Batch 598, Loss:  0.116044, Epoch: 1
# Batch 600, Loss:  0.116292, Epoch: 1
# Batch 602, Loss:  0.116533, Epoch: 1
# Batch 604, Loss:  0.116819, Epoch: 1
# Batch 606, Loss:  0.117137, Epoch: 1
# Batch 608, Loss:  0.117433, Epoch: 1
# Batch 610, Loss:  0.117756, Epoch: 1
# Batch 612, Loss:  0.118072, Epoch: 1
# Batch 614, Loss:  0.118295, Epoch: 1
# Batch 616, Loss:  0.118548, Epoch: 1
# Batch 618, Loss:  0.118790, Epoch: 1
# Batch 620, Loss:  0.119046, Epoch: 1
# Batch 622, Loss:  0.119284, Epoch: 1
# Batch 624, Loss:  0.119629, Epoch: 1
# Batch 626, Loss:  0.119987, Epoch: 1
# Batch 628, Loss:  0.120265, Epoch: 1
# Batch 630, Loss:  0.120552, Epoch: 1
# Batch 632, Loss:  0.120954, Epoch: 1
# Batch 634, Loss:  0.121208, Epoch: 1
# Batch 636, Loss:  0.121493, Epoch: 1
# Batch 638, Loss:  0.121798, Epoch: 1
# Batch 640, Loss:  0.122087, Epoch: 1
# Batch 642, Loss:  0.122384, Epoch: 1
# Batch 644, Loss:  0.122674, Epoch: 1
# Batch 646, Loss:  0.122999, Epoch: 1
# Batch 648, Loss:  0.123214, Epoch: 1
# Batch 650, Loss:  0.123456, Epoch: 1
# Batch 652, Loss:  0.123687, Epoch: 1
# Batch 654, Loss:  0.123976, Epoch: 1
# Batch 656, Loss:  0.124210, Epoch: 1
# Batch 658, Loss:  0.124422, Epoch: 1
# Batch 660, Loss:  0.124677, Epoch: 1
# Batch 662, Loss:  0.124925, Epoch: 1
# Batch 664, Loss:  0.125203, Epoch: 1
# Batch 666, Loss:  0.125443, Epoch: 1
# Batch 668, Loss:  0.125704, Epoch: 1
# Batch 670, Loss:  0.125921, Epoch: 1
# Batch 672, Loss:  0.126164, Epoch: 1
# Batch 674, Loss:  0.126410, Epoch: 1
# Batch 676, Loss:  0.126613, Epoch: 1
# Batch 678, Loss:  0.126858, Epoch: 1
# Batch 680, Loss:  0.127141, Epoch: 1
# Batch 682, Loss:  0.127377, Epoch: 1
# Batch 684, Loss:  0.127610, Epoch: 1
# Batch 686, Loss:  0.127809, Epoch: 1
# Batch 688, Loss:  0.128050, Epoch: 1
# Batch 690, Loss:  0.128227, Epoch: 1
# Batch 692, Loss:  0.128449, Epoch: 1
# Batch 694, Loss:  0.128677, Epoch: 1
# Batch 696, Loss:  0.128916, Epoch: 1
# Batch 698, Loss:  0.129133, Epoch: 1
# Batch 700, Loss:  0.129339, Epoch: 1
# Batch 702, Loss:  0.129525, Epoch: 1
# Batch 704, Loss:  0.129726, Epoch: 1
# Batch 706, Loss:  0.129925, Epoch: 1
# Batch 708, Loss:  0.130181, Epoch: 1
# Batch 710, Loss:  0.130415, Epoch: 1
# Batch 712, Loss:  0.130606, Epoch: 1
# Batch 714, Loss:  0.130884, Epoch: 1
# Batch 716, Loss:  0.131114, Epoch: 1
# Batch 718, Loss:  0.131318, Epoch: 1
# Batch 720, Loss:  0.131545, Epoch: 1
# Batch 722, Loss:  0.131800, Epoch: 1
# Batch 724, Loss:  0.132032, Epoch: 1
# Batch 726, Loss:  0.132276, Epoch: 1
# Batch 728, Loss:  0.132519, Epoch: 1
# Batch 730, Loss:  0.132747, Epoch: 1
# Batch 732, Loss:  0.132944, Epoch: 1
# Batch 734, Loss:  0.133135, Epoch: 1
# Batch 736, Loss:  0.133298, Epoch: 1
# Batch 738, Loss:  0.133522, Epoch: 1
# Batch 740, Loss:  0.133759, Epoch: 1
# Batch 742, Loss:  0.134005, Epoch: 1
# Batch 744, Loss:  0.134176, Epoch: 1
# Batch 746, Loss:  0.134336, Epoch: 1
# Batch 748, Loss:  0.134570, Epoch: 1
# Batch 750, Loss:  0.134754, Epoch: 1
# Batch 752, Loss:  0.134933, Epoch: 1
# Batch 754, Loss:  0.135133, Epoch: 1
# Batch 756, Loss:  0.135315, Epoch: 1
# Batch 758, Loss:  0.135460, Epoch: 1
# Batch 760, Loss:  0.135653, Epoch: 1
# Batch 762, Loss:  0.135808, Epoch: 1
# Batch 764, Loss:  0.135983, Epoch: 1
# Batch 766, Loss:  0.136134, Epoch: 1
# Batch 768, Loss:  0.136282, Epoch: 1
# Batch 770, Loss:  0.136467, Epoch: 1
# Batch 772, Loss:  0.136630, Epoch: 1
# Batch 774, Loss:  0.136794, Epoch: 1
# Batch 776, Loss:  0.136942, Epoch: 1
# Batch 778, Loss:  0.137131, Epoch: 1
# Batch 780, Loss:  0.137296, Epoch: 1
# Batch 782, Loss:  0.137478, Epoch: 1
# Batch 784, Loss:  0.137649, Epoch: 1
# Batch 786, Loss:  0.137821, Epoch: 1
# Batch 788, Loss:  0.137968, Epoch: 1
# Batch 790, Loss:  0.138133, Epoch: 1
# Batch 792, Loss:  0.138283, Epoch: 1
# Batch 794, Loss:  0.138491, Epoch: 1
# Batch 796, Loss:  0.138674, Epoch: 1
# Batch 798, Loss:  0.138860, Epoch: 1
# Batch 800, Loss:  0.139040, Epoch: 1
# Batch 802, Loss:  0.139222, Epoch: 1
# Batch 804, Loss:  0.139398, Epoch: 1
# Batch 806, Loss:  0.139598, Epoch: 1
# Batch 808, Loss:  0.139792, Epoch: 1
# Batch 810, Loss:  0.139976, Epoch: 1
# Batch 812, Loss:  0.140153, Epoch: 1
# Batch 814, Loss:  0.140311, Epoch: 1
# Batch 816, Loss:  0.140502, Epoch: 1
# Batch 818, Loss:  0.140687, Epoch: 1
# Batch 820, Loss:  0.140886, Epoch: 1
# Batch 822, Loss:  0.141079, Epoch: 1
# Batch 824, Loss:  0.141239, Epoch: 1
# Batch 826, Loss:  0.141387, Epoch: 1
# Batch 828, Loss:  0.141573, Epoch: 1
# Batch 830, Loss:  0.141720, Epoch: 1
# Batch 832, Loss:  0.141866, Epoch: 1
# Batch 834, Loss:  0.142070, Epoch: 1
# Batch 836, Loss:  0.142232, Epoch: 1
# Batch 838, Loss:  0.142376, Epoch: 1
# Batch 840, Loss:  0.142551, Epoch: 1
# Batch 842, Loss:  0.142696, Epoch: 1
# Batch 844, Loss:  0.142818, Epoch: 1
# Batch 846, Loss:  0.143040, Epoch: 1
# Batch 848, Loss:  0.143215, Epoch: 1
# Batch 850, Loss:  0.143407, Epoch: 1
# Batch 852, Loss:  0.143607, Epoch: 1
# Batch 854, Loss:  0.143766, Epoch: 1
# Batch 856, Loss:  0.143910, Epoch: 1
# Batch 858, Loss:  0.144056, Epoch: 1
# Batch 860, Loss:  0.144235, Epoch: 1
# Batch 862, Loss:  0.144415, Epoch: 1
# Batch 864, Loss:  0.144610, Epoch: 1
# Batch 866, Loss:  0.144737, Epoch: 1
# Batch 868, Loss:  0.144918, Epoch: 1
# Batch 870, Loss:  0.145108, Epoch: 1
# Batch 872, Loss:  0.145260, Epoch: 1
# Batch 874, Loss:  0.145426, Epoch: 1
# Batch 876, Loss:  0.145562, Epoch: 1
# Batch 878, Loss:  0.145718, Epoch: 1
# Batch 880, Loss:  0.145855, Epoch: 1
# Batch 882, Loss:  0.145977, Epoch: 1
# Batch 884, Loss:  0.146105, Epoch: 1
# Batch 886, Loss:  0.146244, Epoch: 1
# Batch 888, Loss:  0.146373, Epoch: 1
# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

df = pd.read_csv('experimental/Training.csv')
time = df['Time'].values.astype('float32')
time = time[:len(time)-30]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 9))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Angular Speed (rad/s)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

df = pd.read_csv('experimental/Testing.csv')
time = df['Time'].values.astype('float32')
time = time[:len(time)-30]

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time (s)')
axs[0, 0].set_ylabel('Angular Speed (rad/s)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time (s)')
axs[0, 1].set_ylabel('Angular Speed (rad/s)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time (s)')
axs[1, 0].set_ylabel('Weight (kg)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time (s)')
axs[1, 1].set_ylabel('Weight (kg)')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Loading the model and furnishing the output data

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

# Define the hyperparameters
input_size = 2
hidden_size = 120
num_stacked_layers = 5
fc_size1 = 140
fc_size2 = 280
fc_size3 = 360
output_size = 2
dropout = 0.1

# Initialize the model
model = LSTMModel(input_size, hidden_size, num_stacked_layers, dropout=0.0, output_size=output_size)

model_path = "model.pth"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
model.load_state_dict(torch.load(model_path))

model.to(device)

model.eval()
# Out:
# cpu
# LSTMModel(
#   (lstm_layers): ModuleList(
#     (0): ResidualLSTM(
#       (lstm): LSTM(2, 120, batch_first=True)
#       (residual): Linear(in_features=2, out_features=120, bias=True)
#     )
#     (1-4): 4 x ResidualLSTM(
#       (lstm): LSTM(120, 120, batch_first=True)
#       (residual): Identity()
#     )
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (fc_output1): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
#   (fc_output2): Sequential(
#     (0): ResidualFC(
#       (fc): Linear(in_features=120, out_features=140, bias=True)
#       (residual): Linear(in_features=120, out_features=140, bias=True)
#       (relu): ReLU()
#     )
#     (1): ResidualFC(
#       (fc): Linear(in_features=140, out_features=280, bias=True)
#       (residual): Linear(in_features=140, out_features=280, bias=True)
#       (relu): ReLU()
#     )
#     (2): ResidualFC(
#       (fc): Linear(in_features=280, out_features=360, bias=True)
#       (residual): Linear(in_features=280, out_features=360, bias=True)
#       (relu): ReLU()
#     )
#     (3): Linear(in_features=360, out_features=1, bias=True)
#   )
# )

# %%
for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

print("Actual_Data_shape", actual_data.shape, "Predicted_Data_shape", predicted_data.shape)
# Out:
# Actual_Data_shape (52970, 2) Predicted_Data_shape (52970, 2)

# %%
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

time = np.linspace(0, 60, len(actual_data))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time Stamp')
axs[0, 0].set_ylabel('Flow')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time Stamp')
axs[0, 1].set_ylabel('Flow')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize predictions and actual values storage
actual_data = []
predicted_data = []

for batch_index, batch in enumerate(test_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    with torch.no_grad():
        predicted = model(x_batch).to('cpu').numpy()

    actual_data.append(y_batch.to('cpu').numpy())
    predicted_data.append(predicted)

# Convert lists to numpy arrays for plotting
actual_data = np.concatenate(actual_data, axis=0)
predicted_data = np.concatenate(predicted_data, axis=0)

time = np.linspace(0, 60, len(actual_data))
# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# First subplot - Actual Output Speed
axs[0, 0].plot(time, actual_data[:, 0], label='Scaled Actual Output Speed')
axs[0, 0].set_title('Actual Output Speed')
axs[0, 0].set_xlabel('Time Stamp')
axs[0, 0].set_ylabel('Flow')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Second subplot - Predicted Output Speed
axs[0, 1].plot(time, predicted_data[:, 0], label='Scaled Predicted Output Speed')
axs[0, 1].set_title('Predicted Output Speed')
axs[0, 1].set_xlabel('Time Stamp')
axs[0, 1].set_ylabel('Flow')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Third subplot - Actual Weight on Bit
axs[1, 0].plot(time, actual_data[:, 1], label='Scaled Actual Weight on Bit')
axs[1, 0].set_title('Actual Weight on Bit')
axs[1, 0].set_xlabel('Time Stamp')
axs[1, 0].set_ylabel('Flow')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Fourth subplot - Predicted Weight on Bit
axs[1, 1].plot(time, predicted_data[:, 1], label='Scaled Predicted Weight on Bit')
axs[1, 1].set_title('Predicted Weight on Bit')
axs[1, 1].set_xlabel('Time Stamp')
axs[1, 1].set_ylabel('Flow')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Concatenating the test train and analysing the
print(type(X_train))
X_train = X_train.cpu().numpy()
print(X_train.shape)

X_test = X_test.cpu().numpy()
print(X_test.shape)

# dataset_total = np.concatenate((X_train, X_test))
# print(dataset_total.shape)
inputs = X_train[len(X_train) - 30:]
print(inputs.shape)
# inputs = inputs.reshape(-1, 2)
# print(inputs.shape)
# Out:
# <class 'torch.Tensor'>
# (52970, 30, 2)
# (5970, 30, 2)
# (30, 30, 2)

# %%
input_tensor = torch.from_numpy(inputs).to(device)
print(input_tensor.shape)
model.eval()

with torch.no_grad():
  predicted_number = model(input_tensor)

predicted_number = predicted_number.cpu().numpy()

print("Predicted_Number_shape", predicted_number.shape)
# Out:
# torch.Size([30, 30, 2])
# Predicted_Number_shape (30, 2)

# %%
labels = set_to_scale_labels[len(set_to_scale_labels)-30:]

fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].plot(labels[:, 0], color = 'red', label = 'Last Batch Labels')
ax[0].plot(predicted_number[:, 0], color = 'blue', label = 'Predicted Output Velocity')
ax[0].set_xlabel('Time Stamps (s)')
ax[0].set_ylabel('Labels (rad/sec)')
ax[0].set_title("Real Out Vel last 30 samples")
ax[0].legend()

ax[1].plot(labels[:, 1], color = 'red', label = 'Last Batch Labels')
ax[1].plot(predicted_number[:, 1], color = 'blue', label = 'Predicted Weight on Bit')
ax[1].set_xlabel('Time Stamps (s)')
ax[1].set_ylabel('Weight on bit (kg)')
ax[1].set_title("Predicted Bit Weight last 30 samples")
ax[1].legend()

plt.tight_layout()
plt.show()
